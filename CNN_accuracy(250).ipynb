# %%
#Step -1
#importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Set to display all the columns of the dataset
pd.set_option("display.max_columns",None)

#Ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")
# Out:
# /home/l2-48/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %% [markdown]
# **DATA PRE PROCESSING**

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Define constants
data_path = r"/home/l2-48/Downloads/ARVIND/oral-combined-dataset"  # Updated path
target_size = (224, 224)  # Define the target size for resizing

# Function to load and preprocess images from a given folder
def load_images_from_folder(folder_path, label):
    images = []
    labels = []
    for image_name in os.listdir(folder_path):
        image_path = os.path.join(folder_path, image_name)
        # Read the image in grayscale
        img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        # Resize the image to the target size
        img = cv2.resize(img, target_size)
        # Normalize the pixel values to the range [0, 1]
        img = img.astype(np.float32) / 255.0
        # Append the preprocessed image to the images list
        images.append(img)
        # Append the label to the labels list
        labels.append(label)
    return images, labels

# Load and preprocess data for NORMAL and OSCC classes
all_images = []
all_labels = []

# Loop through each class (NORMAL and OSCC)
for class_name in ['NORMAL', 'OSCC']:
    class_path = os.path.join(data_path, class_name)
    images, labels = load_images_from_folder(class_path, 0 if class_name == 'NORMAL' else 1)
    all_images.extend(images)
    all_labels.extend(labels)

# Convert data to NumPy arrays
all_images = np.array(all_images)
all_labels = np.array(all_labels)

# Print class proportions
print("Data Class Proportions:")
print("Normal:", np.sum(all_labels == 0), "OSCC:", np.sum(all_labels == 1))

# Plot histogram for class distribution
plt.figure(figsize=(8, 6))
plt.hist(all_labels, bins=2, color='skyblue', edgecolor='black', alpha=0.7)
plt.xticks([0.25, 0.75], ['Normal', 'OSCC'])
plt.xlabel('Class')
plt.ylabel('Count')
plt.title('Data Distribution')
plt.show()
# Out:
# Data Class Proportions:
# Normal: 621 OSCC: 2032

# %% [markdown]
# BALANCING

# %%
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# Define constants
data_path = "/home/l2-48/Downloads/ARVIND/oral-combined-dataset"  # Updated path
target_size = (224, 224)  # Define the target size for resizing

# Load and preprocess data
images = []
labels = []

# Loop through each class (NORMAL and OSCC)
for class_name in ['NORMAL', 'OSCC']:
    class_path = os.path.join(data_path, class_name)
    # Iterate through each image in the class
    for image_name in os.listdir(class_path):
        image_path = os.path.join(class_path, image_name)
        # Read the image in grayscale
        img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        # Resize the image to the target size
        img = cv2.resize(img, target_size)
        # Normalize the pixel values to the range [0, 1]
        img = img.astype(np.float32) / 255.0
        # Append the preprocessed image to the images list
        images.append(img)
        # Append the label (0 for NORMAL, 1 for OSCC) to the labels list
        labels.append(0 if class_name == 'NORMAL' else 1)

# Convert images and labels to NumPy arrays
images = np.array(images)
labels = np.array(labels)

# Ensure dataset is balanced by selecting 600 images from each class
normal_images = images[labels == 0][:600]  # Select 600 images from NORMAL class
oscc_images = images[labels == 1][:600]    # Select 600 images from OSCC class
normal_labels = labels[labels == 0][:600]
oscc_labels = labels[labels == 1][:600]

# Concatenate the normal and OSCC images and labels to create a balanced dataset
balanced_images = np.concatenate([normal_images, oscc_images])
balanced_labels = np.concatenate([normal_labels, oscc_labels])

# Split the balanced dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(balanced_images, balanced_labels, test_size=0.2, random_state=42)

# Print the balanced data
print("Balanced Images:", balanced_images.shape)
print("Balanced Labels:", balanced_labels.shape)

# Print the data separately for each class
print("Normal Images:", normal_images.shape)
print("OSCC Images:", oscc_images.shape)

# Print the shapes of the training and testing sets
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)

# Plot histogram for the balanced class distribution
plt.figure(figsize=(8, 6))
plt.hist(balanced_labels, bins=2, color='skyblue', edgecolor='black', alpha=0.7)
plt.xticks([0.25, 0.75], ['Normal', 'OSCC'])
plt.xlabel('Class')
plt.ylabel('Count')
plt.title('Balanced Data Distribution')
plt.show()
# Out:
# Balanced Images: (1200, 224, 224)
# Balanced Labels: (1200,)
# Normal Images: (600, 224, 224)
# OSCC Images: (600, 224, 224)
# X_train shape: (960, 224, 224)
# X_test shape: (240, 224, 224)
# y_train shape: (960,)
# y_test shape: (240,)

# %% [markdown]
# LABELLING NORMAL -> 0 OSCC -> 1

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# Define the number of images to display
num_images_to_display = 10

# Select random indices for the images
indices = random.sample(range(len(balanced_images)), num_images_to_display)

# Create a figure to display the images
plt.figure(figsize=(15, 5))

# Loop over the selected indices and display the images
for i, idx in enumerate(indices):
    # Get the image and its corresponding label
    image = balanced_images[idx]
    label = balanced_labels[idx]

    # Define the label text for display as "NORMAL-0" or "OSCC-1"
    label_text = 'NORMAL-0' if label == 0 else 'OSCC-1'

    # Add a subplot for the current image
    plt.subplot(2, 5, i + 1)
    plt.imshow(image, cmap='gray')
    plt.title(f'Label: {label_text}')
    plt.axis('off')

# Adjust the layout of the subplots
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# Define the number of images to display
num_images_to_display = 10

# Select random indices for the images
indices = random.sample(range(len(balanced_images)), num_images_to_display)

# Create a figure to display the images
plt.figure(figsize=(15, 5))

# Loop over the selected indices and display the images
for i, idx in enumerate(indices):
    # Get the image and its corresponding label
    image = balanced_images[idx]
    label = balanced_labels[idx]

    # Define the label text for display as "NORMAL" or "OSCC"
    label_text = 'NORMAL' if label == 0 else 'OSCC'

    # Add a subplot for the current image
    plt.subplot(2, 5, i + 1)
    plt.imshow(image, cmap='gray')
    plt.title(f'Label: {label_text}')
    plt.axis('off')

# Adjust the layout of the subplots
plt.tight_layout()
plt.show()

# %% [markdown]
# # CNN

# %% [markdown]
# # Dense Layers

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_recall_curve, auc, precision_score, recall_score, f1_score, balanced_accuracy_score, cohen_kappa_score, matthews_corrcoef
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
import time
from tensorflow.keras.callbacks import EarlyStopping

# Start time
start_time = time.time()

# Assume X_train and y_train are the original splits

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension
X_train_resized = np.repeat(X_train_resized, 3, axis=-1)  # Repeat the channel dimension to match the expected input shape of the CNN

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)
X_test_resized = np.repeat(X_test_resized, 3, axis=-1)

# Define CNN architecture
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(512, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compile the model with Adam optimizer and additional metrics
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      tf.keras.metrics.TrueNegatives(),
                                                                      tf.keras.metrics.FalsePositives(),
                                                                      tf.keras.metrics.FalseNegatives(),
                                                                      tf.keras.metrics.TruePositives()])

# Display model summary
model.summary()

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model with early stopping and 50 epochs
history = model.fit(X_train_resized, y_train, epochs=50, validation_data=(X_test_resized, y_test), callbacks=[early_stopping])

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
test_loss, test_accuracy, precision, recall, auc_roc, auc_pr, tn, fp, fn, tp = model.evaluate(X_test_resized, y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
print(f'AUC-ROC: {auc_roc:.2f}')
print(f'AUC-PR: {auc_pr:.2f}')
print(f'TN: {tn}, FP: {fp}, FN: {fn}, TP: {tp}')

# Confusion matrix
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
print("Confusion Matrix:")
print(conf_matrix)

# Generate classification report
print("Classification Report:")
print(classification_report(y_test, test_predictions))

# ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, test_predictions)
roc_auc = roc_auc_score(y_test, test_predictions)
print(f'AUC Score: {roc_auc:.2f}')

# Precision for class 1 (Positive)
precision = precision_score(y_test, test_predictions)
print(f'Precision: {precision:.2f}')

# Recall for class 1 (Positive)
recall = recall_score(y_test, test_predictions)
print(f'Recall: {recall:.2f}')

# F1 Score
f1 = f1_score(y_test, test_predictions)
print(f'F1 Score: {f1:.2f}')

# Precision-Recall curve and PR AUC
precision, recall, _ = precision_recall_curve(y_test, test_predictions)
pr_auc = auc(recall, precision)
print(f'PR AUC: {pr_auc:.2f}')

# Cohen's Kappa Coefficient
kappa = cohen_kappa_score(y_test, test_predictions)
print(f"Cohen's Kappa Coefficient: {kappa:.2f}")

# Matthews Correlation Coefficient
mcc = matthews_corrcoef(y_test, test_predictions)
print(f"Matthews Correlation Coefficient (MCC): {mcc:.2f}")

# Balanced Accuracy
balanced_accuracy = balanced_accuracy_score(y_test, test_predictions)
print(f"Balanced Accuracy: {balanced_accuracy:.2f}")

# End time
end_time = time.time()

# Print the time taken
print(f"Time taken: {end_time - start_time:.2f} seconds")
# Out:
# 2024-11-15 12:50:31.947869: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-11-15 12:50:31.952214: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-15 12:50:31.993210: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-15 12:50:32.032477: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1731655232.066388   23886 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1731655232.075837   23886 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-15 12:50:32.155794: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-15 12:50:33.431960: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 52, 52, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 26, 26, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 86528)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │    44,302,848 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 44,396,609 (169.36 MB)
#  Trainable params: 44,396,609 (169.36 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 15s 461ms/step - accuracy: 0.4734 - auc: 0.4844 - auc_1: 0.5012 - false_negatives: 163.8065 - false_positives: 98.2581 - loss: 2.8587 - precision: 0.4716 - recall: 0.3994 - true_negatives: 154.0968 - true_positives: 94.8064 - val_accuracy: 0.5083 - val_auc: 0.4928 - val_auc_1: 0.4845 - val_false_negatives: 118.0000 - val_false_positives: 0.0000e+00 - val_loss: 0.6931 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_true_negatives: 122.0000 - val_true_positives: 0.0000e+00
# Epoch 2/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 13s 443ms/step - accuracy: 0.5573 - auc: 0.5173 - auc_1: 0.4785 - false_negatives: 174.1935 - false_positives: 59.8710 - loss: 0.6940 - precision: 0.4250 - recall: 0.2314 - true_negatives: 198.0000 - true_positives: 78.9032 - val_accuracy: 0.5083 - val_auc: 0.4912 - val_auc_1: 0.4833 - val_false_negatives: 118.0000 - val_false_positives: 0.0000e+00 - val_loss: 0.6936 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_true_negatives: 122.0000 - val_true_positives: 0.0000e+00
# Epoch 3/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 13s 442ms/step - accuracy: 0.5109 - auc: 0.4994 - auc_1: 0.4922 - false_negatives: 228.2903 - false_positives: 23.2581 - loss: 0.6993 - precision: 0.3804 - recall: 0.0577 - true_negatives: 234.8065 - true_positives: 24.6129 - val_accuracy: 0.4958 - val_auc: 0.4950 - val_auc_1: 0.5084 - val_false_negatives: 19.0000 - val_false_positives: 102.0000 - val_loss: 0.6939 - val_precision: 0.4925 - val_recall: 0.8390 - val_true_negatives: 20.0000 - val_true_positives: 99.0000
# Epoch 4/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 13s 442ms/step - accuracy: 0.4986 - auc: 0.5004 - auc_1: 0.4667 - false_negatives: 106.1936 - false_positives: 143.6129 - loss: 0.7046 - precision: 0.4794 - recall: 0.5514 - true_negatives: 117.3226 - true_positives: 143.8387 - val_accuracy: 0.5083 - val_auc: 0.5021 - val_auc_1: 0.4921 - val_false_negatives: 118.0000 - val_false_positives: 0.0000e+00 - val_loss: 0.6934 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_true_negatives: 122.0000 - val_true_positives: 0.0000e+00
# Epoch 4: early stopping
# Restoring model weights from the end of the best epoch: 1.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.5577 - auc: 0.4684 - auc_1: 0.4205 - false_negatives: 70.4444 - false_positives: 0.0000e+00 - loss: 0.6926 - precision: 0.0000e+00 - recall: 0.0000e+00 - true_negatives: 82.4444 - true_positives: 0.0000e+00
# Test Accuracy: 50.83%
# Precision: 0.00
# Recall: 0.00
# AUC-ROC: 0.49
# AUC-PR: 0.48
# TN: 122.0, FP: 0.0, FN: 118.0, TP: 0.0
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step
# Confusion Matrix:
# [[122   0]
#  [118   0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.51      1.00      0.67       122
#            1       0.00      0.00      0.00       118
#
#     accuracy                           0.51       240
#    macro avg       0.25      0.50      0.34       240
# weighted avg       0.26      0.51      0.34       240
#
# AUC Score: 0.50
# Precision: 0.00
# Recall: 0.00
# F1 Score: 0.00
# PR AUC: 0.75
# Cohen's Kappa Coefficient: 0.00
# Matthews Correlation Coefficient (MCC): 0.00
# Balanced Accuracy: 0.50
# Time taken: 56.92 seconds

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_recall_curve, auc, precision_score, recall_score, f1_score, balanced_accuracy_score, cohen_kappa_score, matthews_corrcoef
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
import time
from tensorflow.keras.callbacks import EarlyStopping

# Start time
start_time = time.time()

# Assume X_train and y_train are the original splits

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension
X_train_resized = np.repeat(X_train_resized, 3, axis=-1)  # Repeat the channel dimension to match the expected input shape of the CNN

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)
X_test_resized = np.repeat(X_test_resized, 3, axis=-1)

# Define CNN architecture
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(512, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compile the model with Adam optimizer and additional metrics
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      tf.keras.metrics.TrueNegatives(),
                                                                      tf.keras.metrics.FalsePositives(),
                                                                      tf.keras.metrics.FalseNegatives(),
                                                                      tf.keras.metrics.TruePositives()])

# Display model summary
model.summary()

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model with early stopping and 50 epochs
history = model.fit(X_train_resized, y_train, epochs=150, validation_data=(X_test_resized, y_test), callbacks=[early_stopping])

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
test_loss, test_accuracy, precision, recall, auc_roc, auc_pr, tn, fp, fn, tp = model.evaluate(X_test_resized, y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
print(f'AUC-ROC: {auc_roc:.2f}')
print(f'AUC-PR: {auc_pr:.2f}')
print(f'TN: {tn}, FP: {fp}, FN: {fn}, TP: {tp}')

# Confusion matrix
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
print("Confusion Matrix:")
print(conf_matrix)

# Generate classification report
print("Classification Report:")
print(classification_report(y_test, test_predictions))

# ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, test_predictions)
roc_auc = roc_auc_score(y_test, test_predictions)
print(f'AUC Score: {roc_auc:.2f}')

# Precision for class 1 (Positive)
precision = precision_score(y_test, test_predictions)
print(f'Precision: {precision:.2f}')

# Recall for class 1 (Positive)
recall = recall_score(y_test, test_predictions)
print(f'Recall: {recall:.2f}')

# F1 Score
f1 = f1_score(y_test, test_predictions)
print(f'F1 Score: {f1:.2f}')

# Precision-Recall curve and PR AUC
precision, recall, _ = precision_recall_curve(y_test, test_predictions)
pr_auc = auc(recall, precision)
print(f'PR AUC: {pr_auc:.2f}')

# Cohen's Kappa Coefficient
kappa = cohen_kappa_score(y_test, test_predictions)
print(f"Cohen's Kappa Coefficient: {kappa:.2f}")

# Matthews Correlation Coefficient
mcc = matthews_corrcoef(y_test, test_predictions)
print(f"Matthews Correlation Coefficient (MCC): {mcc:.2f}")

# Balanced Accuracy
balanced_accuracy = balanced_accuracy_score(y_test, test_predictions)
print(f"Balanced Accuracy: {balanced_accuracy:.2f}")

# End time
end_time = time.time()

# Print the time taken
print(f"Time taken: {end_time - start_time:.2f} seconds")
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 52, 52, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 26, 26, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 86528)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 512)            │    44,302,848 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 44,396,609 (169.36 MB)
#  Trainable params: 44,396,609 (169.36 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 15s 455ms/step - accuracy: 0.5234 - auc_2: 0.5219 - auc_3: 0.5539 - false_negatives_1: 79.1936 - false_positives_1: 161.8710 - loss: 2.0240 - precision_1: 0.5406 - recall_1: 0.7046 - true_negatives_1: 79.6774 - true_positives_1: 190.2258 - val_accuracy: 0.5083 - val_auc_2: 0.5778 - val_auc_3: 0.5629 - val_false_negatives_1: 118.0000 - val_false_positives_1: 0.0000e+00 - val_loss: 0.6957 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_true_negatives_1: 122.0000 - val_true_positives_1: 0.0000e+00
# Epoch 2/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 14s 450ms/step - accuracy: 0.5010 - auc_2: 0.5342 - auc_3: 0.5139 - false_negatives_1: 173.2581 - false_positives_1: 86.9355 - loss: 0.6988 - precision_1: 0.3523 - recall_1: 0.2272 - true_negatives_1: 166.8387 - true_positives_1: 83.9355 - val_accuracy: 0.5208 - val_auc_2: 0.5063 - val_auc_3: 0.4949 - val_false_negatives_1: 54.0000 - val_false_positives_1: 61.0000 - val_loss: 0.6929 - val_precision_1: 0.5120 - val_recall_1: 0.5424 - val_true_negatives_1: 61.0000 - val_true_positives_1: 64.0000
# Epoch 3/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 13s 448ms/step - accuracy: 0.5623 - auc_2: 0.5312 - auc_3: 0.5451 - false_negatives_1: 87.2903 - false_positives_1: 146.4839 - loss: 0.6929 - precision_1: 0.5708 - recall_1: 0.7191 - true_negatives_1: 99.4839 - true_positives_1: 177.7097 - val_accuracy: 0.5000 - val_auc_2: 0.5099 - val_auc_3: 0.4969 - val_false_negatives_1: 24.0000 - val_false_positives_1: 96.0000 - val_loss: 0.6928 - val_precision_1: 0.4947 - val_recall_1: 0.7966 - val_true_negatives_1: 26.0000 - val_true_positives_1: 94.0000
# Epoch 4/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 13s 448ms/step - accuracy: 0.5374 - auc_2: 0.5403 - auc_3: 0.5362 - false_negatives_1: 48.1290 - false_positives_1: 191.5161 - loss: 0.6912 - precision_1: 0.5350 - recall_1: 0.8279 - true_negatives_1: 58.1290 - true_positives_1: 213.1935 - val_accuracy: 0.4875 - val_auc_2: 0.5019 - val_auc_3: 0.4888 - val_false_negatives_1: 51.0000 - val_false_positives_1: 72.0000 - val_loss: 0.6940 - val_precision_1: 0.4820 - val_recall_1: 0.5678 - val_true_negatives_1: 50.0000 - val_true_positives_1: 67.0000
# Epoch 5/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 14s 454ms/step - accuracy: 0.5160 - auc_2: 0.5390 - auc_3: 0.4937 - false_negatives_1: 97.6452 - false_positives_1: 149.9677 - loss: 0.6865 - precision_1: 0.4949 - recall_1: 0.6058 - true_negatives_1: 111.8387 - true_positives_1: 151.5161 - val_accuracy: 0.5083 - val_auc_2: 0.5164 - val_auc_3: 0.5016 - val_false_negatives_1: 24.0000 - val_false_positives_1: 94.0000 - val_loss: 0.6928 - val_precision_1: 0.5000 - val_recall_1: 0.7966 - val_true_negatives_1: 28.0000 - val_true_positives_1: 94.0000
# Epoch 6/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 13s 448ms/step - accuracy: 0.5373 - auc_2: 0.5463 - auc_3: 0.5105 - false_negatives_1: 36.8064 - false_positives_1: 191.6129 - loss: 0.6911 - precision_1: 0.5155 - recall_1: 0.8609 - true_negatives_1: 62.8387 - true_positives_1: 219.7097 - val_accuracy: 0.5042 - val_auc_2: 0.5154 - val_auc_3: 0.5170 - val_false_negatives_1: 44.0000 - val_false_positives_1: 75.0000 - val_loss: 0.6931 - val_precision_1: 0.4966 - val_recall_1: 0.6271 - val_true_negatives_1: 47.0000 - val_true_positives_1: 74.0000
# Epoch 7/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 13s 448ms/step - accuracy: 0.5546 - auc_2: 0.5708 - auc_3: 0.5404 - false_negatives_1: 76.7742 - false_positives_1: 154.9032 - loss: 0.6858 - precision_1: 0.5349 - recall_1: 0.7073 - true_negatives_1: 103.2903 - true_positives_1: 176.0000 - val_accuracy: 0.5125 - val_auc_2: 0.5306 - val_auc_3: 0.5484 - val_false_negatives_1: 37.0000 - val_false_positives_1: 80.0000 - val_loss: 0.6927 - val_precision_1: 0.5031 - val_recall_1: 0.6864 - val_true_negatives_1: 42.0000 - val_true_positives_1: 81.0000
# Epoch 8/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 13s 449ms/step - accuracy: 0.5512 - auc_2: 0.5415 - auc_3: 0.5479 - false_negatives_1: 40.8064 - false_positives_1: 190.0968 - loss: 0.6889 - precision_1: 0.5469 - recall_1: 0.8341 - true_negatives_1: 60.2258 - true_positives_1: 219.8387 - val_accuracy: 0.5125 - val_auc_2: 0.5086 - val_auc_3: 0.5209 - val_false_negatives_1: 45.0000 - val_false_positives_1: 72.0000 - val_loss: 0.7010 - val_precision_1: 0.5034 - val_recall_1: 0.6186 - val_true_negatives_1: 50.0000 - val_true_positives_1: 73.0000
# Epoch 9/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 13s 447ms/step - accuracy: 0.5385 - auc_2: 0.5373 - auc_3: 0.5786 - false_negatives_1: 65.9677 - false_positives_1: 164.5806 - loss: 0.6953 - precision_1: 0.5537 - recall_1: 0.7269 - true_negatives_1: 81.3226 - true_positives_1: 199.0968 - val_accuracy: 0.4917 - val_auc_2: 0.5320 - val_auc_3: 0.5453 - val_false_negatives_1: 12.0000 - val_false_positives_1: 110.0000 - val_loss: 0.7013 - val_precision_1: 0.4907 - val_recall_1: 0.8983 - val_true_negatives_1: 12.0000 - val_true_positives_1: 106.0000
# Epoch 10/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 13s 448ms/step - accuracy: 0.5179 - auc_2: 0.5623 - auc_3: 0.5388 - false_negatives_1: 76.3548 - false_positives_1: 165.0968 - loss: 0.6835 - precision_1: 0.5079 - recall_1: 0.7052 - true_negatives_1: 93.7097 - true_positives_1: 175.8065 - val_accuracy: 0.4875 - val_auc_2: 0.5433 - val_auc_3: 0.5368 - val_false_negatives_1: 10.0000 - val_false_positives_1: 113.0000 - val_loss: 0.7057 - val_precision_1: 0.4887 - val_recall_1: 0.9153 - val_true_negatives_1: 9.0000 - val_true_positives_1: 108.0000
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 7.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.4696 - auc_2: 0.5003 - auc_3: 0.4912 - false_negatives_1: 23.4444 - false_positives_1: 55.2222 - loss: 0.6942 - precision_1: 0.4336 - recall_1: 0.6539 - true_negatives_1: 27.2222 - true_positives_1: 47.0000
# Test Accuracy: 51.25%
# Precision: 0.50
# Recall: 0.69
# AUC-ROC: 0.53
# AUC-PR: 0.55
# TN: 42.0, FP: 80.0, FN: 37.0, TP: 81.0
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step
# Confusion Matrix:
# [[42 80]
#  [37 81]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.53      0.34      0.42       122
#            1       0.50      0.69      0.58       118
#
#     accuracy                           0.51       240
#    macro avg       0.52      0.52      0.50       240
# weighted avg       0.52      0.51      0.50       240
#
# AUC Score: 0.52
# Precision: 0.50
# Recall: 0.69
# F1 Score: 0.58
# PR AUC: 0.67
# Cohen's Kappa Coefficient: 0.03
# Matthews Correlation Coefficient (MCC): 0.03
# Balanced Accuracy: 0.52
# Time taken: 138.08 seconds

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_recall_curve, auc, precision_score, recall_score, f1_score, balanced_accuracy_score, cohen_kappa_score, matthews_corrcoef
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
import time
from tensorflow.keras.callbacks import EarlyStopping

# Start time
start_time = time.time()

# Assume X_train and y_train are the original splits

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension
X_train_resized = np.repeat(X_train_resized, 3, axis=-1)  # Repeat the channel dimension to match the expected input shape of the CNN

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)
X_test_resized = np.repeat(X_test_resized, 3, axis=-1)

# Define CNN architecture
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(512, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compile the model with Adam optimizer and additional metrics
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      tf.keras.metrics.TrueNegatives(),
                                                                      tf.keras.metrics.FalsePositives(),
                                                                      tf.keras.metrics.FalseNegatives(),
                                                                      tf.keras.metrics.TruePositives()])

# Display model summary
model.summary()

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model with early stopping and 50 epochs
history = model.fit(X_train_resized, y_train, epochs=200, validation_data=(X_test_resized, y_test), callbacks=[early_stopping])

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
test_loss, test_accuracy, precision, recall, auc_roc, auc_pr, tn, fp, fn, tp = model.evaluate(X_test_resized, y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
print(f'AUC-ROC: {auc_roc:.2f}')
print(f'AUC-PR: {auc_pr:.2f}')
print(f'TN: {tn}, FP: {fp}, FN: {fn}, TP: {tp}')

# Confusion matrix
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
print("Confusion Matrix:")
print(conf_matrix)

# Generate classification report
print("Classification Report:")
print(classification_report(y_test, test_predictions))

# ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, test_predictions)
roc_auc = roc_auc_score(y_test, test_predictions)
print(f'AUC Score: {roc_auc:.2f}')

# Precision for class 1 (Positive)
precision = precision_score(y_test, test_predictions)
print(f'Precision: {precision:.2f}')

# Recall for class 1 (Positive)
recall = recall_score(y_test, test_predictions)
print(f'Recall: {recall:.2f}')

# F1 Score
f1 = f1_score(y_test, test_predictions)
print(f'F1 Score: {f1:.2f}')

# Precision-Recall curve and PR AUC
precision, recall, _ = precision_recall_curve(y_test, test_predictions)
pr_auc = auc(recall, precision)
print(f'PR AUC: {pr_auc:.2f}')

# Cohen's Kappa Coefficient
kappa = cohen_kappa_score(y_test, test_predictions)
print(f"Cohen's Kappa Coefficient: {kappa:.2f}")

# Matthews Correlation Coefficient
mcc = matthews_corrcoef(y_test, test_predictions)
print(f"Matthews Correlation Coefficient (MCC): {mcc:.2f}")

# Balanced Accuracy
balanced_accuracy = balanced_accuracy_score(y_test, test_predictions)
print(f"Balanced Accuracy: {balanced_accuracy:.2f}")

# End time
end_time = time.time()

# Print the time taken
print(f"Time taken: {end_time - start_time:.2f} seconds")
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)               │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 52, 52, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 26, 26, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 86528)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 512)            │    44,302,848 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 44,396,609 (169.36 MB)
#  Trainable params: 44,396,609 (169.36 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 15s 462ms/step - accuracy: 0.4986 - auc_4: 0.5085 - auc_5: 0.5136 - false_negatives_2: 134.1613 - false_positives_2: 125.0968 - loss: 1.3703 - precision_2: 0.5217 - recall_2: 0.4461 - true_negatives_2: 129.2258 - true_positives_2: 122.4839 - val_accuracy: 0.4958 - val_auc_4: 0.5595 - val_auc_5: 0.5693 - val_false_negatives_2: 0.0000e+00 - val_false_positives_2: 121.0000 - val_loss: 0.6934 - val_precision_2: 0.4937 - val_recall_2: 1.0000 - val_true_negatives_2: 1.0000 - val_true_positives_2: 118.0000
# Epoch 2/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 13s 448ms/step - accuracy: 0.5238 - auc_4: 0.5215 - auc_5: 0.5299 - false_negatives_2: 75.0968 - false_positives_2: 166.6129 - loss: 0.6921 - precision_2: 0.5187 - recall_2: 0.7191 - true_negatives_2: 86.9032 - true_positives_2: 182.3548 - val_accuracy: 0.5083 - val_auc_4: 0.5487 - val_auc_5: 0.5291 - val_false_negatives_2: 118.0000 - val_false_positives_2: 0.0000e+00 - val_loss: 0.6927 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_true_negatives_2: 122.0000 - val_true_positives_2: 0.0000e+00
# Epoch 3/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 13s 446ms/step - accuracy: 0.5340 - auc_4: 0.5567 - auc_5: 0.5652 - false_negatives_2: 104.8387 - false_positives_2: 132.0645 - loss: 0.6885 - precision_2: 0.4921 - recall_2: 0.5256 - true_negatives_2: 119.4516 - true_positives_2: 154.6129 - val_accuracy: 0.4917 - val_auc_4: 0.5072 - val_auc_5: 0.5010 - val_false_negatives_2: 13.0000 - val_false_positives_2: 109.0000 - val_loss: 0.7004 - val_precision_2: 0.4907 - val_recall_2: 0.8898 - val_true_negatives_2: 13.0000 - val_true_positives_2: 105.0000
# Epoch 4/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 13s 445ms/step - accuracy: 0.5405 - auc_4: 0.5711 - auc_5: 0.5474 - false_negatives_2: 135.8387 - false_positives_2: 95.0645 - loss: 0.6901 - precision_2: 0.5245 - recall_2: 0.4430 - true_negatives_2: 166.1290 - true_positives_2: 113.9355 - val_accuracy: 0.5083 - val_auc_4: 0.4853 - val_auc_5: 0.4803 - val_false_negatives_2: 33.0000 - val_false_positives_2: 85.0000 - val_loss: 0.6940 - val_precision_2: 0.5000 - val_recall_2: 0.7203 - val_true_negatives_2: 37.0000 - val_true_positives_2: 85.0000
# Epoch 5/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 13s 446ms/step - accuracy: 0.5454 - auc_4: 0.5443 - auc_5: 0.5342 - false_negatives_2: 56.9032 - false_positives_2: 175.8710 - loss: 0.6903 - precision_2: 0.5328 - recall_2: 0.7742 - true_negatives_2: 77.7419 - true_positives_2: 200.4516 - val_accuracy: 0.4958 - val_auc_4: 0.4892 - val_auc_5: 0.4836 - val_false_negatives_2: 40.0000 - val_false_positives_2: 81.0000 - val_loss: 0.6967 - val_precision_2: 0.4906 - val_recall_2: 0.6610 - val_true_negatives_2: 41.0000 - val_true_positives_2: 78.0000
# Epoch 5: early stopping
# Restoring model weights from the end of the best epoch: 2.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.5577 - auc_4: 0.5190 - auc_5: 0.4511 - false_negatives_2: 70.4444 - false_positives_2: 0.0000e+00 - loss: 0.6880 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - true_negatives_2: 82.4444 - true_positives_2: 0.0000e+00
# Test Accuracy: 50.83%
# Precision: 0.00
# Recall: 0.00
# AUC-ROC: 0.55
# AUC-PR: 0.53
# TN: 122.0, FP: 0.0, FN: 118.0, TP: 0.0
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7e39fafc43a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step
# Confusion Matrix:
# [[122   0]
#  [118   0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.51      1.00      0.67       122
#            1       0.00      0.00      0.00       118
#
#     accuracy                           0.51       240
#    macro avg       0.25      0.50      0.34       240
# weighted avg       0.26      0.51      0.34       240
#
# AUC Score: 0.50
# Precision: 0.00
# Recall: 0.00
# F1 Score: 0.00
# PR AUC: 0.75
# Cohen's Kappa Coefficient: 0.00
# Matthews Correlation Coefficient (MCC): 0.00
# Balanced Accuracy: 0.50
# Time taken: 70.60 seconds

# %% [markdown]
# # Dropout + Dense Layers

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_recall_curve, auc, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import matplotlib.pyplot as plt
import cv2
import time
from tensorflow.keras.callbacks import EarlyStopping

# Start time
start_time = time.time()

# Assume X_train and y_train are the original splits

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)

# Define CNN architecture
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dropout(0.5),  # Dropout layer to prevent overfitting
    Dense(512, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compile the model with Adam optimizer and additional metrics
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      tf.keras.metrics.TrueNegatives(),
                                                                      tf.keras.metrics.FalsePositives(),
                                                                      tf.keras.metrics.FalseNegatives(),
                                                                      tf.keras.metrics.TruePositives()])

# Display model summary
model.summary()

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model with early stopping and 50 epochs
history = model.fit(X_train_resized, y_train, epochs=50, validation_data=(X_test_resized, y_test), callbacks=[early_stopping])

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
test_loss, test_accuracy, precision, recall, auc_roc, auc_pr, tn, fp, fn, tp = model.evaluate(X_test_resized, y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
print(f'AUC-ROC: {auc_roc:.2f}')
print(f'AUC-PR: {auc_pr:.2f}')
print(f'TN: {tn}, FP: {fp}, FN: {fn}, TP: {tp}')

# Confusion matrix
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
print("Confusion Matrix:")
print(conf_matrix)

# Generate classification report
print("Classification Report:")
print(classification_report(y_test, test_predictions))

# ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, test_predictions)
roc_auc = roc_auc_score(y_test, test_predictions)
print(f'AUC Score: {roc_auc:.2f}')

# Calculate Precision for class 1 (Positive)
precision = precision_score(y_test, test_predictions)
print(f'Precision: {precision:.2f}')

# Calculate Recall for class 1 (Positive)
recall = recall_score(y_test, test_predictions)
print(f'Recall: {recall:.2f}')

# Calculate F1 Score
f1 = f1_score(y_test, test_predictions)
print(f'F1 Score: {f1:.2f}')

# Calculate Precision-Recall curve
precision, recall, _ = precision_recall_curve(y_test, test_predictions)
pr_auc = auc(recall, precision)
print(f'PR AUC: {pr_auc:.2f}')

# Calculate Cohen's Kappa Coefficient
kappa = cohen_kappa_score(y_test, test_predictions)
print(f"Cohen's Kappa Coefficient: {kappa:.2f}")

# Calculate Matthews Correlation Coefficient
mcc = matthews_corrcoef(y_test, test_predictions)
print(f"Matthews Correlation Coefficient (MCC): {mcc:.2f}")

# Calculate Balanced Accuracy
balanced_acc = balanced_accuracy_score(y_test, test_predictions)
print(f"Balanced Accuracy: {balanced_acc:.2f}")

# End time
end_time = time.time()

# Print the time taken
print(f"Time taken: {end_time - start_time:.2f} seconds")
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_9 (Conv2D)               │ (None, 222, 222, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 52, 52, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 26, 26, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 86528)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 86528)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 512)            │    44,302,848 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 44,396,033 (169.36 MB)
#  Trainable params: 44,396,033 (169.36 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 15s 466ms/step - accuracy: 0.5220 - auc_6: 0.5345 - auc_7: 0.5218 - false_negatives_3: 147.1290 - false_positives_3: 100.9032 - loss: 1.1940 - precision_3: 0.5300 - recall_3: 0.4365 - true_negatives_3: 156.0323 - true_positives_3: 106.9032 - val_accuracy: 0.4917 - val_auc_6: 0.5414 - val_auc_7: 0.5394 - val_false_negatives_3: 0.0000e+00 - val_false_positives_3: 122.0000 - val_loss: 0.6939 - val_precision_3: 0.4917 - val_recall_3: 1.0000 - val_true_negatives_3: 0.0000e+00 - val_true_positives_3: 118.0000
# Epoch 2/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 14s 451ms/step - accuracy: 0.4773 - auc_6: 0.4764 - auc_7: 0.4623 - false_negatives_3: 112.3226 - false_positives_3: 153.1935 - loss: 0.6950 - precision_3: 0.4729 - recall_3: 0.6277 - true_negatives_3: 104.6774 - true_positives_3: 140.7742 - val_accuracy: 0.5083 - val_auc_6: 0.6024 - val_auc_7: 0.5842 - val_false_negatives_3: 118.0000 - val_false_positives_3: 0.0000e+00 - val_loss: 0.6927 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00 - val_true_negatives_3: 122.0000 - val_true_positives_3: 0.0000e+00
# Epoch 3/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 14s 451ms/step - accuracy: 0.4940 - auc_6: 0.4819 - auc_7: 0.5191 - false_negatives_3: 208.0645 - false_positives_3: 45.5806 - loss: 0.6971 - precision_3: 0.5211 - recall_3: 0.2260 - true_negatives_3: 204.5806 - true_positives_3: 52.7419 - val_accuracy: 0.5083 - val_auc_6: 0.6074 - val_auc_7: 0.5989 - val_false_negatives_3: 118.0000 - val_false_positives_3: 0.0000e+00 - val_loss: 0.6909 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00 - val_true_negatives_3: 122.0000 - val_true_positives_3: 0.0000e+00
# Epoch 4/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 14s 450ms/step - accuracy: 0.5502 - auc_6: 0.5656 - auc_7: 0.5440 - false_negatives_3: 151.1935 - false_positives_3: 76.3871 - loss: 0.6910 - precision_3: 0.5692 - recall_3: 0.4002 - true_negatives_3: 181.3226 - true_positives_3: 102.0645 - val_accuracy: 0.5125 - val_auc_6: 0.5966 - val_auc_7: 0.6136 - val_false_negatives_3: 2.0000 - val_false_positives_3: 115.0000 - val_loss: 0.6927 - val_precision_3: 0.5022 - val_recall_3: 0.9831 - val_true_negatives_3: 7.0000 - val_true_positives_3: 116.0000
# Epoch 5/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 14s 452ms/step - accuracy: 0.5568 - auc_6: 0.5686 - auc_7: 0.5718 - false_negatives_3: 96.0645 - false_positives_3: 131.6452 - loss: 0.6858 - precision_3: 0.5531 - recall_3: 0.6843 - true_negatives_3: 119.8710 - true_positives_3: 163.3871 - val_accuracy: 0.6167 - val_auc_6: 0.6531 - val_auc_7: 0.6931 - val_false_negatives_3: 86.0000 - val_false_positives_3: 6.0000 - val_loss: 0.6728 - val_precision_3: 0.8421 - val_recall_3: 0.2712 - val_true_negatives_3: 116.0000 - val_true_positives_3: 32.0000
# Epoch 6/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 13s 450ms/step - accuracy: 0.6218 - auc_6: 0.6771 - auc_7: 0.6844 - false_negatives_3: 95.7419 - false_positives_3: 95.2903 - loss: 0.6523 - precision_3: 0.6421 - recall_3: 0.6095 - true_negatives_3: 159.0968 - true_positives_3: 160.8387 - val_accuracy: 0.6542 - val_auc_6: 0.7286 - val_auc_7: 0.7452 - val_false_negatives_3: 30.0000 - val_false_positives_3: 53.0000 - val_loss: 0.6261 - val_precision_3: 0.6241 - val_recall_3: 0.7458 - val_true_negatives_3: 69.0000 - val_true_positives_3: 88.0000
# Epoch 7/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 13s 449ms/step - accuracy: 0.6089 - auc_6: 0.6673 - auc_7: 0.6770 - false_negatives_3: 108.9032 - false_positives_3: 94.7097 - loss: 0.6513 - precision_3: 0.6065 - recall_3: 0.6238 - true_negatives_3: 162.2903 - true_positives_3: 145.0645 - val_accuracy: 0.6125 - val_auc_6: 0.6949 - val_auc_7: 0.7250 - val_false_negatives_3: 28.0000 - val_false_positives_3: 65.0000 - val_loss: 0.6359 - val_precision_3: 0.5806 - val_recall_3: 0.7627 - val_true_negatives_3: 57.0000 - val_true_positives_3: 90.0000
# Epoch 8/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 13s 448ms/step - accuracy: 0.6645 - auc_6: 0.6959 - auc_7: 0.6985 - false_negatives_3: 91.1936 - false_positives_3: 81.0323 - loss: 0.6281 - precision_3: 0.6622 - recall_3: 0.6561 - true_negatives_3: 178.0645 - true_positives_3: 160.6774 - val_accuracy: 0.6417 - val_auc_6: 0.7299 - val_auc_7: 0.7604 - val_false_negatives_3: 20.0000 - val_false_positives_3: 66.0000 - val_loss: 0.6446 - val_precision_3: 0.5976 - val_recall_3: 0.8305 - val_true_negatives_3: 56.0000 - val_true_positives_3: 98.0000
# Epoch 9/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 13s 450ms/step - accuracy: 0.6712 - auc_6: 0.7391 - auc_7: 0.7494 - false_negatives_3: 103.8064 - false_positives_3: 61.6129 - loss: 0.6038 - precision_3: 0.7133 - recall_3: 0.5974 - true_negatives_3: 192.1935 - true_positives_3: 153.3548 - val_accuracy: 0.6083 - val_auc_6: 0.7344 - val_auc_7: 0.7548 - val_false_negatives_3: 16.0000 - val_false_positives_3: 78.0000 - val_loss: 0.6760 - val_precision_3: 0.5667 - val_recall_3: 0.8644 - val_true_negatives_3: 44.0000 - val_true_positives_3: 102.0000
# Epoch 9: early stopping
# Restoring model weights from the end of the best epoch: 6.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.6486 - auc_6: 0.7475 - auc_7: 0.7155 - false_negatives_3: 17.2222 - false_positives_3: 36.7778 - loss: 0.6269 - precision_3: 0.5770 - recall_3: 0.7723 - true_negatives_3: 45.6667 - true_positives_3: 53.2222
# Test Accuracy: 65.42%
# Precision: 0.62
# Recall: 0.75
# AUC-ROC: 0.73
# AUC-PR: 0.75
# TN: 69.0, FP: 53.0, FN: 30.0, TP: 88.0
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7e39d31bc8b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step
# Confusion Matrix:
# [[69 53]
#  [30 88]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.70      0.57      0.62       122
#            1       0.62      0.75      0.68       118
#
#     accuracy                           0.65       240
#    macro avg       0.66      0.66      0.65       240
# weighted avg       0.66      0.65      0.65       240
#
# AUC Score: 0.66
# Precision: 0.62
# Recall: 0.75
# F1 Score: 0.68
# PR AUC: 0.75
# Cohen's Kappa Coefficient: 0.31
# Matthews Correlation Coefficient (MCC): 0.32
# Balanced Accuracy: 0.66
# Time taken: 124.56 seconds

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_recall_curve, auc, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import matplotlib.pyplot as plt
import cv2
import time
from tensorflow.keras.callbacks import EarlyStopping

# Start time
start_time = time.time()

# Assume X_train and y_train are the original splits

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)

# Define CNN architecture
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dropout(0.5),  # Dropout layer to prevent overfitting
    Dense(512, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compile the model with Adam optimizer and additional metrics
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      tf.keras.metrics.TrueNegatives(),
                                                                      tf.keras.metrics.FalsePositives(),
                                                                      tf.keras.metrics.FalseNegatives(),
                                                                      tf.keras.metrics.TruePositives()])

# Display model summary
model.summary()

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model with early stopping and 50 epochs
history = model.fit(X_train_resized, y_train, epochs=150, validation_data=(X_test_resized, y_test), callbacks=[early_stopping])

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
test_loss, test_accuracy, precision, recall, auc_roc, auc_pr, tn, fp, fn, tp = model.evaluate(X_test_resized, y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
print(f'AUC-ROC: {auc_roc:.2f}')
print(f'AUC-PR: {auc_pr:.2f}')
print(f'TN: {tn}, FP: {fp}, FN: {fn}, TP: {tp}')

# Confusion matrix
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
print("Confusion Matrix:")
print(conf_matrix)

# Generate classification report
print("Classification Report:")
print(classification_report(y_test, test_predictions))

# ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, test_predictions)
roc_auc = roc_auc_score(y_test, test_predictions)
print(f'AUC Score: {roc_auc:.2f}')

# Calculate Precision for class 1 (Positive)
precision = precision_score(y_test, test_predictions)
print(f'Precision: {precision:.2f}')

# Calculate Recall for class 1 (Positive)
recall = recall_score(y_test, test_predictions)
print(f'Recall: {recall:.2f}')

# Calculate F1 Score
f1 = f1_score(y_test, test_predictions)
print(f'F1 Score: {f1:.2f}')

# Calculate Precision-Recall curve
precision, recall, _ = precision_recall_curve(y_test, test_predictions)
pr_auc = auc(recall, precision)
print(f'PR AUC: {pr_auc:.2f}')

# Calculate Cohen's Kappa Coefficient
kappa = cohen_kappa_score(y_test, test_predictions)
print(f"Cohen's Kappa Coefficient: {kappa:.2f}")

# Calculate Matthews Correlation Coefficient
mcc = matthews_corrcoef(y_test, test_predictions)
print(f"Matthews Correlation Coefficient (MCC): {mcc:.2f}")

# Calculate Balanced Accuracy
balanced_acc = balanced_accuracy_score(y_test, test_predictions)
print(f"Balanced Accuracy: {balanced_acc:.2f}")

# End time
end_time = time.time()

# Print the time taken
print(f"Time taken: {end_time - start_time:.2f} seconds")
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_12 (Conv2D)              │ (None, 222, 222, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_12 (MaxPooling2D) │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_13 (MaxPooling2D) │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 52, 52, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_14 (MaxPooling2D) │ (None, 26, 26, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 86528)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 86528)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 512)            │    44,302,848 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 44,396,033 (169.36 MB)
#  Trainable params: 44,396,033 (169.36 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 15s 462ms/step - accuracy: 0.5071 - auc_8: 0.4944 - auc_9: 0.4893 - false_negatives_4: 93.3226 - false_positives_4: 163.9677 - loss: 1.4932 - precision_4: 0.5042 - recall_4: 0.6499 - true_negatives_4: 91.0323 - true_positives_4: 162.6452 - val_accuracy: 0.4917 - val_auc_8: 0.4196 - val_auc_9: 0.4522 - val_false_negatives_4: 0.0000e+00 - val_false_positives_4: 122.0000 - val_loss: 0.6944 - val_precision_4: 0.4917 - val_recall_4: 1.0000 - val_true_negatives_4: 0.0000e+00 - val_true_positives_4: 118.0000
# Epoch 2/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 14s 451ms/step - accuracy: 0.4754 - auc_8: 0.5143 - auc_9: 0.4894 - false_negatives_4: 229.7742 - false_positives_4: 34.5484 - loss: 0.6939 - precision_4: 0.4409 - recall_4: 0.2088 - true_negatives_4: 219.2258 - true_positives_4: 27.4194 - val_accuracy: 0.5083 - val_auc_8: 0.6549 - val_auc_9: 0.6415 - val_false_negatives_4: 118.0000 - val_false_positives_4: 0.0000e+00 - val_loss: 0.6907 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_true_negatives_4: 122.0000 - val_true_positives_4: 0.0000e+00
# Epoch 3/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 14s 462ms/step - accuracy: 0.4918 - auc_8: 0.6381 - auc_9: 0.6547 - false_negatives_4: 255.5161 - false_positives_4: 0.0000e+00 - loss: 0.6924 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - true_negatives_4: 255.4516 - true_positives_4: 0.0000e+00 - val_accuracy: 0.5083 - val_auc_8: 0.6698 - val_auc_9: 0.6504 - val_false_negatives_4: 118.0000 - val_false_positives_4: 0.0000e+00 - val_loss: 0.6909 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_true_negatives_4: 122.0000 - val_true_positives_4: 0.0000e+00
# Epoch 4/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 14s 454ms/step - accuracy: 0.5398 - auc_8: 0.5650 - auc_9: 0.5745 - false_negatives_4: 181.8710 - false_positives_4: 52.5484 - loss: 0.6921 - precision_4: 0.5573 - recall_4: 0.3006 - true_negatives_4: 197.5484 - true_positives_4: 79.0000 - val_accuracy: 0.5083 - val_auc_8: 0.7071 - val_auc_9: 0.7127 - val_false_negatives_4: 118.0000 - val_false_positives_4: 0.0000e+00 - val_loss: 0.6883 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_true_negatives_4: 122.0000 - val_true_positives_4: 0.0000e+00
# Epoch 5/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 14s 453ms/step - accuracy: 0.5190 - auc_8: 0.5917 - auc_9: 0.5816 - false_negatives_4: 198.2581 - false_positives_4: 47.3548 - loss: 0.6892 - precision_4: 0.4685 - recall_4: 0.1916 - true_negatives_4: 208.4839 - true_positives_4: 56.8710 - val_accuracy: 0.6542 - val_auc_8: 0.7318 - val_auc_9: 0.7551 - val_false_negatives_4: 76.0000 - val_false_positives_4: 7.0000 - val_loss: 0.6776 - val_precision_4: 0.8571 - val_recall_4: 0.3559 - val_true_negatives_4: 115.0000 - val_true_positives_4: 42.0000
# Epoch 6/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 13s 449ms/step - accuracy: 0.5882 - auc_8: 0.6198 - auc_9: 0.6014 - false_negatives_4: 154.4194 - false_positives_4: 62.5484 - loss: 0.6779 - precision_4: 0.6152 - recall_4: 0.3629 - true_negatives_4: 200.0000 - true_positives_4: 94.0000 - val_accuracy: 0.5250 - val_auc_8: 0.6011 - val_auc_9: 0.6071 - val_false_negatives_4: 35.0000 - val_false_positives_4: 79.0000 - val_loss: 0.6898 - val_precision_4: 0.5123 - val_recall_4: 0.7034 - val_true_negatives_4: 43.0000 - val_true_positives_4: 83.0000
# Epoch 7/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 14s 459ms/step - accuracy: 0.5593 - auc_8: 0.5659 - auc_9: 0.5823 - false_negatives_4: 124.0323 - false_positives_4: 106.5484 - loss: 0.6892 - precision_4: 0.5659 - recall_4: 0.5824 - true_negatives_4: 147.4194 - true_positives_4: 132.9677 - val_accuracy: 0.5708 - val_auc_8: 0.6589 - val_auc_9: 0.6754 - val_false_negatives_4: 99.0000 - val_false_positives_4: 4.0000 - val_loss: 0.6839 - val_precision_4: 0.8261 - val_recall_4: 0.1610 - val_true_negatives_4: 118.0000 - val_true_positives_4: 19.0000
# Epoch 8/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 14s 461ms/step - accuracy: 0.5380 - auc_8: 0.5910 - auc_9: 0.6043 - false_negatives_4: 166.7097 - false_positives_4: 68.7742 - loss: 0.6890 - precision_4: 0.7204 - recall_4: 0.2561 - true_negatives_4: 186.5806 - true_positives_4: 88.9032 - val_accuracy: 0.5833 - val_auc_8: 0.6613 - val_auc_9: 0.6793 - val_false_negatives_4: 88.0000 - val_false_positives_4: 12.0000 - val_loss: 0.6775 - val_precision_4: 0.7143 - val_recall_4: 0.2542 - val_true_negatives_4: 110.0000 - val_true_positives_4: 30.0000
# Epoch 9/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 14s 450ms/step - accuracy: 0.6040 - auc_8: 0.6254 - auc_9: 0.6135 - false_negatives_4: 141.2903 - false_positives_4: 68.5806 - loss: 0.6814 - precision_4: 0.6824 - recall_4: 0.4200 - true_negatives_4: 186.7742 - true_positives_4: 114.3226 - val_accuracy: 0.6083 - val_auc_8: 0.6708 - val_auc_9: 0.6861 - val_false_negatives_4: 72.0000 - val_false_positives_4: 22.0000 - val_loss: 0.6696 - val_precision_4: 0.6765 - val_recall_4: 0.3898 - val_true_negatives_4: 100.0000 - val_true_positives_4: 46.0000
# Epoch 10/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 14s 454ms/step - accuracy: 0.6344 - auc_8: 0.6821 - auc_9: 0.6964 - false_negatives_4: 132.2258 - false_positives_4: 57.0968 - loss: 0.6648 - precision_4: 0.7198 - recall_4: 0.4741 - true_negatives_4: 197.5806 - true_positives_4: 124.0645 - val_accuracy: 0.5833 - val_auc_8: 0.6895 - val_auc_9: 0.7115 - val_false_negatives_4: 99.0000 - val_false_positives_4: 1.0000 - val_loss: 0.6852 - val_precision_4: 0.9500 - val_recall_4: 0.1610 - val_true_negatives_4: 121.0000 - val_true_positives_4: 19.0000
# Epoch 11/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 14s 452ms/step - accuracy: 0.5877 - auc_8: 0.6337 - auc_9: 0.6223 - false_negatives_4: 105.5161 - false_positives_4: 112.0000 - loss: 0.6647 - precision_4: 0.6340 - recall_4: 0.4545 - true_negatives_4: 148.3226 - true_positives_4: 145.1290 - val_accuracy: 0.6417 - val_auc_8: 0.7004 - val_auc_9: 0.7263 - val_false_negatives_4: 41.0000 - val_false_positives_4: 45.0000 - val_loss: 0.6460 - val_precision_4: 0.6311 - val_recall_4: 0.6525 - val_true_negatives_4: 77.0000 - val_true_positives_4: 77.0000
# Epoch 12/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 14s 451ms/step - accuracy: 0.6242 - auc_8: 0.6769 - auc_9: 0.7110 - false_negatives_4: 132.3226 - false_positives_4: 62.5161 - loss: 0.6405 - precision_4: 0.6714 - recall_4: 0.5087 - true_negatives_4: 191.3871 - true_positives_4: 124.7419 - val_accuracy: 0.6083 - val_auc_8: 0.6530 - val_auc_9: 0.6378 - val_false_negatives_4: 32.0000 - val_false_positives_4: 62.0000 - val_loss: 0.6662 - val_precision_4: 0.5811 - val_recall_4: 0.7288 - val_true_negatives_4: 60.0000 - val_true_positives_4: 86.0000
# Epoch 13/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 14s 453ms/step - accuracy: 0.6523 - auc_8: 0.6952 - auc_9: 0.7342 - false_negatives_4: 110.6774 - false_positives_4: 72.5484 - loss: 0.6298 - precision_4: 0.6766 - recall_4: 0.6388 - true_negatives_4: 176.8387 - true_positives_4: 150.9032 - val_accuracy: 0.4792 - val_auc_8: 0.6306 - val_auc_9: 0.6777 - val_false_negatives_4: 3.0000 - val_false_positives_4: 122.0000 - val_loss: 0.6864 - val_precision_4: 0.4852 - val_recall_4: 0.9746 - val_true_negatives_4: 0.0000e+00 - val_true_positives_4: 115.0000
# Epoch 14/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 14s 451ms/step - accuracy: 0.5557 - auc_8: 0.6705 - auc_9: 0.7028 - false_negatives_4: 62.1613 - false_positives_4: 151.8387 - loss: 0.6515 - precision_4: 0.5399 - recall_4: 0.8190 - true_negatives_4: 105.7097 - true_positives_4: 191.2581 - val_accuracy: 0.6500 - val_auc_8: 0.7055 - val_auc_9: 0.7417 - val_false_negatives_4: 41.0000 - val_false_positives_4: 43.0000 - val_loss: 0.6108 - val_precision_4: 0.6417 - val_recall_4: 0.6525 - val_true_negatives_4: 79.0000 - val_true_positives_4: 77.0000
# Epoch 15/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 14s 450ms/step - accuracy: 0.6282 - auc_8: 0.6685 - auc_9: 0.7176 - false_negatives_4: 111.8387 - false_positives_4: 80.4194 - loss: 0.6319 - precision_4: 0.6580 - recall_4: 0.5679 - true_negatives_4: 171.0000 - true_positives_4: 147.7097 - val_accuracy: 0.6375 - val_auc_8: 0.6843 - val_auc_9: 0.7164 - val_false_negatives_4: 65.0000 - val_false_positives_4: 22.0000 - val_loss: 0.6309 - val_precision_4: 0.7067 - val_recall_4: 0.4492 - val_true_negatives_4: 100.0000 - val_true_positives_4: 53.0000
# Epoch 16/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 14s 451ms/step - accuracy: 0.6398 - auc_8: 0.6886 - auc_9: 0.7295 - false_negatives_4: 129.8065 - false_positives_4: 45.3548 - loss: 0.6205 - precision_4: 0.7245 - recall_4: 0.4542 - true_negatives_4: 204.5806 - true_positives_4: 131.2258 - val_accuracy: 0.6042 - val_auc_8: 0.6694 - val_auc_9: 0.6759 - val_false_negatives_4: 69.0000 - val_false_positives_4: 26.0000 - val_loss: 0.6474 - val_precision_4: 0.6533 - val_recall_4: 0.4153 - val_true_negatives_4: 96.0000 - val_true_positives_4: 49.0000
# Epoch 17/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 13s 450ms/step - accuracy: 0.6643 - auc_8: 0.7227 - auc_9: 0.7680 - false_negatives_4: 113.7742 - false_positives_4: 55.1290 - loss: 0.6032 - precision_4: 0.7399 - recall_4: 0.5508 - true_negatives_4: 195.8387 - true_positives_4: 146.2258 - val_accuracy: 0.6333 - val_auc_8: 0.7025 - val_auc_9: 0.7366 - val_false_negatives_4: 51.0000 - val_false_positives_4: 37.0000 - val_loss: 0.6169 - val_precision_4: 0.6442 - val_recall_4: 0.5678 - val_true_negatives_4: 85.0000 - val_true_positives_4: 67.0000
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 14.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.6612 - auc_8: 0.7311 - auc_9: 0.7169 - false_negatives_4: 23.4444 - false_positives_4: 28.8889 - loss: 0.6093 - precision_4: 0.6047 - recall_4: 0.6703 - true_negatives_4: 53.5556 - true_positives_4: 47.0000
# Test Accuracy: 65.00%
# Precision: 0.64
# Recall: 0.65
# AUC-ROC: 0.71
# AUC-PR: 0.74
# TN: 79.0, FP: 43.0, FN: 41.0, TP: 77.0
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step
# Confusion Matrix:
# [[79 43]
#  [41 77]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.66      0.65      0.65       122
#            1       0.64      0.65      0.65       118
#
#     accuracy                           0.65       240
#    macro avg       0.65      0.65      0.65       240
# weighted avg       0.65      0.65      0.65       240
#
# AUC Score: 0.65
# Precision: 0.64
# Recall: 0.65
# F1 Score: 0.65
# PR AUC: 0.73
# Cohen's Kappa Coefficient: 0.30
# Matthews Correlation Coefficient (MCC): 0.30
# Balanced Accuracy: 0.65
# Time taken: 234.03 seconds

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_recall_curve, auc, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import matplotlib.pyplot as plt
import cv2
import time
from tensorflow.keras.callbacks import EarlyStopping

# Start time
start_time = time.time()

# Assume X_train and y_train are the original splits

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)

# Define CNN architecture
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dropout(0.5),  # Dropout layer to prevent overfitting
    Dense(512, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compile the model with Adam optimizer and additional metrics
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      tf.keras.metrics.TrueNegatives(),
                                                                      tf.keras.metrics.FalsePositives(),
                                                                      tf.keras.metrics.FalseNegatives(),
                                                                      tf.keras.metrics.TruePositives()])

# Display model summary
model.summary()

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model with early stopping and 50 epochs
history = model.fit(X_train_resized, y_train, epochs=200, validation_data=(X_test_resized, y_test), callbacks=[early_stopping])

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
test_loss, test_accuracy, precision, recall, auc_roc, auc_pr, tn, fp, fn, tp = model.evaluate(X_test_resized, y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
print(f'AUC-ROC: {auc_roc:.2f}')
print(f'AUC-PR: {auc_pr:.2f}')
print(f'TN: {tn}, FP: {fp}, FN: {fn}, TP: {tp}')

# Confusion matrix
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
print("Confusion Matrix:")
print(conf_matrix)

# Generate classification report
print("Classification Report:")
print(classification_report(y_test, test_predictions))

# ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, test_predictions)
roc_auc = roc_auc_score(y_test, test_predictions)
print(f'AUC Score: {roc_auc:.2f}')

# Calculate Precision for class 1 (Positive)
precision = precision_score(y_test, test_predictions)
print(f'Precision: {precision:.2f}')

# Calculate Recall for class 1 (Positive)
recall = recall_score(y_test, test_predictions)
print(f'Recall: {recall:.2f}')

# Calculate F1 Score
f1 = f1_score(y_test, test_predictions)
print(f'F1 Score: {f1:.2f}')

# Calculate Precision-Recall curve
precision, recall, _ = precision_recall_curve(y_test, test_predictions)
pr_auc = auc(recall, precision)
print(f'PR AUC: {pr_auc:.2f}')

# Calculate Cohen's Kappa Coefficient
kappa = cohen_kappa_score(y_test, test_predictions)
print(f"Cohen's Kappa Coefficient: {kappa:.2f}")

# Calculate Matthews Correlation Coefficient
mcc = matthews_corrcoef(y_test, test_predictions)
print(f"Matthews Correlation Coefficient (MCC): {mcc:.2f}")

# Calculate Balanced Accuracy
balanced_acc = balanced_accuracy_score(y_test, test_predictions)
print(f"Balanced Accuracy: {balanced_acc:.2f}")

# End time
end_time = time.time()

# Print the time taken
print(f"Time taken: {end_time - start_time:.2f} seconds")
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_15 (Conv2D)              │ (None, 222, 222, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_15 (MaxPooling2D) │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_16 (Conv2D)              │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_16 (MaxPooling2D) │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_17 (Conv2D)              │ (None, 52, 52, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_17 (MaxPooling2D) │ (None, 26, 26, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_5 (Flatten)             │ (None, 86528)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 86528)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 512)            │    44,302,848 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 44,396,033 (169.36 MB)
#  Trainable params: 44,396,033 (169.36 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 15s 470ms/step - accuracy: 0.4803 - auc_10: 0.4846 - auc_11: 0.4668 - false_negatives_5: 117.7419 - false_positives_5: 142.9677 - loss: 0.8928 - precision_5: 0.4689 - recall_5: 0.5263 - true_negatives_5: 114.7419 - true_positives_5: 135.5161 - val_accuracy: 0.5083 - val_auc_10: 0.5050 - val_auc_11: 0.4907 - val_false_negatives_5: 118.0000 - val_false_positives_5: 0.0000e+00 - val_loss: 0.6929 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_true_negatives_5: 122.0000 - val_true_positives_5: 0.0000e+00
# Epoch 2/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 14s 451ms/step - accuracy: 0.5037 - auc_10: 0.5474 - auc_11: 0.5412 - false_negatives_5: 178.7742 - false_positives_5: 70.1290 - loss: 0.6927 - precision_5: 0.3887 - recall_5: 0.2278 - true_negatives_5: 182.6452 - true_positives_5: 79.4194 - val_accuracy: 0.5500 - val_auc_10: 0.5033 - val_auc_11: 0.5012 - val_false_negatives_5: 104.0000 - val_false_positives_5: 4.0000 - val_loss: 0.6923 - val_precision_5: 0.7778 - val_recall_5: 0.1186 - val_true_negatives_5: 118.0000 - val_true_positives_5: 14.0000
# Epoch 3/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 14s 451ms/step - accuracy: 0.5407 - auc_10: 0.5007 - auc_11: 0.5154 - false_negatives_5: 132.0323 - false_positives_5: 107.7419 - loss: 0.6937 - precision_5: 0.6330 - recall_5: 0.4218 - true_negatives_5: 142.0000 - true_positives_5: 129.1935 - val_accuracy: 0.4917 - val_auc_10: 0.4880 - val_auc_11: 0.4760 - val_false_negatives_5: 70.0000 - val_false_positives_5: 52.0000 - val_loss: 0.6944 - val_precision_5: 0.4800 - val_recall_5: 0.4068 - val_true_negatives_5: 70.0000 - val_true_positives_5: 48.0000
# Epoch 4/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 14s 458ms/step - accuracy: 0.5351 - auc_10: 0.5283 - auc_11: 0.5108 - false_negatives_5: 159.5484 - false_positives_5: 82.1613 - loss: 0.6935 - precision_5: 0.5450 - recall_5: 0.3373 - true_negatives_5: 175.4516 - true_positives_5: 93.8064 - val_accuracy: 0.5583 - val_auc_10: 0.5083 - val_auc_11: 0.5338 - val_false_negatives_5: 104.0000 - val_false_positives_5: 2.0000 - val_loss: 0.6931 - val_precision_5: 0.8750 - val_recall_5: 0.1186 - val_true_negatives_5: 120.0000 - val_true_positives_5: 14.0000
# Epoch 5/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 14s 470ms/step - accuracy: 0.5270 - auc_10: 0.5619 - auc_11: 0.5852 - false_negatives_5: 94.3871 - false_positives_5: 147.1613 - loss: 0.6845 - precision_5: 0.5586 - recall_5: 0.5557 - true_negatives_5: 104.5806 - true_positives_5: 164.8387 - val_accuracy: 0.5833 - val_auc_10: 0.6793 - val_auc_11: 0.7271 - val_false_negatives_5: 35.0000 - val_false_positives_5: 65.0000 - val_loss: 0.6474 - val_precision_5: 0.5608 - val_recall_5: 0.7034 - val_true_negatives_5: 57.0000 - val_true_positives_5: 83.0000
# Epoch 6/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 14s 461ms/step - accuracy: 0.5996 - auc_10: 0.6606 - auc_11: 0.6951 - false_negatives_5: 87.8064 - false_positives_5: 114.7097 - loss: 0.6488 - precision_5: 0.5914 - recall_5: 0.6824 - true_negatives_5: 136.2581 - true_positives_5: 172.1935 - val_accuracy: 0.6167 - val_auc_10: 0.6608 - val_auc_11: 0.7027 - val_false_negatives_5: 74.0000 - val_false_positives_5: 18.0000 - val_loss: 0.6564 - val_precision_5: 0.7097 - val_recall_5: 0.3729 - val_true_negatives_5: 104.0000 - val_true_positives_5: 44.0000
# Epoch 7/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 14s 451ms/step - accuracy: 0.6172 - auc_10: 0.6758 - auc_11: 0.6875 - false_negatives_5: 137.2581 - false_positives_5: 52.5806 - loss: 0.6501 - precision_5: 0.7121 - recall_5: 0.4064 - true_negatives_5: 199.7419 - true_positives_5: 121.3871 - val_accuracy: 0.5792 - val_auc_10: 0.5944 - val_auc_11: 0.6470 - val_false_negatives_5: 91.0000 - val_false_positives_5: 10.0000 - val_loss: 0.6802 - val_precision_5: 0.7297 - val_recall_5: 0.2288 - val_true_negatives_5: 112.0000 - val_true_positives_5: 27.0000
# Epoch 8/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 14s 451ms/step - accuracy: 0.6968 - auc_10: 0.7568 - auc_11: 0.7691 - false_negatives_5: 101.9032 - false_positives_5: 54.5161 - loss: 0.5839 - precision_5: 0.7581 - recall_5: 0.5891 - true_negatives_5: 198.3871 - true_positives_5: 156.1613 - val_accuracy: 0.6292 - val_auc_10: 0.6460 - val_auc_11: 0.6996 - val_false_negatives_5: 77.0000 - val_false_positives_5: 12.0000 - val_loss: 0.6506 - val_precision_5: 0.7736 - val_recall_5: 0.3475 - val_true_negatives_5: 110.0000 - val_true_positives_5: 41.0000
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 5.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.5733 - auc_10: 0.6657 - auc_11: 0.6738 - false_negatives_5: 20.8889 - false_positives_5: 44.1111 - loss: 0.6585 - precision_5: 0.5118 - recall_5: 0.7049 - true_negatives_5: 38.3333 - true_positives_5: 49.5556
# Test Accuracy: 58.33%
# Precision: 0.56
# Recall: 0.70
# AUC-ROC: 0.68
# AUC-PR: 0.73
# TN: 57.0, FP: 65.0, FN: 35.0, TP: 83.0
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step
# Confusion Matrix:
# [[57 65]
#  [35 83]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.62      0.47      0.53       122
#            1       0.56      0.70      0.62       118
#
#     accuracy                           0.58       240
#    macro avg       0.59      0.59      0.58       240
# weighted avg       0.59      0.58      0.58       240
#
# AUC Score: 0.59
# Precision: 0.56
# Recall: 0.70
# F1 Score: 0.62
# PR AUC: 0.71
# Cohen's Kappa Coefficient: 0.17
# Matthews Correlation Coefficient (MCC): 0.18
# Balanced Accuracy: 0.59
# Time taken: 112.43 seconds

# %% [markdown]
# # GlobalAveragePooling2D

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout, Flatten
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score, precision_recall_curve, auc, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
import time
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score, balanced_accuracy_score

# Start time
start_time = time.time()

# Assume X_train and y_train are the original splits

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)

# Define custom CNN architecture
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    GlobalAveragePooling2D(),  # Global Average Pooling layer
    Dense(512, activation='relu'),
    Dropout(0.5),  # Dropout layer to prevent overfitting
    Dense(1, activation='sigmoid')
])

# Compile the model with Adam optimizer and additional metrics
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      ])

# Display model summary
model.summary()

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model with early stopping and 50 epochs
history = model.fit(X_train_resized, y_train, epochs=50, validation_data=(X_test_resized, y_test), callbacks=[early_stopping])

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
test_predictions = model.predict(X_test_resized) > 0.5

# Accuracy
accuracy = accuracy_score(y_test, test_predictions)
print(f'Accuracy: {accuracy:.2f}')

# Precision
precision = precision_score(y_test, test_predictions)
print(f'Precision: {precision:.2f}')

# Recall
recall = recall_score(y_test, test_predictions)
print(f'Recall (Sensitivity): {recall:.2f}')

# F1 Score
f1 = f1_score(y_test, test_predictions)
print(f'F1 Score: {f1:.2f}')

# Specificity
tn, fp, fn, tp = confusion_matrix(y_test, test_predictions).ravel()
specificity = tn / (tn + fp)
print(f'Specificity: {specificity:.2f}')

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, test_predictions)
print("Confusion Matrix:")
print(conf_matrix)

# ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, test_predictions)
roc_auc = roc_auc_score(y_test, test_predictions)
print(f'Area Under the ROC Curve (AUC-ROC): {roc_auc:.2f}')
plt.figure()
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# Precision-Recall curve and AUC score
precision, recall, _ = precision_recall_curve(y_test, test_predictions)
pr_auc = auc(recall, precision)
print(f'Precision-Recall Curve (AUC-PR): {pr_auc:.2f}')
plt.figure()
plt.plot(recall, precision, label='Precision-Recall curve (area = %0.2f)' % pr_auc)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower right")
plt.show()

# Cohen's Kappa Coefficient
kappa = cohen_kappa_score(y_test, test_predictions)
print(f"Cohen's Kappa Coefficient: {kappa:.2f}")

# Matthews Correlation Coefficient
mcc = matthews_corrcoef(y_test, test_predictions)
print(f"Matthews Correlation Coefficient (MCC): {mcc:.2f}")

# Balanced Accuracy
balanced_accuracy =balanced_accuracy_score(y_test, test_predictions)
print(f"Balanced Accuracy: {balanced_accuracy:.2f}")

# End time
end_time = time.time()

# Print the time taken
print(f"Time taken: {end_time - start_time:.2f} seconds")
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_18 (Conv2D)              │ (None, 222, 222, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_18 (MaxPooling2D) │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_19 (Conv2D)              │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_19 (MaxPooling2D) │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_20 (Conv2D)              │ (None, 52, 52, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_20 (MaxPooling2D) │ (None, 26, 26, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 512)            │        66,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 159,233 (622.00 KB)
#  Trainable params: 159,233 (622.00 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 8s 249ms/step - accuracy: 0.5027 - auc_12: 0.4964 - auc_13: 0.5167 - loss: 0.6960 - precision_6: 0.5168 - recall_6: 0.5109 - val_accuracy: 0.5083 - val_auc_12: 0.5110 - val_auc_13: 0.4975 - val_loss: 0.6926 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 2/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.4987 - auc_12: 0.5034 - auc_13: 0.5387 - loss: 0.6940 - precision_6: 0.6123 - recall_6: 0.2479 - val_accuracy: 0.5083 - val_auc_12: 0.6710 - val_auc_13: 0.6666 - val_loss: 0.6910 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 3/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 246ms/step - accuracy: 0.5042 - auc_12: 0.5408 - auc_13: 0.5508 - loss: 0.6930 - precision_6: 0.3104 - recall_6: 0.0335 - val_accuracy: 0.5917 - val_auc_12: 0.7382 - val_auc_13: 0.7599 - val_loss: 0.6836 - val_precision_6: 1.0000 - val_recall_6: 0.1695
# Epoch 4/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.5593 - auc_12: 0.6204 - auc_13: 0.5945 - loss: 0.6833 - precision_6: 0.6325 - recall_6: 0.2894 - val_accuracy: 0.6000 - val_auc_12: 0.7443 - val_auc_13: 0.7252 - val_loss: 0.6509 - val_precision_6: 0.5598 - val_recall_6: 0.8729
# Epoch 5/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 0.5579 - auc_12: 0.6072 - auc_13: 0.5750 - loss: 0.6796 - precision_6: 0.5600 - recall_6: 0.5162 - val_accuracy: 0.6833 - val_auc_12: 0.7264 - val_auc_13: 0.7631 - val_loss: 0.6629 - val_precision_6: 0.7100 - val_recall_6: 0.6017
# Epoch 6/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.6079 - auc_12: 0.6461 - auc_13: 0.6460 - loss: 0.6693 - precision_6: 0.5848 - recall_6: 0.6778 - val_accuracy: 0.6750 - val_auc_12: 0.7469 - val_auc_13: 0.7606 - val_loss: 0.6184 - val_precision_6: 0.6493 - val_recall_6: 0.7373
# Epoch 7/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 0.6243 - auc_12: 0.6524 - auc_13: 0.6523 - loss: 0.6632 - precision_6: 0.6516 - recall_6: 0.5884 - val_accuracy: 0.6958 - val_auc_12: 0.7370 - val_auc_13: 0.7652 - val_loss: 0.6247 - val_precision_6: 0.7711 - val_recall_6: 0.5424
# Epoch 8/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 0.5859 - auc_12: 0.6322 - auc_13: 0.6551 - loss: 0.6726 - precision_6: 0.6008 - recall_6: 0.6367 - val_accuracy: 0.6917 - val_auc_12: 0.7364 - val_auc_13: 0.7685 - val_loss: 0.6279 - val_precision_6: 0.8235 - val_recall_6: 0.4746
# Epoch 9/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.6615 - auc_12: 0.6939 - auc_13: 0.6789 - loss: 0.6358 - precision_6: 0.6891 - recall_6: 0.5493 - val_accuracy: 0.6875 - val_auc_12: 0.7361 - val_auc_13: 0.7686 - val_loss: 0.6316 - val_precision_6: 0.8525 - val_recall_6: 0.4407
# Epoch 9: early stopping
# Restoring model weights from the end of the best epoch: 6.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step
# Accuracy: 0.68
# Precision: 0.65
# Recall (Sensitivity): 0.74
# F1 Score: 0.69
# Specificity: 0.61
# Confusion Matrix:
# [[75 47]
#  [31 87]]
# Area Under the ROC Curve (AUC-ROC): 0.68
# Precision-Recall Curve (AUC-PR): 0.76
# Cohen's Kappa Coefficient: 0.35
# Matthews Correlation Coefficient (MCC): 0.35
# Balanced Accuracy: 0.68
# Time taken: 67.39 seconds

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout, Flatten
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score, precision_recall_curve, auc, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
import time
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score, balanced_accuracy_score

# Start time
start_time = time.time()

# Assume X_train and y_train are the original splits

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)

# Define custom CNN architecture
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    GlobalAveragePooling2D(),  # Global Average Pooling layer
    Dense(512, activation='relu'),
    Dropout(0.5),  # Dropout layer to prevent overfitting
    Dense(1, activation='sigmoid')
])

# Compile the model with Adam optimizer and additional metrics
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      ])

# Display model summary
model.summary()

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model with early stopping and 50 epochs
history = model.fit(X_train_resized, y_train, epochs=150, validation_data=(X_test_resized, y_test), callbacks=[early_stopping])

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
test_predictions = model.predict(X_test_resized) > 0.5

# Accuracy
accuracy = accuracy_score(y_test, test_predictions)
print(f'Accuracy: {accuracy:.2f}')

# Precision
precision = precision_score(y_test, test_predictions)
print(f'Precision: {precision:.2f}')

# Recall
recall = recall_score(y_test, test_predictions)
print(f'Recall (Sensitivity): {recall:.2f}')

# F1 Score
f1 = f1_score(y_test, test_predictions)
print(f'F1 Score: {f1:.2f}')

# Specificity
tn, fp, fn, tp = confusion_matrix(y_test, test_predictions).ravel()
specificity = tn / (tn + fp)
print(f'Specificity: {specificity:.2f}')

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, test_predictions)
print("Confusion Matrix:")
print(conf_matrix)

# ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, test_predictions)
roc_auc = roc_auc_score(y_test, test_predictions)
print(f'Area Under the ROC Curve (AUC-ROC): {roc_auc:.2f}')
plt.figure()
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# Precision-Recall curve and AUC score
precision, recall, _ = precision_recall_curve(y_test, test_predictions)
pr_auc = auc(recall, precision)
print(f'Precision-Recall Curve (AUC-PR): {pr_auc:.2f}')
plt.figure()
plt.plot(recall, precision, label='Precision-Recall curve (area = %0.2f)' % pr_auc)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower right")
plt.show()

# Cohen's Kappa Coefficient
kappa = cohen_kappa_score(y_test, test_predictions)
print(f"Cohen's Kappa Coefficient: {kappa:.2f}")

# Matthews Correlation Coefficient
mcc = matthews_corrcoef(y_test, test_predictions)
print(f"Matthews Correlation Coefficient (MCC): {mcc:.2f}")

# Balanced Accuracy
balanced_accuracy =balanced_accuracy_score(y_test, test_predictions)
print(f"Balanced Accuracy: {balanced_accuracy:.2f}")

# End time
end_time = time.time()

# Print the time taken
print(f"Time taken: {end_time - start_time:.2f} seconds")
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_21 (Conv2D)              │ (None, 222, 222, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_21 (MaxPooling2D) │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_22 (Conv2D)              │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_22 (MaxPooling2D) │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_23 (Conv2D)              │ (None, 52, 52, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_23 (MaxPooling2D) │ (None, 26, 26, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 512)            │        66,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 159,233 (622.00 KB)
#  Trainable params: 159,233 (622.00 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 8s 248ms/step - accuracy: 0.4983 - auc_14: 0.4817 - auc_15: 0.4842 - loss: 0.6953 - precision_7: 0.5056 - recall_7: 0.4521 - val_accuracy: 0.5083 - val_auc_14: 0.6027 - val_auc_15: 0.6220 - val_loss: 0.6919 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 2/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 0.4995 - auc_14: 0.5368 - auc_15: 0.5528 - loss: 0.6924 - precision_7: 0.5430 - recall_7: 0.4178 - val_accuracy: 0.5083 - val_auc_14: 0.6727 - val_auc_15: 0.6719 - val_loss: 0.6895 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 3/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 0.5437 - auc_14: 0.5452 - auc_15: 0.5484 - loss: 0.6912 - precision_7: 0.7427 - recall_7: 0.2534 - val_accuracy: 0.4917 - val_auc_14: 0.5254 - val_auc_15: 0.5632 - val_loss: 0.6934 - val_precision_7: 0.4917 - val_recall_7: 1.0000
# Epoch 4/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.4887 - auc_14: 0.5131 - auc_15: 0.4920 - loss: 0.6929 - precision_7: 0.4875 - recall_7: 0.5902 - val_accuracy: 0.4917 - val_auc_14: 0.6259 - val_auc_15: 0.5607 - val_loss: 0.6945 - val_precision_7: 0.4917 - val_recall_7: 1.0000
# Epoch 5/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 0.5126 - auc_14: 0.5692 - auc_15: 0.5561 - loss: 0.6901 - precision_7: 0.5160 - recall_7: 0.5363 - val_accuracy: 0.6250 - val_auc_14: 0.7199 - val_auc_15: 0.7480 - val_loss: 0.6758 - val_precision_7: 0.8182 - val_recall_7: 0.3051
# Epoch 6/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 0.5263 - auc_14: 0.5545 - auc_15: 0.5806 - loss: 0.6933 - precision_7: 0.5941 - recall_7: 0.3465 - val_accuracy: 0.5792 - val_auc_14: 0.7320 - val_auc_15: 0.7610 - val_loss: 0.6532 - val_precision_7: 0.5497 - val_recall_7: 0.7966
# Epoch 7/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 0.6146 - auc_14: 0.6505 - auc_15: 0.6339 - loss: 0.6646 - precision_7: 0.6325 - recall_7: 0.5342 - val_accuracy: 0.5583 - val_auc_14: 0.7368 - val_auc_15: 0.7616 - val_loss: 0.6641 - val_precision_7: 0.5294 - val_recall_7: 0.9153
# Epoch 8/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 0.5867 - auc_14: 0.6348 - auc_15: 0.6563 - loss: 0.6721 - precision_7: 0.5726 - recall_7: 0.7186 - val_accuracy: 0.6958 - val_auc_14: 0.7267 - val_auc_15: 0.7581 - val_loss: 0.6198 - val_precision_7: 0.7143 - val_recall_7: 0.6356
# Epoch 9/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 0.6379 - auc_14: 0.6621 - auc_15: 0.6952 - loss: 0.6494 - precision_7: 0.6613 - recall_7: 0.6199 - val_accuracy: 0.7125 - val_auc_14: 0.7273 - val_auc_15: 0.7557 - val_loss: 0.6127 - val_precision_7: 0.7526 - val_recall_7: 0.6186
# Epoch 10/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.5865 - auc_14: 0.6467 - auc_15: 0.6852 - loss: 0.6559 - precision_7: 0.6084 - recall_7: 0.5525 - val_accuracy: 0.6333 - val_auc_14: 0.7285 - val_auc_15: 0.7598 - val_loss: 0.6215 - val_precision_7: 0.6190 - val_recall_7: 0.6610
# Epoch 11/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 0.6355 - auc_14: 0.6651 - auc_15: 0.6857 - loss: 0.6500 - precision_7: 0.6327 - recall_7: 0.6381 - val_accuracy: 0.6083 - val_auc_14: 0.7315 - val_auc_15: 0.7588 - val_loss: 0.6356 - val_precision_7: 0.5750 - val_recall_7: 0.7797
# Epoch 12/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 0.6241 - auc_14: 0.6784 - auc_15: 0.7185 - loss: 0.6415 - precision_7: 0.6324 - recall_7: 0.6755 - val_accuracy: 0.7000 - val_auc_14: 0.7209 - val_auc_15: 0.7365 - val_loss: 0.6150 - val_precision_7: 0.7738 - val_recall_7: 0.5508
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 9.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step
# Accuracy: 0.71
# Precision: 0.75
# Recall (Sensitivity): 0.62
# F1 Score: 0.68
# Specificity: 0.80
# Confusion Matrix:
# [[98 24]
#  [45 73]]
# Area Under the ROC Curve (AUC-ROC): 0.71
# Precision-Recall Curve (AUC-PR): 0.78
# Cohen's Kappa Coefficient: 0.42
# Matthews Correlation Coefficient (MCC): 0.43
# Balanced Accuracy: 0.71
# Time taken: 89.39 seconds

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout, Flatten
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score, precision_recall_curve, auc, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
import time
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score, balanced_accuracy_score

# Start time
start_time = time.time()

# Assume X_train and y_train are the original splits

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)

# Define custom CNN architecture
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    GlobalAveragePooling2D(),  # Global Average Pooling layer
    Dense(512, activation='relu'),
    Dropout(0.5),  # Dropout layer to prevent overfitting
    Dense(1, activation='sigmoid')
])

# Compile the model with Adam optimizer and additional metrics
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      ])

# Display model summary
model.summary()

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model with early stopping and 50 epochs
history = model.fit(X_train_resized, y_train, epochs=200, validation_data=(X_test_resized, y_test), callbacks=[early_stopping])

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
test_predictions = model.predict(X_test_resized) > 0.5

# Accuracy
accuracy = accuracy_score(y_test, test_predictions)
print(f'Accuracy: {accuracy:.2f}')

# Precision
precision = precision_score(y_test, test_predictions)
print(f'Precision: {precision:.2f}')

# Recall
recall = recall_score(y_test, test_predictions)
print(f'Recall (Sensitivity): {recall:.2f}')

# F1 Score
f1 = f1_score(y_test, test_predictions)
print(f'F1 Score: {f1:.2f}')

# Specificity
tn, fp, fn, tp = confusion_matrix(y_test, test_predictions).ravel()
specificity = tn / (tn + fp)
print(f'Specificity: {specificity:.2f}')

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, test_predictions)
print("Confusion Matrix:")
print(conf_matrix)

# ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, test_predictions)
roc_auc = roc_auc_score(y_test, test_predictions)
print(f'Area Under the ROC Curve (AUC-ROC): {roc_auc:.2f}')
plt.figure()
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# Precision-Recall curve and AUC score
precision, recall, _ = precision_recall_curve(y_test, test_predictions)
pr_auc = auc(recall, precision)
print(f'Precision-Recall Curve (AUC-PR): {pr_auc:.2f}')
plt.figure()
plt.plot(recall, precision, label='Precision-Recall curve (area = %0.2f)' % pr_auc)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower right")
plt.show()

# Cohen's Kappa Coefficient
kappa = cohen_kappa_score(y_test, test_predictions)
print(f"Cohen's Kappa Coefficient: {kappa:.2f}")

# Matthews Correlation Coefficient
mcc = matthews_corrcoef(y_test, test_predictions)
print(f"Matthews Correlation Coefficient (MCC): {mcc:.2f}")

# Balanced Accuracy
balanced_accuracy =balanced_accuracy_score(y_test, test_predictions)
print(f"Balanced Accuracy: {balanced_accuracy:.2f}")

# End time
end_time = time.time()

# Print the time taken
print(f"Time taken: {end_time - start_time:.2f} seconds")
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_24 (Conv2D)              │ (None, 222, 222, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_24 (MaxPooling2D) │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_25 (Conv2D)              │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_25 (MaxPooling2D) │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_26 (Conv2D)              │ (None, 52, 52, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_26 (MaxPooling2D) │ (None, 26, 26, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_2      │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 512)            │        66,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 159,233 (622.00 KB)
#  Trainable params: 159,233 (622.00 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 8s 254ms/step - accuracy: 0.5214 - auc_16: 0.5043 - auc_17: 0.4982 - loss: 0.6939 - precision_8: 0.5167 - recall_8: 0.5840 - val_accuracy: 0.4917 - val_auc_16: 0.5048 - val_auc_17: 0.5001 - val_loss: 0.6935 - val_precision_8: 0.4917 - val_recall_8: 1.0000
# Epoch 2/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 247ms/step - accuracy: 0.5026 - auc_16: 0.5038 - auc_17: 0.5309 - loss: 0.6930 - precision_8: 0.5094 - recall_8: 0.8214 - val_accuracy: 0.5083 - val_auc_16: 0.6552 - val_auc_17: 0.6469 - val_loss: 0.6898 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 3/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 0.5023 - auc_16: 0.5289 - auc_17: 0.5480 - loss: 0.6931 - precision_8: 0.4825 - recall_8: 0.3204 - val_accuracy: 0.6792 - val_auc_16: 0.7398 - val_auc_17: 0.7608 - val_loss: 0.6807 - val_precision_8: 0.7733 - val_recall_8: 0.4915
# Epoch 4/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.5403 - auc_16: 0.5483 - auc_17: 0.5850 - loss: 0.6897 - precision_8: 0.5621 - recall_8: 0.6209 - val_accuracy: 0.5083 - val_auc_16: 0.6903 - val_auc_17: 0.7039 - val_loss: 0.6857 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 5/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 0.5575 - auc_16: 0.5763 - auc_17: 0.6128 - loss: 0.6910 - precision_8: 0.6652 - recall_8: 0.3626 - val_accuracy: 0.5917 - val_auc_16: 0.7117 - val_auc_17: 0.7451 - val_loss: 0.6792 - val_precision_8: 0.9545 - val_recall_8: 0.1780
# Epoch 6/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.5736 - auc_16: 0.6038 - auc_17: 0.6226 - loss: 0.6831 - precision_8: 0.7199 - recall_8: 0.3023 - val_accuracy: 0.6625 - val_auc_16: 0.7238 - val_auc_17: 0.7623 - val_loss: 0.6552 - val_precision_8: 0.8364 - val_recall_8: 0.3898
# Epoch 7/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 0.5851 - auc_16: 0.6222 - auc_17: 0.6471 - loss: 0.6684 - precision_8: 0.6316 - recall_8: 0.3971 - val_accuracy: 0.6542 - val_auc_16: 0.7263 - val_auc_17: 0.7635 - val_loss: 0.6214 - val_precision_8: 0.6471 - val_recall_8: 0.6525
# Epoch 8/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.6095 - auc_16: 0.6561 - auc_17: 0.6800 - loss: 0.6530 - precision_8: 0.6040 - recall_8: 0.6147 - val_accuracy: 0.6708 - val_auc_16: 0.7234 - val_auc_17: 0.7590 - val_loss: 0.6315 - val_precision_8: 0.8421 - val_recall_8: 0.4068
# Epoch 9/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.5970 - auc_16: 0.6537 - auc_17: 0.6674 - loss: 0.6503 - precision_8: 0.6209 - recall_8: 0.4481 - val_accuracy: 0.6458 - val_auc_16: 0.7282 - val_auc_17: 0.7565 - val_loss: 0.6110 - val_precision_8: 0.6341 - val_recall_8: 0.6610
# Epoch 10/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 0.6185 - auc_16: 0.6607 - auc_17: 0.6837 - loss: 0.6498 - precision_8: 0.6401 - recall_8: 0.5605 - val_accuracy: 0.7000 - val_auc_16: 0.7207 - val_auc_17: 0.7539 - val_loss: 0.6264 - val_precision_8: 0.7875 - val_recall_8: 0.5339
# Epoch 11/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.6148 - auc_16: 0.6394 - auc_17: 0.6597 - loss: 0.6511 - precision_8: 0.6581 - recall_8: 0.3902 - val_accuracy: 0.6250 - val_auc_16: 0.7370 - val_auc_17: 0.7576 - val_loss: 0.6452 - val_precision_8: 0.5886 - val_recall_8: 0.7881
# Epoch 12/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 0.6052 - auc_16: 0.6430 - auc_17: 0.6779 - loss: 0.6651 - precision_8: 0.6343 - recall_8: 0.5798 - val_accuracy: 0.6625 - val_auc_16: 0.7271 - val_auc_17: 0.7453 - val_loss: 0.6116 - val_precision_8: 0.6555 - val_recall_8: 0.6610
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 9.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step
# Accuracy: 0.65
# Precision: 0.63
# Recall (Sensitivity): 0.66
# F1 Score: 0.65
# Specificity: 0.63
# Confusion Matrix:
# [[77 45]
#  [40 78]]
# Area Under the ROC Curve (AUC-ROC): 0.65
# Precision-Recall Curve (AUC-PR): 0.73
# Cohen's Kappa Coefficient: 0.29
# Matthews Correlation Coefficient (MCC): 0.29
# Balanced Accuracy: 0.65
# Time taken: 89.82 seconds

# %% [markdown]
# # Conv2D + GlobalAveragePooling2D +Dropout+ Dense Layers

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_recall_curve, auc, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
import time
from tensorflow.keras.callbacks import EarlyStopping

# Start time
start_time = time.time()

# Assume X_train and y_train are the original splits

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)

# Define custom CNN architecture
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 1)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    GlobalAveragePooling2D(),  # Global Average Pooling layer
    Dropout(0.5),  # Dropout layer to prevent overfitting
    Dense(512, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compile the model with Adam optimizer
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      tf.keras.metrics.TruePositives(),
                                                                      tf.keras.metrics.FalsePositives(),
                                                                      tf.keras.metrics.TrueNegatives(),
                                                                      tf.keras.metrics.FalseNegatives()])

# Display model summary
model.summary()

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model with early stopping and 50 epochs
history = model.fit(X_train_resized, y_train, epochs=50, validation_data=(X_test_resized, y_test), callbacks=[early_stopping])

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
test_loss, test_accuracy, precision, recall, auc_roc, auc_pr, tp, fp, tn, fn = model.evaluate(X_test_resized, y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
print(f'AUC-ROC: {auc_roc:.2f}')
print(f'AUC-PR: {auc_pr:.2f}')
print(f'TP: {tp}, FP: {fp}, TN: {tn}, FN: {fn}')

# Confusion matrix
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
print("Confusion Matrix:")
print(conf_matrix)

# Generate classification report
print("Classification Report:")
print(classification_report(y_test, test_predictions))

# ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, test_predictions)
roc_auc = roc_auc_score(y_test, test_predictions)
print(f'AUC Score: {roc_auc:.2f}')

# Precision for class 1 (Positive)
precision = precision_score(y_test, test_predictions)
print(f'Precision: {precision:.2f}')

# Recall for class 1 (Positive)
recall = recall_score(y_test, test_predictions)
print(f'Recall: {recall:.2f}')

# F1 Score
f1 = f1_score(y_test, test_predictions)
print(f'F1 Score: {f1:.2f}')

# Precision-Recall curve and PR AUC
precision, recall, _ = precision_recall_curve(y_test, test_predictions)
pr_auc = auc(recall, precision)
print(f'PR AUC: {pr_auc:.2f}')

# Cohen's Kappa Coefficient
kappa = cohen_kappa_score(y_test, test_predictions)
print(f"Cohen's Kappa Coefficient: {kappa:.2f}")

# Matthews Correlation Coefficient
mcc = matthews_corrcoef(y_test, test_predictions)
print(f"Matthews Correlation Coefficient (MCC): {mcc:.2f}")

# Balanced Accuracy
balanced_accuracy = balanced_accuracy_score(y_test, test_predictions)
print(f"Balanced Accuracy: {balanced_accuracy:.2f}")

# End time
end_time = time.time()

# Print the time taken
print(f"Time taken: {end_time - start_time:.2f} seconds")
# Out:
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_27 (Conv2D)              │ (None, 222, 222, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_28 (Conv2D)              │ (None, 220, 220, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_27 (MaxPooling2D) │ (None, 110, 110, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_29 (Conv2D)              │ (None, 108, 108, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_3      │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 512)            │        66,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 159,233 (622.00 KB)
#  Trainable params: 159,233 (622.00 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 26s 857ms/step - accuracy: 0.4847 - auc_18: 0.4877 - auc_19: 0.4817 - false_negatives_6: 176.9355 - false_positives_6: 86.6774 - loss: 0.6941 - precision_9: 0.4771 - recall_9: 0.4097 - true_negatives_6: 169.0323 - true_positives_6: 78.3226 - val_accuracy: 0.6208 - val_auc_18: 0.6566 - val_auc_19: 0.6385 - val_false_negatives_6: 83.0000 - val_false_positives_6: 8.0000 - val_loss: 0.6911 - val_precision_9: 0.8140 - val_recall_9: 0.2966 - val_true_negatives_6: 114.0000 - val_true_positives_6: 35.0000
# Epoch 2/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 26s 869ms/step - accuracy: 0.5259 - auc_18: 0.5082 - auc_19: 0.5018 - false_negatives_6: 116.0323 - false_positives_6: 126.9355 - loss: 0.6943 - precision_9: 0.5225 - recall_9: 0.5664 - true_negatives_6: 128.0323 - true_positives_6: 139.9677 - val_accuracy: 0.5542 - val_auc_18: 0.7078 - val_auc_19: 0.7161 - val_false_negatives_6: 15.0000 - val_false_positives_6: 92.0000 - val_loss: 0.6902 - val_precision_9: 0.5282 - val_recall_9: 0.8729 - val_true_negatives_6: 30.0000 - val_true_positives_6: 103.0000
# Epoch 3/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 25s 846ms/step - accuracy: 0.5309 - auc_18: 0.5632 - auc_19: 0.5294 - false_negatives_6: 83.0645 - false_positives_6: 154.8710 - loss: 0.6913 - precision_9: 0.5088 - recall_9: 0.6723 - true_negatives_6: 104.3548 - true_positives_6: 168.6774 - val_accuracy: 0.6833 - val_auc_18: 0.7229 - val_auc_19: 0.7575 - val_false_negatives_6: 58.0000 - val_false_positives_6: 18.0000 - val_loss: 0.6824 - val_precision_9: 0.7692 - val_recall_9: 0.5085 - val_true_negatives_6: 104.0000 - val_true_positives_6: 60.0000
# Epoch 4/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 26s 866ms/step - accuracy: 0.5726 - auc_18: 0.5762 - auc_19: 0.5626 - false_negatives_6: 105.7097 - false_positives_6: 120.2581 - loss: 0.6871 - precision_9: 0.5824 - recall_9: 0.6099 - true_negatives_6: 134.3226 - true_positives_6: 150.6774 - val_accuracy: 0.5042 - val_auc_18: 0.7296 - val_auc_19: 0.7577 - val_false_negatives_6: 3.0000 - val_false_positives_6: 116.0000 - val_loss: 0.6827 - val_precision_9: 0.4978 - val_recall_9: 0.9746 - val_true_negatives_6: 6.0000 - val_true_positives_6: 115.0000
# Epoch 5/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 28s 922ms/step - accuracy: 0.5899 - auc_18: 0.6313 - auc_19: 0.6603 - false_negatives_6: 57.4839 - false_positives_6: 150.4516 - loss: 0.6749 - precision_9: 0.5756 - recall_9: 0.8321 - true_negatives_6: 97.5484 - true_positives_6: 205.4839 - val_accuracy: 0.6917 - val_auc_18: 0.7296 - val_auc_19: 0.7666 - val_false_negatives_6: 40.0000 - val_false_positives_6: 34.0000 - val_loss: 0.6255 - val_precision_9: 0.6964 - val_recall_9: 0.6610 - val_true_negatives_6: 88.0000 - val_true_positives_6: 78.0000
# Epoch 6/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 26s 883ms/step - accuracy: 0.5977 - auc_18: 0.6476 - auc_19: 0.6815 - false_negatives_6: 106.1613 - false_positives_6: 99.4516 - loss: 0.6553 - precision_9: 0.6175 - recall_9: 0.6264 - true_negatives_6: 149.1613 - true_positives_6: 156.1935 - val_accuracy: 0.6458 - val_auc_18: 0.7216 - val_auc_19: 0.7644 - val_false_negatives_6: 77.0000 - val_false_positives_6: 8.0000 - val_loss: 0.6415 - val_precision_9: 0.8367 - val_recall_9: 0.3475 - val_true_negatives_6: 114.0000 - val_true_positives_6: 41.0000
# Epoch 7/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 27s 890ms/step - accuracy: 0.5765 - auc_18: 0.6216 - auc_19: 0.6518 - false_negatives_6: 114.7742 - false_positives_6: 105.2581 - loss: 0.6660 - precision_9: 0.5839 - recall_9: 0.5568 - true_negatives_6: 147.8387 - true_positives_6: 143.0968 - val_accuracy: 0.6333 - val_auc_18: 0.7229 - val_auc_19: 0.7631 - val_false_negatives_6: 34.0000 - val_false_positives_6: 54.0000 - val_loss: 0.6419 - val_precision_9: 0.6087 - val_recall_9: 0.7119 - val_true_negatives_6: 68.0000 - val_true_positives_6: 84.0000
# Epoch 8/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 26s 880ms/step - accuracy: 0.5985 - auc_18: 0.6577 - auc_19: 0.7168 - false_negatives_6: 93.5161 - false_positives_6: 114.8387 - loss: 0.6493 - precision_9: 0.6057 - recall_9: 0.6816 - true_negatives_6: 133.8387 - true_positives_6: 168.7742 - val_accuracy: 0.6958 - val_auc_18: 0.7261 - val_auc_19: 0.7606 - val_false_negatives_6: 50.0000 - val_false_positives_6: 23.0000 - val_loss: 0.6128 - val_precision_9: 0.7473 - val_recall_9: 0.5763 - val_true_negatives_6: 99.0000 - val_true_positives_6: 68.0000
# Epoch 9/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 27s 883ms/step - accuracy: 0.5980 - auc_18: 0.6477 - auc_19: 0.6612 - false_negatives_6: 141.2581 - false_positives_6: 63.9032 - loss: 0.6518 - precision_9: 0.6323 - recall_9: 0.3982 - true_negatives_6: 195.3548 - true_positives_6: 110.4516 - val_accuracy: 0.7083 - val_auc_18: 0.7230 - val_auc_19: 0.7562 - val_false_negatives_6: 53.0000 - val_false_positives_6: 17.0000 - val_loss: 0.6220 - val_precision_9: 0.7927 - val_recall_9: 0.5508 - val_true_negatives_6: 105.0000 - val_true_positives_6: 65.0000
# Epoch 10/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 26s 851ms/step - accuracy: 0.6074 - auc_18: 0.6286 - auc_19: 0.6691 - false_negatives_6: 120.7419 - false_positives_6: 78.1613 - loss: 0.6572 - precision_9: 0.6377 - recall_9: 0.5126 - true_negatives_6: 175.1613 - true_positives_6: 136.9032 - val_accuracy: 0.5250 - val_auc_18: 0.7031 - val_auc_19: 0.7273 - val_false_negatives_6: 114.0000 - val_false_positives_6: 0.0000e+00 - val_loss: 0.6956 - val_precision_9: 1.0000 - val_recall_9: 0.0339 - val_true_negatives_6: 122.0000 - val_true_positives_6: 4.0000
# Epoch 11/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 26s 866ms/step - accuracy: 0.5788 - auc_18: 0.5872 - auc_19: 0.6281 - false_negatives_6: 158.5484 - false_positives_6: 50.1290 - loss: 0.6843 - precision_9: 0.7070 - recall_9: 0.2782 - true_negatives_6: 206.1290 - true_positives_6: 96.1613 - val_accuracy: 0.6667 - val_auc_18: 0.7113 - val_auc_19: 0.7509 - val_false_negatives_6: 43.0000 - val_false_positives_6: 37.0000 - val_loss: 0.6356 - val_precision_9: 0.6696 - val_recall_9: 0.6356 - val_true_negatives_6: 85.0000 - val_true_positives_6: 75.0000
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 8.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - accuracy: 0.6798 - auc_18: 0.7381 - auc_19: 0.7228 - false_negatives_6: 29.6667 - false_positives_6: 17.7778 - loss: 0.6127 - precision_9: 0.6598 - recall_9: 0.5662 - true_negatives_6: 64.6667 - true_positives_6: 40.7778
# Test Accuracy: 69.58%
# Precision: 0.75
# Recall: 0.58
# AUC-ROC: 0.73
# AUC-PR: 0.76
# TP: 68.0, FP: 23.0, TN: 99.0, FN: 50.0
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step
# Confusion Matrix:
# [[99 23]
#  [50 68]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.66      0.81      0.73       122
#            1       0.75      0.58      0.65       118
#
#     accuracy                           0.70       240
#    macro avg       0.71      0.69      0.69       240
# weighted avg       0.71      0.70      0.69       240
#
# AUC Score: 0.69
# Precision: 0.75
# Recall: 0.58
# F1 Score: 0.65
# PR AUC: 0.77
# Cohen's Kappa Coefficient: 0.39
# Matthews Correlation Coefficient (MCC): 0.40
# Balanced Accuracy: 0.69
# Time taken: 292.26 seconds

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_recall_curve, auc, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
import time
from tensorflow.keras.callbacks import EarlyStopping

# Start time
start_time = time.time()

# Assume X_train and y_train are the original splits

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)

# Define custom CNN architecture
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 1)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    GlobalAveragePooling2D(),  # Global Average Pooling layer
    Dropout(0.5),  # Dropout layer to prevent overfitting
    Dense(512, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compile the model with Adam optimizer
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      tf.keras.metrics.TruePositives(),
                                                                      tf.keras.metrics.FalsePositives(),
                                                                      tf.keras.metrics.TrueNegatives(),
                                                                      tf.keras.metrics.FalseNegatives()])

# Display model summary
model.summary()

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model with early stopping and 50 epochs
history = model.fit(X_train_resized, y_train, epochs=150, validation_data=(X_test_resized, y_test), callbacks=[early_stopping])

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
test_loss, test_accuracy, precision, recall, auc_roc, auc_pr, tp, fp, tn, fn = model.evaluate(X_test_resized, y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
print(f'AUC-ROC: {auc_roc:.2f}')
print(f'AUC-PR: {auc_pr:.2f}')
print(f'TP: {tp}, FP: {fp}, TN: {tn}, FN: {fn}')

# Confusion matrix
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
print("Confusion Matrix:")
print(conf_matrix)

# Generate classification report
print("Classification Report:")
print(classification_report(y_test, test_predictions))

# ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, test_predictions)
roc_auc = roc_auc_score(y_test, test_predictions)
print(f'AUC Score: {roc_auc:.2f}')

# Precision for class 1 (Positive)
precision = precision_score(y_test, test_predictions)
print(f'Precision: {precision:.2f}')

# Recall for class 1 (Positive)
recall = recall_score(y_test, test_predictions)
print(f'Recall: {recall:.2f}')

# F1 Score
f1 = f1_score(y_test, test_predictions)
print(f'F1 Score: {f1:.2f}')

# Precision-Recall curve and PR AUC
precision, recall, _ = precision_recall_curve(y_test, test_predictions)
pr_auc = auc(recall, precision)
print(f'PR AUC: {pr_auc:.2f}')

# Cohen's Kappa Coefficient
kappa = cohen_kappa_score(y_test, test_predictions)
print(f"Cohen's Kappa Coefficient: {kappa:.2f}")

# Matthews Correlation Coefficient
mcc = matthews_corrcoef(y_test, test_predictions)
print(f"Matthews Correlation Coefficient (MCC): {mcc:.2f}")

# Balanced Accuracy
balanced_accuracy = balanced_accuracy_score(y_test, test_predictions)
print(f"Balanced Accuracy: {balanced_accuracy:.2f}")

# End time
end_time = time.time()

# Print the time taken
print(f"Time taken: {end_time - start_time:.2f} seconds")
# Out:
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_30 (Conv2D)              │ (None, 222, 222, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_31 (Conv2D)              │ (None, 220, 220, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_28 (MaxPooling2D) │ (None, 110, 110, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_32 (Conv2D)              │ (None, 108, 108, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_4      │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 512)            │        66,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 159,233 (622.00 KB)
#  Trainable params: 159,233 (622.00 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 27s 883ms/step - accuracy: 0.5125 - auc_20: 0.4935 - auc_21: 0.4457 - false_negatives_7: 192.8065 - false_positives_7: 54.3548 - loss: 0.6962 - precision_10: 0.4120 - recall_10: 0.1961 - true_negatives_7: 210.3548 - true_positives_7: 53.4516 - val_accuracy: 0.4917 - val_auc_20: 0.5000 - val_auc_21: 0.4917 - val_false_negatives_7: 0.0000e+00 - val_false_positives_7: 122.0000 - val_loss: 0.6943 - val_precision_10: 0.4917 - val_recall_10: 1.0000 - val_true_negatives_7: 0.0000e+00 - val_true_positives_7: 118.0000
# Epoch 2/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 26s 864ms/step - accuracy: 0.5029 - auc_20: 0.4810 - auc_21: 0.4766 - false_negatives_7: 0.4516 - false_positives_7: 254.0968 - loss: 0.6937 - precision_10: 0.5026 - recall_10: 0.9990 - true_negatives_7: 0.9032 - true_positives_7: 255.5161 - val_accuracy: 0.4917 - val_auc_20: 0.6424 - val_auc_21: 0.6507 - val_false_negatives_7: 0.0000e+00 - val_false_positives_7: 122.0000 - val_loss: 0.6924 - val_precision_10: 0.4917 - val_recall_10: 1.0000 - val_true_negatives_7: 0.0000e+00 - val_true_positives_7: 118.0000
# Epoch 3/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 26s 870ms/step - accuracy: 0.5154 - auc_20: 0.4919 - auc_21: 0.4915 - false_negatives_7: 144.9355 - false_positives_7: 100.0645 - loss: 0.6933 - precision_10: 0.5088 - recall_10: 0.5399 - true_negatives_7: 160.6774 - true_positives_7: 105.2903 - val_accuracy: 0.5292 - val_auc_20: 0.6727 - val_auc_21: 0.6873 - val_false_negatives_7: 6.0000 - val_false_positives_7: 107.0000 - val_loss: 0.6907 - val_precision_10: 0.5114 - val_recall_10: 0.9492 - val_true_negatives_7: 15.0000 - val_true_positives_7: 112.0000
# Epoch 4/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 26s 878ms/step - accuracy: 0.5348 - auc_20: 0.5592 - auc_21: 0.5439 - false_negatives_7: 86.2903 - false_positives_7: 148.7097 - loss: 0.6914 - precision_10: 0.5243 - recall_10: 0.7239 - true_negatives_7: 105.7097 - true_positives_7: 170.2581 - val_accuracy: 0.6583 - val_auc_20: 0.7097 - val_auc_21: 0.7352 - val_false_negatives_7: 59.0000 - val_false_positives_7: 23.0000 - val_loss: 0.6867 - val_precision_10: 0.7195 - val_recall_10: 0.5000 - val_true_negatives_7: 99.0000 - val_true_positives_7: 59.0000
# Epoch 5/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 26s 863ms/step - accuracy: 0.5331 - auc_20: 0.5694 - auc_21: 0.5886 - false_negatives_7: 31.4839 - false_positives_7: 207.9355 - loss: 0.6905 - precision_10: 0.5344 - recall_10: 0.8553 - true_negatives_7: 44.3226 - true_positives_7: 227.2258 - val_accuracy: 0.5750 - val_auc_20: 0.7108 - val_auc_21: 0.7448 - val_false_negatives_7: 102.0000 - val_false_positives_7: 0.0000e+00 - val_loss: 0.6780 - val_precision_10: 1.0000 - val_recall_10: 0.1356 - val_true_negatives_7: 122.0000 - val_true_positives_7: 16.0000
# Epoch 6/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 26s 879ms/step - accuracy: 0.5407 - auc_20: 0.5955 - auc_21: 0.5891 - false_negatives_7: 146.8065 - false_positives_7: 83.9032 - loss: 0.6833 - precision_10: 0.5761 - recall_10: 0.3890 - true_negatives_7: 173.2903 - true_positives_7: 106.9677 - val_accuracy: 0.6500 - val_auc_20: 0.7232 - val_auc_21: 0.7532 - val_false_negatives_7: 32.0000 - val_false_positives_7: 52.0000 - val_loss: 0.6424 - val_precision_10: 0.6232 - val_recall_10: 0.7288 - val_true_negatives_7: 70.0000 - val_true_positives_7: 86.0000
# Epoch 7/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 26s 873ms/step - accuracy: 0.6002 - auc_20: 0.6310 - auc_21: 0.6137 - false_negatives_7: 103.8710 - false_positives_7: 99.3871 - loss: 0.6659 - precision_10: 0.5852 - recall_10: 0.5893 - true_negatives_7: 165.0323 - true_positives_7: 142.6774 - val_accuracy: 0.6000 - val_auc_20: 0.7247 - val_auc_21: 0.7566 - val_false_negatives_7: 24.0000 - val_false_positives_7: 72.0000 - val_loss: 0.6428 - val_precision_10: 0.5663 - val_recall_10: 0.7966 - val_true_negatives_7: 50.0000 - val_true_positives_7: 94.0000
# Epoch 8/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 26s 882ms/step - accuracy: 0.6004 - auc_20: 0.6474 - auc_21: 0.6611 - false_negatives_7: 100.7097 - false_positives_7: 109.4839 - loss: 0.6615 - precision_10: 0.5862 - recall_10: 0.6503 - true_negatives_7: 145.4194 - true_positives_7: 155.3548 - val_accuracy: 0.6667 - val_auc_20: 0.7093 - val_auc_21: 0.7541 - val_false_negatives_7: 49.0000 - val_false_positives_7: 31.0000 - val_loss: 0.6508 - val_precision_10: 0.6900 - val_recall_10: 0.5847 - val_true_negatives_7: 91.0000 - val_true_positives_7: 69.0000
# Epoch 9/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 27s 894ms/step - accuracy: 0.5612 - auc_20: 0.6104 - auc_21: 0.6397 - false_negatives_7: 102.2258 - false_positives_7: 118.7097 - loss: 0.6731 - precision_10: 0.5675 - recall_10: 0.5973 - true_negatives_7: 134.0968 - true_positives_7: 155.9355 - val_accuracy: 0.6792 - val_auc_20: 0.7147 - val_auc_21: 0.7489 - val_false_negatives_7: 57.0000 - val_false_positives_7: 20.0000 - val_loss: 0.6300 - val_precision_10: 0.7531 - val_recall_10: 0.5169 - val_true_negatives_7: 102.0000 - val_true_positives_7: 61.0000
# Epoch 10/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 26s 869ms/step - accuracy: 0.5854 - auc_20: 0.6159 - auc_21: 0.6412 - false_negatives_7: 119.5484 - false_positives_7: 91.4839 - loss: 0.6701 - precision_10: 0.6066 - recall_10: 0.5439 - true_negatives_7: 161.5484 - true_positives_7: 138.3871 - val_accuracy: 0.6833 - val_auc_20: 0.7169 - val_auc_21: 0.7542 - val_false_negatives_7: 54.0000 - val_false_positives_7: 22.0000 - val_loss: 0.6331 - val_precision_10: 0.7442 - val_recall_10: 0.5424 - val_true_negatives_7: 100.0000 - val_true_positives_7: 64.0000
# Epoch 11/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 26s 883ms/step - accuracy: 0.5903 - auc_20: 0.6189 - auc_21: 0.6418 - false_negatives_7: 122.6452 - false_positives_7: 88.6129 - loss: 0.6682 - precision_10: 0.6157 - recall_10: 0.5505 - true_negatives_7: 162.0645 - true_positives_7: 137.6452 - val_accuracy: 0.6333 - val_auc_20: 0.7223 - val_auc_21: 0.7578 - val_false_negatives_7: 35.0000 - val_false_positives_7: 53.0000 - val_loss: 0.6327 - val_precision_10: 0.6103 - val_recall_10: 0.7034 - val_true_negatives_7: 69.0000 - val_true_positives_7: 83.0000
# Epoch 12/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 26s 879ms/step - accuracy: 0.6055 - auc_20: 0.6571 - auc_21: 0.6700 - false_negatives_7: 103.6129 - false_positives_7: 97.0323 - loss: 0.6543 - precision_10: 0.5992 - recall_10: 0.6242 - true_negatives_7: 160.7097 - true_positives_7: 149.6129 - val_accuracy: 0.6500 - val_auc_20: 0.7126 - val_auc_21: 0.7370 - val_false_negatives_7: 73.0000 - val_false_positives_7: 11.0000 - val_loss: 0.6344 - val_precision_10: 0.8036 - val_recall_10: 0.3814 - val_true_negatives_7: 111.0000 - val_true_positives_7: 45.0000
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 9.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - accuracy: 0.6901 - auc_20: 0.7334 - auc_21: 0.7208 - false_negatives_7: 32.5556 - false_positives_7: 15.6667 - loss: 0.6263 - precision_10: 0.6910 - recall_10: 0.5497 - true_negatives_7: 66.7778 - true_positives_7: 37.8889
# Test Accuracy: 67.92%
# Precision: 0.75
# Recall: 0.52
# AUC-ROC: 0.71
# AUC-PR: 0.75
# TP: 61.0, FP: 20.0, TN: 102.0, FN: 57.0
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step
# Confusion Matrix:
# [[102  20]
#  [ 57  61]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.64      0.84      0.73       122
#            1       0.75      0.52      0.61       118
#
#     accuracy                           0.68       240
#    macro avg       0.70      0.68      0.67       240
# weighted avg       0.70      0.68      0.67       240
#
# AUC Score: 0.68
# Precision: 0.75
# Recall: 0.52
# F1 Score: 0.61
# PR AUC: 0.75
# Cohen's Kappa Coefficient: 0.35
# Matthews Correlation Coefficient (MCC): 0.37
# Balanced Accuracy: 0.68
# Time taken: 319.49 seconds

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_recall_curve, auc, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
import time
from tensorflow.keras.callbacks import EarlyStopping

# Start time
start_time = time.time()

# Assume X_train and y_train are the original splits

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)

# Define custom CNN architecture
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 1)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    GlobalAveragePooling2D(),  # Global Average Pooling layer
    Dropout(0.5),  # Dropout layer to prevent overfitting
    Dense(512, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compile the model with Adam optimizer
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      tf.keras.metrics.TruePositives(),
                                                                      tf.keras.metrics.FalsePositives(),
                                                                      tf.keras.metrics.TrueNegatives(),
                                                                      tf.keras.metrics.FalseNegatives()])

# Display model summary
model.summary()

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model with early stopping and 50 epochs
history = model.fit(X_train_resized, y_train, epochs=200, validation_data=(X_test_resized, y_test), callbacks=[early_stopping])

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
test_loss, test_accuracy, precision, recall, auc_roc, auc_pr, tp, fp, tn, fn = model.evaluate(X_test_resized, y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
print(f'AUC-ROC: {auc_roc:.2f}')
print(f'AUC-PR: {auc_pr:.2f}')
print(f'TP: {tp}, FP: {fp}, TN: {tn}, FN: {fn}')

# Confusion matrix
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
print("Confusion Matrix:")
print(conf_matrix)

# Generate classification report
print("Classification Report:")
print(classification_report(y_test, test_predictions))

# ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, test_predictions)
roc_auc = roc_auc_score(y_test, test_predictions)
print(f'AUC Score: {roc_auc:.2f}')

# Precision for class 1 (Positive)
precision = precision_score(y_test, test_predictions)
print(f'Precision: {precision:.2f}')

# Recall for class 1 (Positive)
recall = recall_score(y_test, test_predictions)
print(f'Recall: {recall:.2f}')

# F1 Score
f1 = f1_score(y_test, test_predictions)
print(f'F1 Score: {f1:.2f}')

# Precision-Recall curve and PR AUC
precision, recall, _ = precision_recall_curve(y_test, test_predictions)
pr_auc = auc(recall, precision)
print(f'PR AUC: {pr_auc:.2f}')

# Cohen's Kappa Coefficient
kappa = cohen_kappa_score(y_test, test_predictions)
print(f"Cohen's Kappa Coefficient: {kappa:.2f}")

# Matthews Correlation Coefficient
mcc = matthews_corrcoef(y_test, test_predictions)
print(f"Matthews Correlation Coefficient (MCC): {mcc:.2f}")

# Balanced Accuracy
balanced_accuracy = balanced_accuracy_score(y_test, test_predictions)
print(f"Balanced Accuracy: {balanced_accuracy:.2f}")

# End time
end_time = time.time()

# Print the time taken
print(f"Time taken: {end_time - start_time:.2f} seconds")
# Out:
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_33 (Conv2D)              │ (None, 222, 222, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_34 (Conv2D)              │ (None, 220, 220, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_29 (MaxPooling2D) │ (None, 110, 110, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_35 (Conv2D)              │ (None, 108, 108, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_5      │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 512)            │        66,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 159,233 (622.00 KB)
#  Trainable params: 159,233 (622.00 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 28s 901ms/step - accuracy: 0.5346 - auc_22: 0.5043 - auc_23: 0.5152 - false_negatives_8: 56.3548 - false_positives_8: 179.5161 - loss: 0.6928 - precision_11: 0.5361 - recall_11: 0.8450 - true_negatives_8: 66.2581 - true_positives_8: 208.8387 - val_accuracy: 0.5083 - val_auc_22: 0.6929 - val_auc_23: 0.7088 - val_false_negatives_8: 118.0000 - val_false_positives_8: 0.0000e+00 - val_loss: 0.6887 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00 - val_true_negatives_8: 122.0000 - val_true_positives_8: 0.0000e+00
# Epoch 2/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 26s 873ms/step - accuracy: 0.5301 - auc_22: 0.5360 - auc_23: 0.5143 - false_negatives_8: 196.9677 - false_positives_8: 49.4839 - loss: 0.6907 - precision_11: 0.5203 - recall_11: 0.1484 - true_negatives_8: 209.8065 - true_positives_8: 54.7097 - val_accuracy: 0.4917 - val_auc_22: 0.6730 - val_auc_23: 0.6654 - val_false_negatives_8: 0.0000e+00 - val_false_positives_8: 122.0000 - val_loss: 0.6928 - val_precision_11: 0.4917 - val_recall_11: 1.0000 - val_true_negatives_8: 0.0000e+00 - val_true_positives_8: 118.0000
# Epoch 3/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 27s 912ms/step - accuracy: 0.5184 - auc_22: 0.5410 - auc_23: 0.5374 - false_negatives_8: 102.9355 - false_positives_8: 140.5161 - loss: 0.6919 - precision_11: 0.5078 - recall_11: 0.6817 - true_negatives_8: 117.3226 - true_positives_8: 150.1935 - val_accuracy: 0.6417 - val_auc_22: 0.7025 - val_auc_23: 0.7340 - val_false_negatives_8: 77.0000 - val_false_positives_8: 9.0000 - val_loss: 0.6836 - val_precision_11: 0.8200 - val_recall_11: 0.3475 - val_true_negatives_8: 113.0000 - val_true_positives_8: 41.0000
# Epoch 4/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 28s 932ms/step - accuracy: 0.5313 - auc_22: 0.5519 - auc_23: 0.5480 - false_negatives_8: 83.7419 - false_positives_8: 149.2258 - loss: 0.6897 - precision_11: 0.5343 - recall_11: 0.6616 - true_negatives_8: 103.7097 - true_positives_8: 174.2903 - val_accuracy: 0.5833 - val_auc_22: 0.7089 - val_auc_23: 0.7363 - val_false_negatives_8: 100.0000 - val_false_positives_8: 0.0000e+00 - val_loss: 0.6762 - val_precision_11: 1.0000 - val_recall_11: 0.1525 - val_true_negatives_8: 122.0000 - val_true_positives_8: 18.0000
# Epoch 5/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 27s 902ms/step - accuracy: 0.5880 - auc_22: 0.6287 - auc_23: 0.6150 - false_negatives_8: 132.6129 - false_positives_8: 79.8064 - loss: 0.6749 - precision_11: 0.6357 - recall_11: 0.4212 - true_negatives_8: 178.9355 - true_positives_8: 119.6129 - val_accuracy: 0.5625 - val_auc_22: 0.7153 - val_auc_23: 0.7378 - val_false_negatives_8: 15.0000 - val_false_positives_8: 90.0000 - val_loss: 0.6641 - val_precision_11: 0.5337 - val_recall_11: 0.8729 - val_true_negatives_8: 32.0000 - val_true_positives_8: 103.0000
# Epoch 6/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 26s 870ms/step - accuracy: 0.5623 - auc_22: 0.5936 - auc_23: 0.5756 - false_negatives_8: 107.7097 - false_positives_8: 113.0968 - loss: 0.6820 - precision_11: 0.5456 - recall_11: 0.5537 - true_negatives_8: 147.2258 - true_positives_8: 142.9355 - val_accuracy: 0.5750 - val_auc_22: 0.7158 - val_auc_23: 0.7460 - val_false_negatives_8: 25.0000 - val_false_positives_8: 77.0000 - val_loss: 0.6562 - val_precision_11: 0.5471 - val_recall_11: 0.7881 - val_true_negatives_8: 45.0000 - val_true_positives_8: 93.0000
# Epoch 7/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 26s 864ms/step - accuracy: 0.5933 - auc_22: 0.6387 - auc_23: 0.6617 - false_negatives_8: 112.6452 - false_positives_8: 93.6129 - loss: 0.6654 - precision_11: 0.5971 - recall_11: 0.5959 - true_negatives_8: 161.0968 - true_positives_8: 143.6129 - val_accuracy: 0.6708 - val_auc_22: 0.7109 - val_auc_23: 0.7438 - val_false_negatives_8: 66.0000 - val_false_positives_8: 13.0000 - val_loss: 0.6381 - val_precision_11: 0.8000 - val_recall_11: 0.4407 - val_true_negatives_8: 109.0000 - val_true_positives_8: 52.0000
# Epoch 8/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 26s 861ms/step - accuracy: 0.5761 - auc_22: 0.6281 - auc_23: 0.6499 - false_negatives_8: 111.7097 - false_positives_8: 98.8387 - loss: 0.6645 - precision_11: 0.5973 - recall_11: 0.5325 - true_negatives_8: 158.0645 - true_positives_8: 142.3548 - val_accuracy: 0.6875 - val_auc_22: 0.7164 - val_auc_23: 0.7405 - val_false_negatives_8: 56.0000 - val_false_positives_8: 19.0000 - val_loss: 0.6268 - val_precision_11: 0.7654 - val_recall_11: 0.5254 - val_true_negatives_8: 103.0000 - val_true_positives_8: 62.0000
# Epoch 9/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 26s 863ms/step - accuracy: 0.5783 - auc_22: 0.6172 - auc_23: 0.6314 - false_negatives_8: 147.9032 - false_positives_8: 66.0323 - loss: 0.6716 - precision_11: 0.6340 - recall_11: 0.4003 - true_negatives_8: 189.3548 - true_positives_8: 107.6774 - val_accuracy: 0.6958 - val_auc_22: 0.7093 - val_auc_23: 0.7457 - val_false_negatives_8: 56.0000 - val_false_positives_8: 17.0000 - val_loss: 0.6422 - val_precision_11: 0.7848 - val_recall_11: 0.5254 - val_true_negatives_8: 105.0000 - val_true_positives_8: 62.0000
# Epoch 10/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 26s 877ms/step - accuracy: 0.5659 - auc_22: 0.6110 - auc_23: 0.6781 - false_negatives_8: 101.2581 - false_positives_8: 116.8064 - loss: 0.6612 - precision_11: 0.5859 - recall_11: 0.6118 - true_negatives_8: 130.8710 - true_positives_8: 162.0323 - val_accuracy: 0.6458 - val_auc_22: 0.7196 - val_auc_23: 0.7483 - val_false_negatives_8: 40.0000 - val_false_positives_8: 45.0000 - val_loss: 0.6153 - val_precision_11: 0.6341 - val_recall_11: 0.6610 - val_true_negatives_8: 77.0000 - val_true_positives_8: 78.0000
# Epoch 11/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 26s 861ms/step - accuracy: 0.5707 - auc_22: 0.6054 - auc_23: 0.6576 - false_negatives_8: 128.8387 - false_positives_8: 92.3871 - loss: 0.6704 - precision_11: 0.6062 - recall_11: 0.5135 - true_negatives_8: 154.5806 - true_positives_8: 135.1613 - val_accuracy: 0.6792 - val_auc_22: 0.7025 - val_auc_23: 0.7216 - val_false_negatives_8: 65.0000 - val_false_positives_8: 12.0000 - val_loss: 0.6420 - val_precision_11: 0.8154 - val_recall_11: 0.4492 - val_true_negatives_8: 110.0000 - val_true_positives_8: 53.0000
# Epoch 12/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 27s 894ms/step - accuracy: 0.5582 - auc_22: 0.6220 - auc_23: 0.6356 - false_negatives_8: 160.9355 - false_positives_8: 56.5161 - loss: 0.6644 - precision_11: 0.5935 - recall_11: 0.3188 - true_negatives_8: 198.9355 - true_positives_8: 94.5806 - val_accuracy: 0.7000 - val_auc_22: 0.7225 - val_auc_23: 0.7373 - val_false_negatives_8: 56.0000 - val_false_positives_8: 16.0000 - val_loss: 0.6138 - val_precision_11: 0.7949 - val_recall_11: 0.5254 - val_true_negatives_8: 106.0000 - val_true_positives_8: 62.0000
# Epoch 13/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 26s 860ms/step - accuracy: 0.6279 - auc_22: 0.6738 - auc_23: 0.6887 - false_negatives_8: 144.8710 - false_positives_8: 47.5484 - loss: 0.6398 - precision_11: 0.6961 - recall_11: 0.4138 - true_negatives_8: 212.0000 - true_positives_8: 106.5484 - val_accuracy: 0.6875 - val_auc_22: 0.7195 - val_auc_23: 0.7438 - val_false_negatives_8: 42.0000 - val_false_positives_8: 33.0000 - val_loss: 0.6139 - val_precision_11: 0.6972 - val_recall_11: 0.6441 - val_true_negatives_8: 89.0000 - val_true_positives_8: 76.0000
# Epoch 14/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 26s 870ms/step - accuracy: 0.6106 - auc_22: 0.6618 - auc_23: 0.6945 - false_negatives_8: 134.0000 - false_positives_8: 67.2258 - loss: 0.6451 - precision_11: 0.6541 - recall_11: 0.5085 - true_negatives_8: 186.0000 - true_positives_8: 123.7419 - val_accuracy: 0.6917 - val_auc_22: 0.7218 - val_auc_23: 0.7416 - val_false_negatives_8: 45.0000 - val_false_positives_8: 29.0000 - val_loss: 0.6148 - val_precision_11: 0.7157 - val_recall_11: 0.6186 - val_true_negatives_8: 93.0000 - val_true_positives_8: 73.0000
# Epoch 15/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 26s 856ms/step - accuracy: 0.5906 - auc_22: 0.6160 - auc_23: 0.6195 - false_negatives_8: 154.9355 - false_positives_8: 53.1290 - loss: 0.6629 - precision_11: 0.6187 - recall_11: 0.3754 - true_negatives_8: 208.6774 - true_positives_8: 94.2258 - val_accuracy: 0.6458 - val_auc_22: 0.7091 - val_auc_23: 0.7225 - val_false_negatives_8: 45.0000 - val_false_positives_8: 40.0000 - val_loss: 0.6239 - val_precision_11: 0.6460 - val_recall_11: 0.6186 - val_true_negatives_8: 82.0000 - val_true_positives_8: 73.0000
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 12.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - accuracy: 0.7069 - auc_22: 0.7328 - auc_23: 0.6911 - false_negatives_8: 32.6667 - false_positives_8: 12.1111 - loss: 0.6143 - precision_11: 0.7305 - recall_11: 0.5342 - true_negatives_8: 70.3333 - true_positives_8: 37.7778
# Test Accuracy: 70.00%
# Precision: 0.79
# Recall: 0.53
# AUC-ROC: 0.72
# AUC-PR: 0.74
# TP: 62.0, FP: 16.0, TN: 106.0, FN: 56.0
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step
# Confusion Matrix:
# [[106  16]
#  [ 56  62]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.65      0.87      0.75       122
#            1       0.79      0.53      0.63       118
#
#     accuracy                           0.70       240
#    macro avg       0.72      0.70      0.69       240
# weighted avg       0.72      0.70      0.69       240
#
# AUC Score: 0.70
# Precision: 0.79
# Recall: 0.53
# F1 Score: 0.63
# PR AUC: 0.78
# Cohen's Kappa Coefficient: 0.40
# Matthews Correlation Coefficient (MCC): 0.42
# Balanced Accuracy: 0.70
# Time taken: 399.99 seconds

# %% [markdown]
# # LSTM + Dense Layers

# %%
import numpy as np
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, LSTM, Dense, Reshape
from tensorflow.keras.models import Model
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_recall_curve, auc, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import cv2
import tensorflow as tf
import time
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt

# Start time
start_time = time.time()

# Assume X_train and y_train are the original splits

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension
X_train_resized = np.repeat(X_train_resized, 3, axis=-1)  # Repeat the channel dimension to match the expected input shape

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)
X_test_resized = np.repeat(X_test_resized, 3, axis=-1)

# Define the input shape
input_shape = (224, 224, 3)

# Define the CNN base model
input_layer = Input(shape=input_shape)
conv1 = Conv2D(32, kernel_size=(3, 3), activation='relu')(input_layer)
pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
conv2 = Conv2D(64, kernel_size=(3, 3), activation='relu')(pool1)
pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
flatten = Flatten()(pool2)

# Define the LSTM layer
reshape = Reshape((1, -1))(flatten)
lstm = LSTM(128)(reshape)

# Define the dense layers for classification
dense1 = Dense(64, activation='relu')(lstm)
output_layer = Dense(1, activation='sigmoid')(dense1)

# Create the model
model = Model(inputs=input_layer, outputs=output_layer)

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Display model summary
model.summary()

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model
history = model.fit(X_train_resized, y_train, epochs=50, validation_data=(X_test_resized, y_test), callbacks=[early_stopping])

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test_resized, y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')

# Confusion matrix
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
print("Confusion Matrix:")
print(conf_matrix)

# Generate classification report
print("Classification Report:")
print(classification_report(y_test, test_predictions))

# ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, test_predictions)
roc_auc = roc_auc_score(y_test, test_predictions)
print(f'AUC Score: {roc_auc:.2f}')

# Calculate Precision, Recall, F1 Score
precision = precision_score(y_test, test_predictions)
recall = recall_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)

# Print additional metrics
print("\nPrecision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)

# Calculate Cohen's Kappa Coefficient
kappa = cohen_kappa_score(y_test, test_predictions)
print(f"Cohen's Kappa Coefficient: {kappa:.2f}")

# Calculate Matthews Correlation Coefficient
mcc = matthews_corrcoef(y_test, test_predictions)
print(f"Matthews Correlation Coefficient (MCC): {mcc:.2f}")

# Calculate Balanced Accuracy
balanced_acc = balanced_accuracy_score(y_test, test_predictions)
print(f"Balanced Accuracy: {balanced_acc:.2f}")

# End time
end_time = time.time()

# Print the time taken
print(f"Time taken: {end_time - start_time:.2f} seconds")
# Out:
# Model: "functional_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_12 (InputLayer)     │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_36 (Conv2D)              │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_30 (MaxPooling2D) │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_37 (Conv2D)              │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_31 (MaxPooling2D) │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_6 (Flatten)             │ (None, 186624)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 1, 186624)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 128)            │    95,617,536 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_24 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 95,645,249 (364.86 MB)
#  Trainable params: 95,645,249 (364.86 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 24s 759ms/step - accuracy: 0.5037 - loss: 0.7637 - val_accuracy: 0.4917 - val_loss: 0.7045
# Epoch 2/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 22s 732ms/step - accuracy: 0.5110 - loss: 0.6972 - val_accuracy: 0.4917 - val_loss: 0.7364
# Epoch 3/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 22s 738ms/step - accuracy: 0.4745 - loss: 0.7126 - val_accuracy: 0.4917 - val_loss: 0.6932
# Epoch 4/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 22s 736ms/step - accuracy: 0.4950 - loss: 0.6947 - val_accuracy: 0.4917 - val_loss: 0.6932
# Epoch 5/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 22s 735ms/step - accuracy: 0.4638 - loss: 0.6941 - val_accuracy: 0.5083 - val_loss: 0.6931
# Epoch 6/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 22s 738ms/step - accuracy: 0.5303 - loss: 0.6954 - val_accuracy: 0.5083 - val_loss: 0.6930
# Epoch 7/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 22s 734ms/step - accuracy: 0.5213 - loss: 0.6952 - val_accuracy: 0.4917 - val_loss: 0.6993
# Epoch 8/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 22s 737ms/step - accuracy: 0.5048 - loss: 0.6966 - val_accuracy: 0.5083 - val_loss: 0.6936
# Epoch 9/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 22s 734ms/step - accuracy: 0.5168 - loss: 0.6931 - val_accuracy: 0.5083 - val_loss: 0.6933
# Epoch 9: early stopping
# Restoring model weights from the end of the best epoch: 6.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.5577 - loss: 0.6916
# Test Accuracy: 50.83%
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step
# Confusion Matrix:
# [[122   0]
#  [118   0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.51      1.00      0.67       122
#            1       0.00      0.00      0.00       118
#
#     accuracy                           0.51       240
#    macro avg       0.25      0.50      0.34       240
# weighted avg       0.26      0.51      0.34       240
#
# AUC Score: 0.50
#
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
# Cohen's Kappa Coefficient: 0.00
# Matthews Correlation Coefficient (MCC): 0.00
# Balanced Accuracy: 0.50
# Time taken: 202.88 seconds

# %%
import numpy as np
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, LSTM, Dense, Reshape
from tensorflow.keras.models import Model
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_recall_curve, auc, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import cv2
import tensorflow as tf
import time
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt

# Start time
start_time = time.time()

# Assume X_train and y_train are the original splits

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension
X_train_resized = np.repeat(X_train_resized, 3, axis=-1)  # Repeat the channel dimension to match the expected input shape

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)
X_test_resized = np.repeat(X_test_resized, 3, axis=-1)

# Define the input shape
input_shape = (224, 224, 3)

# Define the CNN base model
input_layer = Input(shape=input_shape)
conv1 = Conv2D(32, kernel_size=(3, 3), activation='relu')(input_layer)
pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
conv2 = Conv2D(64, kernel_size=(3, 3), activation='relu')(pool1)
pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
flatten = Flatten()(pool2)

# Define the LSTM layer
reshape = Reshape((1, -1))(flatten)
lstm = LSTM(128)(reshape)

# Define the dense layers for classification
dense1 = Dense(64, activation='relu')(lstm)
output_layer = Dense(1, activation='sigmoid')(dense1)

# Create the model
model = Model(inputs=input_layer, outputs=output_layer)

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Display model summary
model.summary()

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model
history = model.fit(X_train_resized, y_train, epochs=150, validation_data=(X_test_resized, y_test), callbacks=[early_stopping])

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test_resized, y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')

# Confusion matrix
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
print("Confusion Matrix:")
print(conf_matrix)

# Generate classification report
print("Classification Report:")
print(classification_report(y_test, test_predictions))

# ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, test_predictions)
roc_auc = roc_auc_score(y_test, test_predictions)
print(f'AUC Score: {roc_auc:.2f}')

# Calculate Precision, Recall, F1 Score
precision = precision_score(y_test, test_predictions)
recall = recall_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)

# Print additional metrics
print("\nPrecision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)

# Calculate Cohen's Kappa Coefficient
kappa = cohen_kappa_score(y_test, test_predictions)
print(f"Cohen's Kappa Coefficient: {kappa:.2f}")

# Calculate Matthews Correlation Coefficient
mcc = matthews_corrcoef(y_test, test_predictions)
print(f"Matthews Correlation Coefficient (MCC): {mcc:.2f}")

# Calculate Balanced Accuracy
balanced_acc = balanced_accuracy_score(y_test, test_predictions)
print(f"Balanced Accuracy: {balanced_acc:.2f}")

# End time
end_time = time.time()

# Print the time taken
print(f"Time taken: {end_time - start_time:.2f} seconds")
# Out:
# Model: "functional_13"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_13 (InputLayer)     │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_38 (Conv2D)              │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_32 (MaxPooling2D) │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_39 (Conv2D)              │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_33 (MaxPooling2D) │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_7 (Flatten)             │ (None, 186624)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_1 (Reshape)             │ (None, 1, 186624)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 128)            │    95,617,536 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_26 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_27 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 95,645,249 (364.86 MB)
#  Trainable params: 95,645,249 (364.86 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 23s 756ms/step - accuracy: 0.5145 - loss: 0.7327 - val_accuracy: 0.5083 - val_loss: 0.6930
# Epoch 2/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 22s 732ms/step - accuracy: 0.4795 - loss: 0.6990 - val_accuracy: 0.5083 - val_loss: 0.6930
# Epoch 3/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 22s 730ms/step - accuracy: 0.5161 - loss: 0.6940 - val_accuracy: 0.4917 - val_loss: 0.7001
# Epoch 4/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 22s 740ms/step - accuracy: 0.4640 - loss: 0.6995 - val_accuracy: 0.5083 - val_loss: 0.6931
# Epoch 4: early stopping
# Restoring model weights from the end of the best epoch: 1.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.5577 - loss: 0.6915
# Test Accuracy: 50.83%
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step
# Confusion Matrix:
# [[122   0]
#  [118   0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.51      1.00      0.67       122
#            1       0.00      0.00      0.00       118
#
#     accuracy                           0.51       240
#    macro avg       0.25      0.50      0.34       240
# weighted avg       0.26      0.51      0.34       240
#
# AUC Score: 0.50
#
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
# Cohen's Kappa Coefficient: 0.00
# Matthews Correlation Coefficient (MCC): 0.00
# Balanced Accuracy: 0.50
# Time taken: 91.77 seconds

# %%
import numpy as np
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, LSTM, Dense, Reshape
from tensorflow.keras.models import Model
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_recall_curve, auc, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import cv2
import tensorflow as tf
import time
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt

# Start time
start_time = time.time()

# Assume X_train and y_train are the original splits

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension
X_train_resized = np.repeat(X_train_resized, 3, axis=-1)  # Repeat the channel dimension to match the expected input shape

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)
X_test_resized = np.repeat(X_test_resized, 3, axis=-1)

# Define the input shape
input_shape = (224, 224, 3)

# Define the CNN base model
input_layer = Input(shape=input_shape)
conv1 = Conv2D(32, kernel_size=(3, 3), activation='relu')(input_layer)
pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
conv2 = Conv2D(64, kernel_size=(3, 3), activation='relu')(pool1)
pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
flatten = Flatten()(pool2)

# Define the LSTM layer
reshape = Reshape((1, -1))(flatten)
lstm = LSTM(128)(reshape)

# Define the dense layers for classification
dense1 = Dense(64, activation='relu')(lstm)
output_layer = Dense(1, activation='sigmoid')(dense1)

# Create the model
model = Model(inputs=input_layer, outputs=output_layer)

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Display model summary
model.summary()

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model
history = model.fit(X_train_resized, y_train, epochs=200, validation_data=(X_test_resized, y_test), callbacks=[early_stopping])

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test_resized, y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')

# Confusion matrix
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
print("Confusion Matrix:")
print(conf_matrix)

# Generate classification report
print("Classification Report:")
print(classification_report(y_test, test_predictions))

# ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, test_predictions)
roc_auc = roc_auc_score(y_test, test_predictions)
print(f'AUC Score: {roc_auc:.2f}')

# Calculate Precision, Recall, F1 Score
precision = precision_score(y_test, test_predictions)
recall = recall_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)

# Print additional metrics
print("\nPrecision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)

# Calculate Cohen's Kappa Coefficient
kappa = cohen_kappa_score(y_test, test_predictions)
print(f"Cohen's Kappa Coefficient: {kappa:.2f}")

# Calculate Matthews Correlation Coefficient
mcc = matthews_corrcoef(y_test, test_predictions)
print(f"Matthews Correlation Coefficient (MCC): {mcc:.2f}")

# Calculate Balanced Accuracy
balanced_acc = balanced_accuracy_score(y_test, test_predictions)
print(f"Balanced Accuracy: {balanced_acc:.2f}")

# End time
end_time = time.time()

# Print the time taken
print(f"Time taken: {end_time - start_time:.2f} seconds")
# Out:
# Model: "functional_14"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_14 (InputLayer)     │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_40 (Conv2D)              │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_34 (MaxPooling2D) │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_41 (Conv2D)              │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_35 (MaxPooling2D) │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_8 (Flatten)             │ (None, 186624)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_2 (Reshape)             │ (None, 1, 186624)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 128)            │    95,617,536 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_28 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_29 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 95,645,249 (364.86 MB)
#  Trainable params: 95,645,249 (364.86 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 24s 758ms/step - accuracy: 0.4854 - loss: 0.7484 - val_accuracy: 0.5083 - val_loss: 0.6930
# Epoch 2/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 22s 732ms/step - accuracy: 0.5005 - loss: 0.6966 - val_accuracy: 0.5083 - val_loss: 0.7006
# Epoch 3/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 22s 733ms/step - accuracy: 0.5060 - loss: 0.6981 - val_accuracy: 0.4917 - val_loss: 0.7050
# Epoch 4/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 22s 737ms/step - accuracy: 0.4847 - loss: 0.7035 - val_accuracy: 0.4917 - val_loss: 0.6972
# Epoch 4: early stopping
# Restoring model weights from the end of the best epoch: 1.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.5577 - loss: 0.6908
# Test Accuracy: 50.83%
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step
# Confusion Matrix:
# [[122   0]
#  [118   0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.51      1.00      0.67       122
#            1       0.00      0.00      0.00       118
#
#     accuracy                           0.51       240
#    macro avg       0.25      0.50      0.34       240
# weighted avg       0.26      0.51      0.34       240
#
# AUC Score: 0.50
#
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
# Cohen's Kappa Coefficient: 0.00
# Matthews Correlation Coefficient (MCC): 0.00
# Balanced Accuracy: 0.50
# Time taken: 92.27 seconds

# %% [markdown]
# # GRU + Dense Layers

# %%
import numpy as np
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, GRU, Dense, Reshape
from tensorflow.keras.models import Sequential
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import cv2
import time
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt

# Start time
start_time = time.time()

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension

X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)

# Create the model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 1)),  # Convolutional layer with 32 filters and 3x3 kernel
    MaxPooling2D((2, 2)),  # Max pooling layer with 2x2 pool size
    Conv2D(64, (3, 3), activation='relu'),  # Convolutional layer with 64 filters and 3x3 kernel
    MaxPooling2D((2, 2)),  # Max pooling layer with 2x2 pool size
    Conv2D(128, (3, 3), activation='relu'),  # Convolutional layer with 128 filters and 3x3 kernel
    MaxPooling2D((2, 2)),  # Max pooling layer with 2x2 pool size
    Conv2D(256, (3, 3), activation='relu'),  # Convolutional layer with 256 filters and 3x3 kernel
    MaxPooling2D((2, 2)),  # Max pooling layer with 2x2 pool size
    Flatten(),  # Flatten layer to flatten the output of the convolutional layers
    Reshape((1, -1)),  # Reshape to 3D tensor for GRU
    GRU(128),  # GRU layer with 128 units
    Dense(1, activation='sigmoid')  # Dense layer for binary classification
])

# Compile the model with Adam optimizer
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      tf.keras.metrics.TruePositives(),
                                                                      tf.keras.metrics.FalsePositives(),
                                                                      tf.keras.metrics.TrueNegatives(),
                                                                      tf.keras.metrics.FalseNegatives()])

# Display model summary
model.summary()

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model with early stopping and 50 epochs
history = model.fit(X_train_resized, y_train, epochs=50, validation_data=(X_test_resized, y_test), callbacks=[early_stopping])

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
test_loss, test_accuracy, precision, recall, auc_roc, auc_pr, tp, fp, tn, fn = model.evaluate(X_test_resized, y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
print(f'AUC-ROC: {auc_roc:.2f}')
print(f'AUC-PR: {auc_pr:.2f}')
print(f'TP: {tp}, FP: {fp}, TN: {tn}, FN: {fn}')

# Confusion matrix
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
print("Confusion Matrix:")
print(conf_matrix)

# Generate classification report
print("Classification Report:")
print(classification_report(y_test, test_predictions))

# ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, test_predictions)
roc_auc = roc_auc_score(y_test, test_predictions)
print(f'AUC Score: {roc_auc:.2f}')

# Calculate Precision, Recall, F1 Score
precision = precision_score(y_test, test_predictions)
recall = recall_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)

# Print additional metrics
print("\nPrecision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)

# End time
end_time = time.time()

# Print the time taken
print(f"Time taken: {end_time - start_time:.2f} seconds")
# Out:
# Model: "sequential_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_42 (Conv2D)              │ (None, 222, 222, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_36 (MaxPooling2D) │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_43 (Conv2D)              │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_37 (MaxPooling2D) │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_44 (Conv2D)              │ (None, 52, 52, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_38 (MaxPooling2D) │ (None, 26, 26, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_45 (Conv2D)              │ (None, 24, 24, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_39 (MaxPooling2D) │ (None, 12, 12, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_9 (Flatten)             │ (None, 36864)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_3 (Reshape)             │ (None, 1, 36864)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru (GRU)                       │ (None, 128)            │    14,205,696 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_30 (Dense)                │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,593,665 (55.67 MB)
#  Trainable params: 14,593,665 (55.67 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 12s 375ms/step - accuracy: 0.4933 - auc_24: 0.4851 - auc_25: 0.4906 - false_negatives_9: 138.3548 - false_positives_9: 125.7742 - loss: 0.8531 - precision_12: 0.5325 - recall_12: 0.4096 - true_negatives_9: 131.3548 - true_positives_9: 115.4839 - val_accuracy: 0.4917 - val_auc_24: 0.4396 - val_auc_25: 0.4322 - val_false_negatives_9: 0.0000e+00 - val_false_positives_9: 122.0000 - val_loss: 0.6936 - val_precision_12: 0.4917 - val_recall_12: 1.0000 - val_true_negatives_9: 0.0000e+00 - val_true_positives_9: 118.0000
# Epoch 2/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 346ms/step - accuracy: 0.4772 - auc_24: 0.4912 - auc_25: 0.4841 - false_negatives_9: 101.8710 - false_positives_9: 166.3871 - loss: 0.6943 - precision_12: 0.4738 - recall_12: 0.6974 - true_negatives_9: 93.6452 - true_positives_9: 149.0645 - val_accuracy: 0.4917 - val_auc_24: 0.6056 - val_auc_25: 0.5530 - val_false_negatives_9: 0.0000e+00 - val_false_positives_9: 122.0000 - val_loss: 0.6935 - val_precision_12: 0.4917 - val_recall_12: 1.0000 - val_true_negatives_9: 0.0000e+00 - val_true_positives_9: 118.0000
# Epoch 3/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 348ms/step - accuracy: 0.5065 - auc_24: 0.5385 - auc_25: 0.5264 - false_negatives_9: 38.1936 - false_positives_9: 208.0968 - loss: 0.6930 - precision_12: 0.5028 - recall_12: 0.8854 - true_negatives_9: 46.4516 - true_positives_9: 218.2258 - val_accuracy: 0.5083 - val_auc_24: 0.6823 - val_auc_25: 0.6693 - val_false_negatives_9: 118.0000 - val_false_positives_9: 0.0000e+00 - val_loss: 0.6919 - val_precision_12: 0.0000e+00 - val_recall_12: 0.0000e+00 - val_true_negatives_9: 122.0000 - val_true_positives_9: 0.0000e+00
# Epoch 4/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 344ms/step - accuracy: 0.5444 - auc_24: 0.5971 - auc_25: 0.5756 - false_negatives_9: 161.8387 - false_positives_9: 66.3226 - loss: 0.6832 - precision_12: 0.5014 - recall_12: 0.2945 - true_negatives_9: 196.6774 - true_positives_9: 86.1290 - val_accuracy: 0.5000 - val_auc_24: 0.7019 - val_auc_25: 0.7199 - val_false_negatives_9: 0.0000e+00 - val_false_positives_9: 120.0000 - val_loss: 0.6950 - val_precision_12: 0.4958 - val_recall_12: 1.0000 - val_true_negatives_9: 2.0000 - val_true_positives_9: 118.0000
# Epoch 5/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 345ms/step - accuracy: 0.5740 - auc_24: 0.6292 - auc_25: 0.6481 - false_negatives_9: 67.7742 - false_positives_9: 144.6774 - loss: 0.6753 - precision_12: 0.5671 - recall_12: 0.7982 - true_negatives_9: 103.0323 - true_positives_9: 195.4839 - val_accuracy: 0.6375 - val_auc_24: 0.7085 - val_auc_25: 0.7630 - val_false_negatives_9: 45.0000 - val_false_positives_9: 42.0000 - val_loss: 0.6441 - val_precision_12: 0.6348 - val_recall_12: 0.6186 - val_true_negatives_9: 80.0000 - val_true_positives_9: 73.0000
# Epoch 6/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 344ms/step - accuracy: 0.5994 - auc_24: 0.6435 - auc_25: 0.6701 - false_negatives_9: 113.3226 - false_positives_9: 85.4516 - loss: 0.6561 - precision_12: 0.6194 - recall_12: 0.5207 - true_negatives_9: 163.6129 - true_positives_9: 148.5806 - val_accuracy: 0.5208 - val_auc_24: 0.5958 - val_auc_25: 0.6594 - val_false_negatives_9: 115.0000 - val_false_positives_9: 0.0000e+00 - val_loss: 0.7484 - val_precision_12: 1.0000 - val_recall_12: 0.0254 - val_true_negatives_9: 122.0000 - val_true_positives_9: 3.0000
# Epoch 7/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 347ms/step - accuracy: 0.4709 - auc_24: 0.5342 - auc_25: 0.5989 - false_negatives_9: 97.9677 - false_positives_9: 169.6774 - loss: 0.7170 - precision_12: 0.4075 - recall_12: 0.4787 - true_negatives_9: 79.1290 - true_positives_9: 164.1935 - val_accuracy: 0.4917 - val_auc_24: 0.6733 - val_auc_25: 0.6968 - val_false_negatives_9: 0.0000e+00 - val_false_positives_9: 122.0000 - val_loss: 0.6890 - val_precision_12: 0.4917 - val_recall_12: 1.0000 - val_true_negatives_9: 0.0000e+00 - val_true_positives_9: 118.0000
# Epoch 8/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 343ms/step - accuracy: 0.5090 - auc_24: 0.6116 - auc_25: 0.6404 - false_negatives_9: 0.0000e+00 - false_positives_9: 254.1613 - loss: 0.6847 - precision_12: 0.5090 - recall_12: 1.0000 - true_negatives_9: 0.0000e+00 - true_positives_9: 256.8065 - val_accuracy: 0.4917 - val_auc_24: 0.6944 - val_auc_25: 0.7157 - val_false_negatives_9: 0.0000e+00 - val_false_positives_9: 122.0000 - val_loss: 0.6805 - val_precision_12: 0.4917 - val_recall_12: 1.0000 - val_true_negatives_9: 0.0000e+00 - val_true_positives_9: 118.0000
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 5.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.6574 - auc_24: 0.7238 - auc_25: 0.7374 - false_negatives_9: 25.2222 - false_positives_9: 27.7778 - loss: 0.6428 - precision_12: 0.6051 - recall_12: 0.6461 - true_negatives_9: 54.6667 - true_positives_9: 45.2222
# Test Accuracy: 63.75%
# Precision: 0.63
# Recall: 0.62
# AUC-ROC: 0.71
# AUC-PR: 0.76
# TP: 73.0, FP: 42.0, TN: 80.0, FN: 45.0
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step
# Confusion Matrix:
# [[80 42]
#  [45 73]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.64      0.66      0.65       122
#            1       0.63      0.62      0.63       118
#
#     accuracy                           0.64       240
#    macro avg       0.64      0.64      0.64       240
# weighted avg       0.64      0.64      0.64       240
#
# AUC Score: 0.64
#
# Precision: 0.6347826086956522
# Recall: 0.6186440677966102
# F1 Score: 0.6266094420600858
# Time taken: 87.13 seconds

# %%
import numpy as np
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, GRU, Dense, Reshape
from tensorflow.keras.models import Sequential
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import cv2
import time
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt

# Start time
start_time = time.time()

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension

X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)

# Create the model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 1)),  # Convolutional layer with 32 filters and 3x3 kernel
    MaxPooling2D((2, 2)),  # Max pooling layer with 2x2 pool size
    Conv2D(64, (3, 3), activation='relu'),  # Convolutional layer with 64 filters and 3x3 kernel
    MaxPooling2D((2, 2)),  # Max pooling layer with 2x2 pool size
    Conv2D(128, (3, 3), activation='relu'),  # Convolutional layer with 128 filters and 3x3 kernel
    MaxPooling2D((2, 2)),  # Max pooling layer with 2x2 pool size
    Conv2D(256, (3, 3), activation='relu'),  # Convolutional layer with 256 filters and 3x3 kernel
    MaxPooling2D((2, 2)),  # Max pooling layer with 2x2 pool size
    Flatten(),  # Flatten layer to flatten the output of the convolutional layers
    Reshape((1, -1)),  # Reshape to 3D tensor for GRU
    GRU(128),  # GRU layer with 128 units
    Dense(1, activation='sigmoid')  # Dense layer for binary classification
])

# Compile the model with Adam optimizer
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      tf.keras.metrics.TruePositives(),
                                                                      tf.keras.metrics.FalsePositives(),
                                                                      tf.keras.metrics.TrueNegatives(),
                                                                      tf.keras.metrics.FalseNegatives()])

# Display model summary
model.summary()

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model with early stopping and 50 epochs
history = model.fit(X_train_resized, y_train, epochs=150, validation_data=(X_test_resized, y_test), callbacks=[early_stopping])

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
test_loss, test_accuracy, precision, recall, auc_roc, auc_pr, tp, fp, tn, fn = model.evaluate(X_test_resized, y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
print(f'AUC-ROC: {auc_roc:.2f}')
print(f'AUC-PR: {auc_pr:.2f}')
print(f'TP: {tp}, FP: {fp}, TN: {tn}, FN: {fn}')

# Confusion matrix
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
print("Confusion Matrix:")
print(conf_matrix)

# Generate classification report
print("Classification Report:")
print(classification_report(y_test, test_predictions))

# ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, test_predictions)
roc_auc = roc_auc_score(y_test, test_predictions)
print(f'AUC Score: {roc_auc:.2f}')

# Calculate Precision, Recall, F1 Score
precision = precision_score(y_test, test_predictions)
recall = recall_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)

# Print additional metrics
print("\nPrecision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)

# End time
end_time = time.time()

# Print the time taken
print(f"Time taken: {end_time - start_time:.2f} seconds")
# Out:
# Model: "sequential_13"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_46 (Conv2D)              │ (None, 222, 222, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_40 (MaxPooling2D) │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_47 (Conv2D)              │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_41 (MaxPooling2D) │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_48 (Conv2D)              │ (None, 52, 52, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_42 (MaxPooling2D) │ (None, 26, 26, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_49 (Conv2D)              │ (None, 24, 24, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_43 (MaxPooling2D) │ (None, 12, 12, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_10 (Flatten)            │ (None, 36864)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_4 (Reshape)             │ (None, 1, 36864)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 128)            │    14,205,696 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_31 (Dense)                │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,593,665 (55.67 MB)
#  Trainable params: 14,593,665 (55.67 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 12s 363ms/step - accuracy: 0.4605 - auc_26: 0.4634 - auc_27: 0.4749 - false_negatives_10: 115.5484 - false_positives_10: 154.9032 - loss: 0.7858 - precision_13: 0.4707 - recall_13: 0.5510 - true_negatives_10: 96.6774 - true_positives_10: 143.8387 - val_accuracy: 0.5125 - val_auc_26: 0.6261 - val_auc_27: 0.6135 - val_false_negatives_10: 117.0000 - val_false_positives_10: 0.0000e+00 - val_loss: 0.6910 - val_precision_13: 1.0000 - val_recall_13: 0.0085 - val_true_negatives_10: 122.0000 - val_true_positives_10: 1.0000
# Epoch 2/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 352ms/step - accuracy: 0.5213 - auc_26: 0.5550 - auc_27: 0.5631 - false_negatives_10: 182.5161 - false_positives_10: 58.8064 - loss: 0.6903 - precision_13: 0.4043 - recall_13: 0.1967 - true_negatives_10: 196.6129 - true_positives_10: 73.0323 - val_accuracy: 0.5083 - val_auc_26: 0.6790 - val_auc_27: 0.7071 - val_false_negatives_10: 118.0000 - val_false_positives_10: 0.0000e+00 - val_loss: 0.6908 - val_precision_13: 0.0000e+00 - val_recall_13: 0.0000e+00 - val_true_negatives_10: 122.0000 - val_true_positives_10: 0.0000e+00
# Epoch 3/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 351ms/step - accuracy: 0.4980 - auc_26: 0.5640 - auc_27: 0.6122 - false_negatives_10: 103.1613 - false_positives_10: 142.4516 - loss: 0.6987 - precision_13: 0.4709 - recall_13: 0.5112 - true_negatives_10: 108.6129 - true_positives_10: 156.7419 - val_accuracy: 0.5583 - val_auc_26: 0.7219 - val_auc_27: 0.7619 - val_false_negatives_10: 106.0000 - val_false_positives_10: 0.0000e+00 - val_loss: 0.6870 - val_precision_13: 1.0000 - val_recall_13: 0.1017 - val_true_negatives_10: 122.0000 - val_true_positives_10: 12.0000
# Epoch 4/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 349ms/step - accuracy: 0.6030 - auc_26: 0.6554 - auc_27: 0.6468 - false_negatives_10: 110.7419 - false_positives_10: 87.1936 - loss: 0.6602 - precision_13: 0.6219 - recall_13: 0.5154 - true_negatives_10: 173.2903 - true_positives_10: 139.7419 - val_accuracy: 0.6000 - val_auc_26: 0.7215 - val_auc_27: 0.7596 - val_false_negatives_10: 20.0000 - val_false_positives_10: 76.0000 - val_loss: 0.6420 - val_precision_13: 0.5632 - val_recall_13: 0.8305 - val_true_negatives_10: 46.0000 - val_true_positives_10: 98.0000
# Epoch 5/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 348ms/step - accuracy: 0.6215 - auc_26: 0.6826 - auc_27: 0.7042 - false_negatives_10: 80.0968 - false_positives_10: 109.4516 - loss: 0.6460 - precision_13: 0.6100 - recall_13: 0.7340 - true_negatives_10: 145.3548 - true_positives_10: 176.0645 - val_accuracy: 0.6292 - val_auc_26: 0.7344 - val_auc_27: 0.7301 - val_false_negatives_10: 11.0000 - val_false_positives_10: 78.0000 - val_loss: 0.6605 - val_precision_13: 0.5784 - val_recall_13: 0.9068 - val_true_negatives_10: 44.0000 - val_true_positives_10: 107.0000
# Epoch 6/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 350ms/step - accuracy: 0.6101 - auc_26: 0.6811 - auc_27: 0.7247 - false_negatives_10: 118.9355 - false_positives_10: 76.5806 - loss: 0.6313 - precision_13: 0.6349 - recall_13: 0.5695 - true_negatives_10: 174.3548 - true_positives_10: 141.0968 - val_accuracy: 0.6500 - val_auc_26: 0.7171 - val_auc_27: 0.7478 - val_false_negatives_10: 41.0000 - val_false_positives_10: 43.0000 - val_loss: 0.6122 - val_precision_13: 0.6417 - val_recall_13: 0.6525 - val_true_negatives_10: 79.0000 - val_true_positives_10: 77.0000
# Epoch 7/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 352ms/step - accuracy: 0.6660 - auc_26: 0.7048 - auc_27: 0.6988 - false_negatives_10: 125.4516 - false_positives_10: 48.6452 - loss: 0.6216 - precision_13: 0.7043 - recall_13: 0.4958 - true_negatives_10: 216.8065 - true_positives_10: 120.0645 - val_accuracy: 0.6458 - val_auc_26: 0.7106 - val_auc_27: 0.7399 - val_false_negatives_10: 39.0000 - val_false_positives_10: 46.0000 - val_loss: 0.6324 - val_precision_13: 0.6320 - val_recall_13: 0.6695 - val_true_negatives_10: 76.0000 - val_true_positives_10: 79.0000
# Epoch 8/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 352ms/step - accuracy: 0.6646 - auc_26: 0.7129 - auc_27: 0.7586 - false_negatives_10: 101.0968 - false_positives_10: 71.9355 - loss: 0.6112 - precision_13: 0.6922 - recall_13: 0.6550 - true_negatives_10: 176.3871 - true_positives_10: 161.5484 - val_accuracy: 0.6125 - val_auc_26: 0.7011 - val_auc_27: 0.7381 - val_false_negatives_10: 27.0000 - val_false_positives_10: 66.0000 - val_loss: 0.6378 - val_precision_13: 0.5796 - val_recall_13: 0.7712 - val_true_negatives_10: 56.0000 - val_true_positives_10: 91.0000
# Epoch 9/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 356ms/step - accuracy: 0.6656 - auc_26: 0.7287 - auc_27: 0.7735 - false_negatives_10: 97.8064 - false_positives_10: 70.0323 - loss: 0.6074 - precision_13: 0.7103 - recall_13: 0.6212 - true_negatives_10: 176.9677 - true_positives_10: 166.1613 - val_accuracy: 0.6750 - val_auc_26: 0.7086 - val_auc_27: 0.7567 - val_false_negatives_10: 60.0000 - val_false_positives_10: 18.0000 - val_loss: 0.5937 - val_precision_13: 0.7632 - val_recall_13: 0.4915 - val_true_negatives_10: 104.0000 - val_true_positives_10: 58.0000
# Epoch 10/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 350ms/step - accuracy: 0.6499 - auc_26: 0.7290 - auc_27: 0.7627 - false_negatives_10: 121.6129 - false_positives_10: 55.9677 - loss: 0.5902 - precision_13: 0.7073 - recall_13: 0.5247 - true_negatives_10: 200.4516 - true_positives_10: 132.9355 - val_accuracy: 0.6417 - val_auc_26: 0.6794 - val_auc_27: 0.7174 - val_false_negatives_10: 71.0000 - val_false_positives_10: 15.0000 - val_loss: 0.6378 - val_precision_13: 0.7581 - val_recall_13: 0.3983 - val_true_negatives_10: 107.0000 - val_true_positives_10: 47.0000
# Epoch 11/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 356ms/step - accuracy: 0.6655 - auc_26: 0.7433 - auc_27: 0.7855 - false_negatives_10: 119.8064 - false_positives_10: 46.5161 - loss: 0.5881 - precision_13: 0.7719 - recall_13: 0.5209 - true_negatives_10: 204.0968 - true_positives_10: 140.5484 - val_accuracy: 0.6500 - val_auc_26: 0.6974 - val_auc_27: 0.7459 - val_false_negatives_10: 51.0000 - val_false_positives_10: 33.0000 - val_loss: 0.6233 - val_precision_13: 0.6700 - val_recall_13: 0.5678 - val_true_negatives_10: 89.0000 - val_true_positives_10: 67.0000
# Epoch 12/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 359ms/step - accuracy: 0.6888 - auc_26: 0.7896 - auc_27: 0.8079 - false_negatives_10: 109.2581 - false_positives_10: 48.3226 - loss: 0.5440 - precision_13: 0.7591 - recall_13: 0.5527 - true_negatives_10: 210.6129 - true_positives_10: 142.7742 - val_accuracy: 0.6708 - val_auc_26: 0.7053 - val_auc_27: 0.7434 - val_false_negatives_10: 56.0000 - val_false_positives_10: 23.0000 - val_loss: 0.6041 - val_precision_13: 0.7294 - val_recall_13: 0.5254 - val_true_negatives_10: 99.0000 - val_true_positives_10: 62.0000
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 9.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.7056 - auc_26: 0.7265 - auc_27: 0.7307 - false_negatives_10: 34.3333 - false_positives_10: 13.1111 - loss: 0.5862 - precision_13: 0.7287 - recall_13: 0.5331 - true_negatives_10: 69.3333 - true_positives_10: 36.1111
# Test Accuracy: 67.50%
# Precision: 0.76
# Recall: 0.49
# AUC-ROC: 0.71
# AUC-PR: 0.76
# TP: 58.0, FP: 18.0, TN: 104.0, FN: 60.0
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step
# Confusion Matrix:
# [[104  18]
#  [ 60  58]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.63      0.85      0.73       122
#            1       0.76      0.49      0.60       118
#
#     accuracy                           0.68       240
#    macro avg       0.70      0.67      0.66       240
# weighted avg       0.70      0.68      0.66       240
#
# AUC Score: 0.67
#
# Precision: 0.7631578947368421
# Recall: 0.4915254237288136
# F1 Score: 0.5979381443298969
# Time taken: 130.30 seconds

# %%
import numpy as np
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, GRU, Dense, Reshape
from tensorflow.keras.models import Sequential
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import cv2
import time
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt

# Start time
start_time = time.time()

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension

X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)

# Create the model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 1)),  # Convolutional layer with 32 filters and 3x3 kernel
    MaxPooling2D((2, 2)),  # Max pooling layer with 2x2 pool size
    Conv2D(64, (3, 3), activation='relu'),  # Convolutional layer with 64 filters and 3x3 kernel
    MaxPooling2D((2, 2)),  # Max pooling layer with 2x2 pool size
    Conv2D(128, (3, 3), activation='relu'),  # Convolutional layer with 128 filters and 3x3 kernel
    MaxPooling2D((2, 2)),  # Max pooling layer with 2x2 pool size
    Conv2D(256, (3, 3), activation='relu'),  # Convolutional layer with 256 filters and 3x3 kernel
    MaxPooling2D((2, 2)),  # Max pooling layer with 2x2 pool size
    Flatten(),  # Flatten layer to flatten the output of the convolutional layers
    Reshape((1, -1)),  # Reshape to 3D tensor for GRU
    GRU(128),  # GRU layer with 128 units
    Dense(1, activation='sigmoid')  # Dense layer for binary classification
])

# Compile the model with Adam optimizer
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy',
                                                                      tf.keras.metrics.Precision(),
                                                                      tf.keras.metrics.Recall(),
                                                                      tf.keras.metrics.AUC(),
                                                                      tf.keras.metrics.AUC(curve='PR'),
                                                                      tf.keras.metrics.TruePositives(),
                                                                      tf.keras.metrics.FalsePositives(),
                                                                      tf.keras.metrics.TrueNegatives(),
                                                                      tf.keras.metrics.FalseNegatives()])

# Display model summary
model.summary()

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model with early stopping and 50 epochs
history = model.fit(X_train_resized, y_train, epochs=200, validation_data=(X_test_resized, y_test), callbacks=[early_stopping])

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
test_loss, test_accuracy, precision, recall, auc_roc, auc_pr, tp, fp, tn, fn = model.evaluate(X_test_resized, y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
print(f'AUC-ROC: {auc_roc:.2f}')
print(f'AUC-PR: {auc_pr:.2f}')
print(f'TP: {tp}, FP: {fp}, TN: {tn}, FN: {fn}')

# Confusion matrix
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
print("Confusion Matrix:")
print(conf_matrix)

# Generate classification report
print("Classification Report:")
print(classification_report(y_test, test_predictions))

# ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, test_predictions)
roc_auc = roc_auc_score(y_test, test_predictions)
print(f'AUC Score: {roc_auc:.2f}')

# Calculate Precision, Recall, F1 Score
precision = precision_score(y_test, test_predictions)
recall = recall_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)

# Print additional metrics
print("\nPrecision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)

# End time
end_time = time.time()

# Print the time taken
print(f"Time taken: {end_time - start_time:.2f} seconds")
# Out:
# 2024-11-15 13:44:13.370762: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-11-15 13:44:13.375090: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-15 13:44:13.414672: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-15 13:44:13.453352: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1731658453.486007   38109 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1731658453.495231   38109 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-15 13:44:13.573586: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-15 13:44:14.640618: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 222, 222, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 52, 52, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 26, 26, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 24, 24, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 12, 12, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 36864)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 1, 36864)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru (GRU)                       │ (None, 128)            │    14,205,696 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,593,665 (55.67 MB)
#  Trainable params: 14,593,665 (55.67 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 12s 351ms/step - accuracy: 0.5235 - auc: 0.5067 - auc_1: 0.5044 - false_negatives: 92.6452 - false_positives: 155.1290 - loss: 0.8460 - precision: 0.4828 - recall: 0.5440 - true_negatives: 95.0645 - true_positives: 168.1290 - val_accuracy: 0.5083 - val_auc: 0.5721 - val_auc_1: 0.5771 - val_false_negatives: 118.0000 - val_false_positives: 0.0000e+00 - val_loss: 0.6917 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_true_negatives: 122.0000 - val_true_positives: 0.0000e+00
# Epoch 2/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 337ms/step - accuracy: 0.5204 - auc: 0.5355 - auc_1: 0.5315 - false_negatives: 174.8710 - false_positives: 70.4516 - loss: 0.6921 - precision: 0.7221 - recall: 0.2061 - true_negatives: 187.9032 - true_positives: 77.7419 - val_accuracy: 0.6083 - val_auc: 0.7112 - val_auc_1: 0.7544 - val_false_negatives: 27.0000 - val_false_positives: 67.0000 - val_loss: 0.6809 - val_precision: 0.5759 - val_recall: 0.7712 - val_true_negatives: 55.0000 - val_true_positives: 91.0000
# Epoch 3/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 354ms/step - accuracy: 0.5873 - auc: 0.6118 - auc_1: 0.5950 - false_negatives: 126.4194 - false_positives: 85.9677 - loss: 0.6813 - precision: 0.5973 - recall: 0.5129 - true_negatives: 170.3226 - true_positives: 128.2581 - val_accuracy: 0.6125 - val_auc: 0.7109 - val_auc_1: 0.7541 - val_false_negatives: 92.0000 - val_false_positives: 1.0000 - val_loss: 0.6684 - val_precision: 0.9630 - val_recall: 0.2203 - val_true_negatives: 121.0000 - val_true_positives: 26.0000
# Epoch 4/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 352ms/step - accuracy: 0.5870 - auc: 0.6400 - auc_1: 0.6458 - false_negatives: 72.9032 - false_positives: 139.2903 - loss: 0.6727 - precision: 0.5809 - recall: 0.6646 - true_negatives: 112.5806 - true_positives: 186.1935 - val_accuracy: 0.6083 - val_auc: 0.6970 - val_auc_1: 0.7418 - val_false_negatives: 92.0000 - val_false_positives: 2.0000 - val_loss: 0.6753 - val_precision: 0.9286 - val_recall: 0.2203 - val_true_negatives: 120.0000 - val_true_positives: 26.0000
# Epoch 5/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 349ms/step - accuracy: 0.5732 - auc: 0.6236 - auc_1: 0.6154 - false_negatives: 145.6774 - false_positives: 76.3548 - loss: 0.6846 - precision: 0.6041 - recall: 0.4262 - true_negatives: 185.0968 - true_positives: 103.8387 - val_accuracy: 0.4875 - val_auc: 0.6211 - val_auc_1: 0.6536 - val_false_negatives: 2.0000 - val_false_positives: 121.0000 - val_loss: 0.6947 - val_precision: 0.4895 - val_recall: 0.9831 - val_true_negatives: 1.0000 - val_true_positives: 116.0000
# Epoch 6/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 355ms/step - accuracy: 0.5650 - auc: 0.6222 - auc_1: 0.6607 - false_negatives: 86.5484 - false_positives: 130.5484 - loss: 0.6766 - precision: 0.5630 - recall: 0.7247 - true_negatives: 118.4194 - true_positives: 175.4516 - val_accuracy: 0.6708 - val_auc: 0.7055 - val_auc_1: 0.7494 - val_false_negatives: 56.0000 - val_false_positives: 23.0000 - val_loss: 0.6326 - val_precision: 0.7294 - val_recall: 0.5254 - val_true_negatives: 99.0000 - val_true_positives: 62.0000
# Epoch 7/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 353ms/step - accuracy: 0.6200 - auc: 0.6742 - auc_1: 0.7073 - false_negatives: 127.2258 - false_positives: 74.2258 - loss: 0.6407 - precision: 0.6585 - recall: 0.5329 - true_negatives: 177.3226 - true_positives: 132.1935 - val_accuracy: 0.6208 - val_auc: 0.6696 - val_auc_1: 0.7095 - val_false_negatives: 36.0000 - val_false_positives: 55.0000 - val_loss: 0.6610 - val_precision: 0.5985 - val_recall: 0.6949 - val_true_negatives: 67.0000 - val_true_positives: 82.0000
# Epoch 8/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 362ms/step - accuracy: 0.6091 - auc: 0.6854 - auc_1: 0.7086 - false_negatives: 85.8387 - false_positives: 115.3226 - loss: 0.6488 - precision: 0.5949 - recall: 0.7169 - true_negatives: 137.1613 - true_positives: 172.6452 - val_accuracy: 0.6583 - val_auc: 0.6917 - val_auc_1: 0.7500 - val_false_negatives: 75.0000 - val_false_positives: 7.0000 - val_loss: 0.6253 - val_precision: 0.8600 - val_recall: 0.3644 - val_true_negatives: 115.0000 - val_true_positives: 43.0000
# Epoch 9/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 362ms/step - accuracy: 0.6531 - auc: 0.7096 - auc_1: 0.7609 - false_negatives: 122.5484 - false_positives: 51.5484 - loss: 0.6221 - precision: 0.7719 - recall: 0.4977 - true_negatives: 200.7742 - true_positives: 136.0968 - val_accuracy: 0.5917 - val_auc: 0.6533 - val_auc_1: 0.6469 - val_false_negatives: 62.0000 - val_false_positives: 36.0000 - val_loss: 0.6590 - val_precision: 0.6087 - val_recall: 0.4746 - val_true_negatives: 86.0000 - val_true_positives: 56.0000
# Epoch 10/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 359ms/step - accuracy: 0.6534 - auc: 0.7199 - auc_1: 0.7433 - false_negatives: 111.0968 - false_positives: 64.8387 - loss: 0.6139 - precision: 0.6935 - recall: 0.5539 - true_negatives: 188.6129 - true_positives: 146.4194 - val_accuracy: 0.6542 - val_auc: 0.6895 - val_auc_1: 0.7355 - val_false_negatives: 77.0000 - val_false_positives: 6.0000 - val_loss: 0.6326 - val_precision: 0.8723 - val_recall: 0.3475 - val_true_negatives: 116.0000 - val_true_positives: 41.0000
# Epoch 11/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 360ms/step - accuracy: 0.6590 - auc: 0.7341 - auc_1: 0.7641 - false_negatives: 108.0645 - false_positives: 63.3226 - loss: 0.5970 - precision: 0.7260 - recall: 0.5488 - true_negatives: 186.3548 - true_positives: 153.2258 - val_accuracy: 0.6542 - val_auc: 0.6529 - val_auc_1: 0.7212 - val_false_negatives: 75.0000 - val_false_positives: 8.0000 - val_loss: 0.6550 - val_precision: 0.8431 - val_recall: 0.3644 - val_true_negatives: 114.0000 - val_true_positives: 43.0000
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 8.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.6738 - auc: 0.7071 - auc_1: 0.7198 - false_negatives: 44.6667 - false_positives: 5.5556 - loss: 0.6026 - precision: 0.7949 - recall: 0.3471 - true_negatives: 76.8889 - true_positives: 25.7778
# Test Accuracy: 65.83%
# Precision: 0.86
# Recall: 0.36
# AUC-ROC: 0.69
# AUC-PR: 0.75
# TP: 43.0, FP: 7.0, TN: 115.0, FN: 75.0
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step
# Confusion Matrix:
# [[115   7]
#  [ 75  43]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.61      0.94      0.74       122
#            1       0.86      0.36      0.51       118
#
#     accuracy                           0.66       240
#    macro avg       0.73      0.65      0.62       240
# weighted avg       0.73      0.66      0.63       240
#
# AUC Score: 0.65
#
# Precision: 0.86
# Recall: 0.3644067796610169
# F1 Score: 0.5119047619047619
# Time taken: 120.14 seconds

# %% [markdown]
# # Attention mechanism

# %%
import numpy as np
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Attention, Multiply
from tensorflow.keras.models import Model
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import cv2
import time
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt

# Start time
start_time = time.time()

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)

# Define the custom CNN architecture with attention mechanism
input_layer = Input(shape=(224, 224, 1))
x = Conv2D(32, (3, 3), activation='relu')(input_layer)
x = MaxPooling2D((2, 2))(x)
x = Conv2D(64, (3, 3), activation='relu')(x)
x = MaxPooling2D((2, 2))(x)
x = Conv2D(128, (3, 3), activation='relu')(x)
x = MaxPooling2D((2, 2))(x)
x = Flatten()(x)
x = Dense(256, activation='relu')(x)
x = Dense(512, activation='relu')(x)
attention_probs = Dense(np.prod(x.shape[1:]), activation='softmax', name='attention_probs')(x)
attention_mul = Multiply()([x, attention_probs])
x = Dense(1, activation='sigmoid')(attention_mul)

# Create the model
model = Model(inputs=input_layer, outputs=x)

# Compile the model with Adam optimizer
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Display model summary
model.summary()

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model with early stopping and 50 epochs
history = model.fit(X_train_resized, y_train, epochs=50, validation_data=(X_test_resized, y_test), callbacks=[early_stopping])

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test_resized, y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')

# Confusion matrix
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
print("Confusion Matrix:")
print(conf_matrix)

# Generate classification report
print("Classification Report:")
print(classification_report(y_test, test_predictions))

# ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, test_predictions)
roc_auc = roc_auc_score(y_test, test_predictions)
print(f'AUC Score: {roc_auc:.2f}')

# Calculate Precision, Recall, F1 Score
precision = precision_score(y_test, test_predictions)
recall = recall_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)

# Print additional metrics
print("\nPrecision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)

# Calculate Cohen's Kappa Coefficient
kappa = cohen_kappa_score(y_test, test_predictions)
print(f"Cohen's Kappa Coefficient: {kappa:.2f}")

# Calculate Matthews Correlation Coefficient
mcc = matthews_corrcoef(y_test, test_predictions)
print(f"Matthews Correlation Coefficient (MCC): {mcc:.2f}")

# Calculate Balanced Accuracy
balanced_acc = balanced_accuracy_score(y_test, test_predictions)
print(f"Balanced Accuracy: {balanced_acc:.2f}")

# End time
end_time = time.time()

# Print the time taken
print(f"Time taken: {end_time - start_time:.2f} seconds")
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 222, 222,  │        320 │ input_layer_1[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 111, 111,  │          0 │ conv2d_4[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 109, 109,  │     18,496 │ max_pooling2d_4[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_5     │ (None, 54, 54,    │          0 │ conv2d_5[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 52, 52,    │     73,856 │ max_pooling2d_5[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_6     │ (None, 26, 26,    │          0 │ conv2d_6[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_1 (Flatten) │ (None, 86528)     │          0 │ max_pooling2d_6[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 256)       │ 22,151,424 │ flatten_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 512)       │    131,584 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attention_probs     │ (None, 512)       │    262,656 │ dense_2[0][0]     │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 512)       │          0 │ dense_2[0][0],    │
# │                     │                   │            │ attention_probs[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 1)         │        513 │ multiply[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 22,638,849 (86.36 MB)
#  Trainable params: 22,638,849 (86.36 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 361ms/step - accuracy: 0.5007 - loss: 0.6932 - val_accuracy: 0.4917 - val_loss: 0.6931
# Epoch 2/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 355ms/step - accuracy: 0.5050 - loss: 0.6931 - val_accuracy: 0.5125 - val_loss: 0.6929
# Epoch 3/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 355ms/step - accuracy: 0.5072 - loss: 0.6939 - val_accuracy: 0.5333 - val_loss: 0.6702
# Epoch 4/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 360ms/step - accuracy: 0.5310 - loss: 0.6878 - val_accuracy: 0.4917 - val_loss: 0.6933
# Epoch 5/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 353ms/step - accuracy: 0.4858 - loss: 0.6935 - val_accuracy: 0.4917 - val_loss: 0.6933
# Epoch 6/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 353ms/step - accuracy: 0.4945 - loss: 0.6933 - val_accuracy: 0.4917 - val_loss: 0.6934
# Epoch 6: early stopping
# Restoring model weights from the end of the best epoch: 3.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.5819 - loss: 0.6580
# Test Accuracy: 53.33%
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step
# Confusion Matrix:
# [[122   0]
#  [112   6]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.52      1.00      0.69       122
#            1       1.00      0.05      0.10       118
#
#     accuracy                           0.53       240
#    macro avg       0.76      0.53      0.39       240
# weighted avg       0.76      0.53      0.40       240
#
# AUC Score: 0.53
#
# Precision: 1.0
# Recall: 0.05084745762711865
# F1 Score: 0.0967741935483871
# Cohen's Kappa Coefficient: 0.05
# Matthews Correlation Coefficient (MCC): 0.16
# Balanced Accuracy: 0.53
# Time taken: 66.30 seconds

# %%
import numpy as np
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Attention, Multiply
from tensorflow.keras.models import Model
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import cv2
import time
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt

# Start time
start_time = time.time()

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)

# Define the custom CNN architecture with attention mechanism
input_layer = Input(shape=(224, 224, 1))
x = Conv2D(32, (3, 3), activation='relu')(input_layer)
x = MaxPooling2D((2, 2))(x)
x = Conv2D(64, (3, 3), activation='relu')(x)
x = MaxPooling2D((2, 2))(x)
x = Conv2D(128, (3, 3), activation='relu')(x)
x = MaxPooling2D((2, 2))(x)
x = Flatten()(x)
x = Dense(256, activation='relu')(x)
x = Dense(512, activation='relu')(x)
attention_probs = Dense(np.prod(x.shape[1:]), activation='softmax', name='attention_probs')(x)
attention_mul = Multiply()([x, attention_probs])
x = Dense(1, activation='sigmoid')(attention_mul)

# Create the model
model = Model(inputs=input_layer, outputs=x)

# Compile the model with Adam optimizer
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Display model summary
model.summary()

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model with early stopping and 50 epochs
history = model.fit(X_train_resized, y_train, epochs=150, validation_data=(X_test_resized, y_test), callbacks=[early_stopping])

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test_resized, y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')

# Confusion matrix
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
print("Confusion Matrix:")
print(conf_matrix)

# Generate classification report
print("Classification Report:")
print(classification_report(y_test, test_predictions))

# ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, test_predictions)
roc_auc = roc_auc_score(y_test, test_predictions)
print(f'AUC Score: {roc_auc:.2f}')

# Calculate Precision, Recall, F1 Score
precision = precision_score(y_test, test_predictions)
recall = recall_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)

# Print additional metrics
print("\nPrecision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)

# Calculate Cohen's Kappa Coefficient
kappa = cohen_kappa_score(y_test, test_predictions)
print(f"Cohen's Kappa Coefficient: {kappa:.2f}")

# Calculate Matthews Correlation Coefficient
mcc = matthews_corrcoef(y_test, test_predictions)
print(f"Matthews Correlation Coefficient (MCC): {mcc:.2f}")

# Calculate Balanced Accuracy
balanced_acc = balanced_accuracy_score(y_test, test_predictions)
print(f"Balanced Accuracy: {balanced_acc:.2f}")

# End time
end_time = time.time()

# Print the time taken
print(f"Time taken: {end_time - start_time:.2f} seconds")
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 222, 222,  │        320 │ input_layer_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_7     │ (None, 111, 111,  │          0 │ conv2d_7[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 109, 109,  │     18,496 │ max_pooling2d_7[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_8     │ (None, 54, 54,    │          0 │ conv2d_8[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 52, 52,    │     73,856 │ max_pooling2d_8[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_9     │ (None, 26, 26,    │          0 │ conv2d_9[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_2 (Flatten) │ (None, 86528)     │          0 │ max_pooling2d_9[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 256)       │ 22,151,424 │ flatten_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 512)       │    131,584 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attention_probs     │ (None, 512)       │    262,656 │ dense_5[0][0]     │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 512)       │          0 │ dense_5[0][0],    │
# │ (Multiply)          │                   │            │ attention_probs[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 1)         │        513 │ multiply_1[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 22,638,849 (86.36 MB)
#  Trainable params: 22,638,849 (86.36 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 357ms/step - accuracy: 0.5169 - loss: 0.6982 - val_accuracy: 0.4917 - val_loss: 0.6925
# Epoch 2/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 352ms/step - accuracy: 0.4823 - loss: 0.6927 - val_accuracy: 0.5083 - val_loss: 0.6931
# Epoch 3/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 352ms/step - accuracy: 0.5188 - loss: 0.6931 - val_accuracy: 0.4917 - val_loss: 0.6932
# Epoch 4/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 351ms/step - accuracy: 0.4985 - loss: 0.6932 - val_accuracy: 0.4917 - val_loss: 0.6932
# Epoch 4: early stopping
# Restoring model weights from the end of the best epoch: 1.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.4423 - loss: 0.6928
# Test Accuracy: 49.17%
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x771a632beef0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step
# Confusion Matrix:
# [[  0 122]
#  [  0 118]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       122
#            1       0.49      1.00      0.66       118
#
#     accuracy                           0.49       240
#    macro avg       0.25      0.50      0.33       240
# weighted avg       0.24      0.49      0.32       240
#
# AUC Score: 0.50
#
# Precision: 0.49166666666666664
# Recall: 1.0
# F1 Score: 0.659217877094972
# Cohen's Kappa Coefficient: 0.00
# Matthews Correlation Coefficient (MCC): 0.00
# Balanced Accuracy: 0.50
# Time taken: 44.74 seconds

# %%
import numpy as np
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Attention, Multiply
from tensorflow.keras.models import Model
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import cv2
import time
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt

# Start time
start_time = time.time()

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)

# Define the custom CNN architecture with attention mechanism
input_layer = Input(shape=(224, 224, 1))
x = Conv2D(32, (3, 3), activation='relu')(input_layer)
x = MaxPooling2D((2, 2))(x)
x = Conv2D(64, (3, 3), activation='relu')(x)
x = MaxPooling2D((2, 2))(x)
x = Conv2D(128, (3, 3), activation='relu')(x)
x = MaxPooling2D((2, 2))(x)
x = Flatten()(x)
x = Dense(256, activation='relu')(x)
x = Dense(512, activation='relu')(x)
attention_probs = Dense(np.prod(x.shape[1:]), activation='softmax', name='attention_probs')(x)
attention_mul = Multiply()([x, attention_probs])
x = Dense(1, activation='sigmoid')(attention_mul)

# Create the model
model = Model(inputs=input_layer, outputs=x)

# Compile the model with Adam optimizer
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Display model summary
model.summary()

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model with early stopping and 50 epochs
history = model.fit(X_train_resized, y_train, epochs=200, validation_data=(X_test_resized, y_test), callbacks=[early_stopping])

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test_resized, y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')

# Confusion matrix
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
print("Confusion Matrix:")
print(conf_matrix)

# Generate classification report
print("Classification Report:")
print(classification_report(y_test, test_predictions))

# ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, test_predictions)
roc_auc = roc_auc_score(y_test, test_predictions)
print(f'AUC Score: {roc_auc:.2f}')

# Calculate Precision, Recall, F1 Score
precision = precision_score(y_test, test_predictions)
recall = recall_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)

# Print additional metrics
print("\nPrecision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)

# Calculate Cohen's Kappa Coefficient
kappa = cohen_kappa_score(y_test, test_predictions)
print(f"Cohen's Kappa Coefficient: {kappa:.2f}")

# Calculate Matthews Correlation Coefficient
mcc = matthews_corrcoef(y_test, test_predictions)
print(f"Matthews Correlation Coefficient (MCC): {mcc:.2f}")

# Calculate Balanced Accuracy
balanced_acc = balanced_accuracy_score(y_test, test_predictions)
print(f"Balanced Accuracy: {balanced_acc:.2f}")

# End time
end_time = time.time()

# Print the time taken
print(f"Time taken: {end_time - start_time:.2f} seconds")
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 222, 222,  │        320 │ input_layer_3[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_10    │ (None, 111, 111,  │          0 │ conv2d_10[0][0]   │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 109, 109,  │     18,496 │ max_pooling2d_10… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_11    │ (None, 54, 54,    │          0 │ conv2d_11[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 52, 52,    │     73,856 │ max_pooling2d_11… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_12    │ (None, 26, 26,    │          0 │ conv2d_12[0][0]   │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_3 (Flatten) │ (None, 86528)     │          0 │ max_pooling2d_12… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 256)       │ 22,151,424 │ flatten_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 512)       │    131,584 │ dense_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attention_probs     │ (None, 512)       │    262,656 │ dense_8[0][0]     │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_2          │ (None, 512)       │          0 │ dense_8[0][0],    │
# │ (Multiply)          │                   │            │ attention_probs[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 1)         │        513 │ multiply_2[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 22,638,849 (86.36 MB)
#  Trainable params: 22,638,849 (86.36 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 357ms/step - accuracy: 0.5075 - loss: 0.6932 - val_accuracy: 0.4917 - val_loss: 0.6931
# Epoch 2/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 352ms/step - accuracy: 0.5028 - loss: 0.6935 - val_accuracy: 0.5333 - val_loss: 0.6886
# Epoch 3/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 353ms/step - accuracy: 0.5433 - loss: 0.6859 - val_accuracy: 0.5167 - val_loss: 0.6882
# Epoch 4/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 354ms/step - accuracy: 0.6010 - loss: 0.6729 - val_accuracy: 0.6417 - val_loss: 0.6696
# Epoch 5/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 352ms/step - accuracy: 0.6593 - loss: 0.6623 - val_accuracy: 0.4917 - val_loss: 0.6937
# Epoch 6/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 353ms/step - accuracy: 0.4940 - loss: 0.6936 - val_accuracy: 0.4917 - val_loss: 0.6937
# Epoch 7/200
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 353ms/step - accuracy: 0.5022 - loss: 0.6933 - val_accuracy: 0.4917 - val_loss: 0.6936
# Epoch 7: early stopping
# Restoring model weights from the end of the best epoch: 4.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.6451 - loss: 0.6613
# Test Accuracy: 64.17%
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x771a60610280> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step
# Confusion Matrix:
# [[82 40]
#  [46 72]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.64      0.67      0.66       122
#            1       0.64      0.61      0.63       118
#
#     accuracy                           0.64       240
#    macro avg       0.64      0.64      0.64       240
# weighted avg       0.64      0.64      0.64       240
#
# AUC Score: 0.64
#
# Precision: 0.6428571428571429
# Recall: 0.6101694915254238
# F1 Score: 0.6260869565217392
# Cohen's Kappa Coefficient: 0.28
# Matthews Correlation Coefficient (MCC): 0.28
# Balanced Accuracy: 0.64
# Time taken: 76.47 seconds

# %% [markdown]
# # Capsule Network

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.layers import Layer, Dense, Flatten, Input, Reshape, Conv2D, MaxPooling2D
from tensorflow.keras.models import Model
import cv2
import time
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping
import csv

# Define Capsule Layer
class CapsuleLayer(Layer):
    def __init__(self, num_capsule, dim_capsule, routings=3, **kwargs):
        super(CapsuleLayer, self).__init__(**kwargs)
        self.num_capsule = num_capsule
        self.dim_capsule = dim_capsule
        self.routings = routings

    def build(self, input_shape):
        input_dim_capsule = input_shape[-1]
        self.W = self.add_weight(shape=[input_dim_capsule, self.num_capsule * self.dim_capsule],
                                 initializer='glorot_uniform',
                                 name='W')

    def call(self, u_vecs):
        u_hat_vecs = tf.reduce_sum(tf.expand_dims(u_vecs, -1) * tf.expand_dims(self.W, 0), axis=-2)
        b = tf.zeros(shape=[tf.shape(u_hat_vecs)[0], self.num_capsule])
        for i in range(self.routings):
            c = tf.nn.softmax(b, axis=1)
            s_j = tf.reduce_sum(tf.multiply(c[:, :, None], u_hat_vecs), axis=1)
            v_j = self.squash(s_j)
            if i < self.routings - 1:
                b += tf.reduce_sum(tf.multiply(v_j[:, None, :], u_hat_vecs), axis=-1)
        return v_j

    def squash(self, s_j):
        s_squared_norm = tf.reduce_sum(tf.square(s_j), axis=-1, keepdims=True)
        scale = s_squared_norm / (1 + s_squared_norm) / tf.sqrt(s_squared_norm + tf.keras.backend.epsilon())
        return scale * s_j

# Start time
start_time = time.time()

# Placeholder data - replace with your actual training and testing data
X_train = np.random.rand(100, 100, 3)  # Example training data with shape (100, 100, 3)
y_train = np.random.randint(0, 2, size=100)  # Example training labels (binary)
X_test = np.random.rand(20, 100, 3)  # Example testing data with shape (20, 100, 3)
y_test = np.random.randint(0, 2, size=20)  # Example testing labels (binary)

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension
X_train_resized = np.repeat(X_train_resized, 3, axis=-1)  # Repeat the channel dimension to match the expected input shape of VGG16

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)
X_test_resized = np.repeat(X_test_resized, 3, axis=-1)

# Load pre-trained VGG16 model without top layers
vgg_base = tf.keras.applications.VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Add Capsule Network layer on top of VGG16
input_tensor = Input(shape=(224, 224, 3))
vgg_output = vgg_base(input_tensor)
flatten = Flatten()(vgg_output)
x = Dense(128, activation='relu')(flatten)
x = Reshape((-1, 128))(x)  # Reshape to 3D tensor for Capsule Network
capsule = CapsuleLayer(num_capsule=10, dim_capsule=16, routings=3)(x)  # Example: 10 capsules with dimension 16
capsule = Flatten()(capsule)  # Flatten the output
output = Dense(1, activation='sigmoid')(capsule)  # Use a single output unit for binary classification

# Create the full model
model = Model(inputs=input_tensor, outputs=output)

# Compile the model with Adam optimizer
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Display model summary
model.summary()

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model with early stopping and 50 epochs
history = model.fit(X_train_resized, y_train, epochs=50, validation_data=(X_test_resized, y_test), callbacks=[early_stopping])

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test_resized, y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')

# Confusion matrix
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
print("Confusion Matrix:")
print(conf_matrix)

# Generate classification report
print("Classification Report:")
print(classification_report(y_test, test_predictions))

# ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, test_predictions)
roc_auc = roc_auc_score(y_test, test_predictions)
print(f'AUC Score: {roc_auc:.2f}')

# Calculate Precision, Recall, F1 Score, Cohen's Kappa, Matthews Correlation Coefficient, and Balanced Accuracy
precision = precision_score(y_test, test_predictions)
recall = recall_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_acc = balanced_accuracy_score(y_test, test_predictions)

# Print additional metrics
print("\nPrecision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Cohen's Kappa Coefficient:", kappa)
print("Matthews Correlation Coefficient (MCC):", mcc)
print("Balanced Accuracy:", balanced_acc)

# Save the model predictions to a CSV file
csv_file = "model_predictions.csv"
with open(csv_file, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['True_Label', 'Predicted_Label'])
    writer.writerows(zip(y_test, test_predictions))

print("Model predictions saved to:", csv_file)

# End time
end_time = time.time()

# Print the time taken
print(f"Time taken: {end_time - start_time:.2f} seconds")
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ vgg16 (Functional)              │ (None, 7, 7, 512)      │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 128)            │     3,211,392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_1 (Reshape)             │ (None, 1, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ capsule_layer (CapsuleLayer)    │ (None, 160)            │        20,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_5 (Flatten)             │ (None, 160)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │           161 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,946,721 (68.46 MB)
#  Trainable params: 17,946,721 (68.46 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 18s 4s/step - accuracy: 0.5681 - loss: 0.6996 - val_accuracy: 0.4000 - val_loss: 0.7059
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 16s 4s/step - accuracy: 0.4062 - loss: 0.7033 - val_accuracy: 0.6000 - val_loss: 0.6825
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 16s 4s/step - accuracy: 0.5473 - loss: 0.6911 - val_accuracy: 0.6000 - val_loss: 0.6737
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 16s 4s/step - accuracy: 0.5525 - loss: 0.6912 - val_accuracy: 0.6000 - val_loss: 0.6730
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 16s 4s/step - accuracy: 0.5379 - loss: 0.6966 - val_accuracy: 0.6000 - val_loss: 0.6738
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 16s 4s/step - accuracy: 0.5358 - loss: 0.6948 - val_accuracy: 0.6000 - val_loss: 0.6738
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 17s 4s/step - accuracy: 0.5618 - loss: 0.6874 - val_accuracy: 0.6000 - val_loss: 0.6732
# Epoch 7: early stopping
# Restoring model weights from the end of the best epoch: 4.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 764ms/step - accuracy: 0.6000 - loss: 0.6730
# Test Accuracy: 60.00%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 871ms/step
# Confusion Matrix:
# [[12  0]
#  [ 8  0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.60      1.00      0.75        12
#            1       0.00      0.00      0.00         8
#
#     accuracy                           0.60        20
#    macro avg       0.30      0.50      0.38        20
# weighted avg       0.36      0.60      0.45        20
#
# AUC Score: 0.50
#
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
# Cohen's Kappa Coefficient: 0.0
# Matthews Correlation Coefficient (MCC): 0.0
# Balanced Accuracy: 0.5
# Model predictions saved to: model_predictions.csv
# Time taken: 117.02 seconds

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.layers import Layer, Dense, Flatten, Input, Reshape, Conv2D, MaxPooling2D
from tensorflow.keras.models import Model
import cv2
import time
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping
import csv

# Define Capsule Layer
class CapsuleLayer(Layer):
    def __init__(self, num_capsule, dim_capsule, routings=3, **kwargs):
        super(CapsuleLayer, self).__init__(**kwargs)
        self.num_capsule = num_capsule
        self.dim_capsule = dim_capsule
        self.routings = routings

    def build(self, input_shape):
        input_dim_capsule = input_shape[-1]
        self.W = self.add_weight(shape=[input_dim_capsule, self.num_capsule * self.dim_capsule],
                                 initializer='glorot_uniform',
                                 name='W')

    def call(self, u_vecs):
        u_hat_vecs = tf.reduce_sum(tf.expand_dims(u_vecs, -1) * tf.expand_dims(self.W, 0), axis=-2)
        b = tf.zeros(shape=[tf.shape(u_hat_vecs)[0], self.num_capsule])
        for i in range(self.routings):
            c = tf.nn.softmax(b, axis=1)
            s_j = tf.reduce_sum(tf.multiply(c[:, :, None], u_hat_vecs), axis=1)
            v_j = self.squash(s_j)
            if i < self.routings - 1:
                b += tf.reduce_sum(tf.multiply(v_j[:, None, :], u_hat_vecs), axis=-1)
        return v_j

    def squash(self, s_j):
        s_squared_norm = tf.reduce_sum(tf.square(s_j), axis=-1, keepdims=True)
        scale = s_squared_norm / (1 + s_squared_norm) / tf.sqrt(s_squared_norm + tf.keras.backend.epsilon())
        return scale * s_j

# Start time
start_time = time.time()

# Placeholder data - replace with your actual training and testing data
X_train = np.random.rand(100, 100, 3)  # Example training data with shape (100, 100, 3)
y_train = np.random.randint(0, 2, size=100)  # Example training labels (binary)
X_test = np.random.rand(20, 100, 3)  # Example testing data with shape (20, 100, 3)
y_test = np.random.randint(0, 2, size=20)  # Example testing labels (binary)

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension
X_train_resized = np.repeat(X_train_resized, 3, axis=-1)  # Repeat the channel dimension to match the expected input shape of VGG16

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)
X_test_resized = np.repeat(X_test_resized, 3, axis=-1)

# Load pre-trained VGG16 model without top layers
vgg_base = tf.keras.applications.VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Add Capsule Network layer on top of VGG16
input_tensor = Input(shape=(224, 224, 3))
vgg_output = vgg_base(input_tensor)
flatten = Flatten()(vgg_output)
x = Dense(128, activation='relu')(flatten)
x = Reshape((-1, 128))(x)  # Reshape to 3D tensor for Capsule Network
capsule = CapsuleLayer(num_capsule=10, dim_capsule=16, routings=3)(x)  # Example: 10 capsules with dimension 16
capsule = Flatten()(capsule)  # Flatten the output
output = Dense(1, activation='sigmoid')(capsule)  # Use a single output unit for binary classification

# Create the full model
model = Model(inputs=input_tensor, outputs=output)

# Compile the model with Adam optimizer
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Display model summary
model.summary()

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model with early stopping and 50 epochs
history = model.fit(X_train_resized, y_train, epochs=150, validation_data=(X_test_resized, y_test), callbacks=[early_stopping])

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test_resized, y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')

# Confusion matrix
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
print("Confusion Matrix:")
print(conf_matrix)

# Generate classification report
print("Classification Report:")
print(classification_report(y_test, test_predictions))

# ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, test_predictions)
roc_auc = roc_auc_score(y_test, test_predictions)
print(f'AUC Score: {roc_auc:.2f}')

# Calculate Precision, Recall, F1 Score, Cohen's Kappa, Matthews Correlation Coefficient, and Balanced Accuracy
precision = precision_score(y_test, test_predictions)
recall = recall_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_acc = balanced_accuracy_score(y_test, test_predictions)

# Print additional metrics
print("\nPrecision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Cohen's Kappa Coefficient:", kappa)
print("Matthews Correlation Coefficient (MCC):", mcc)
print("Balanced Accuracy:", balanced_acc)

# Save the model predictions to a CSV file
csv_file = "model_predictions.csv"
with open(csv_file, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['True_Label', 'Predicted_Label'])
    writer.writerows(zip(y_test, test_predictions))

print("Model predictions saved to:", csv_file)

# End time
end_time = time.time()

# Print the time taken
print(f"Time taken: {end_time - start_time:.2f} seconds")
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_7 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ vgg16 (Functional)              │ (None, 7, 7, 512)      │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_6 (Flatten)             │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 128)            │     3,211,392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_2 (Reshape)             │ (None, 1, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ capsule_layer_1 (CapsuleLayer)  │ (None, 160)            │        20,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_7 (Flatten)             │ (None, 160)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 1)              │           161 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,946,721 (68.46 MB)
#  Trainable params: 17,946,721 (68.46 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 18s 4s/step - accuracy: 0.5156 - loss: 0.6999 - val_accuracy: 0.7000 - val_loss: 0.6728
# Epoch 2/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 16s 4s/step - accuracy: 0.5657 - loss: 0.6893 - val_accuracy: 0.7000 - val_loss: 0.6479
# Epoch 3/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 16s 4s/step - accuracy: 0.5500 - loss: 0.6888 - val_accuracy: 0.7000 - val_loss: 0.6350
# Epoch 4/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 17s 4s/step - accuracy: 0.5646 - loss: 0.6877 - val_accuracy: 0.7000 - val_loss: 0.6300
# Epoch 5/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 16s 4s/step - accuracy: 0.5657 - loss: 0.6875 - val_accuracy: 0.7000 - val_loss: 0.6350
# Epoch 6/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 16s 4s/step - accuracy: 0.5740 - loss: 0.6830 - val_accuracy: 0.7000 - val_loss: 0.6381
# Epoch 7/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 16s 4s/step - accuracy: 0.5271 - loss: 0.6999 - val_accuracy: 0.7000 - val_loss: 0.6503
# Epoch 7: early stopping
# Restoring model weights from the end of the best epoch: 4.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 743ms/step - accuracy: 0.7000 - loss: 0.6300
# Test Accuracy: 70.00%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 830ms/step
# Confusion Matrix:
# [[14  0]
#  [ 6  0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.82        14
#            1       0.00      0.00      0.00         6
#
#     accuracy                           0.70        20
#    macro avg       0.35      0.50      0.41        20
# weighted avg       0.49      0.70      0.58        20
#
# AUC Score: 0.50
#
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
# Cohen's Kappa Coefficient: 0.0
# Matthews Correlation Coefficient (MCC): 0.0
# Balanced Accuracy: 0.5
# Model predictions saved to: model_predictions.csv
# Time taken: 116.82 seconds

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.layers import Layer, Dense, Flatten, Input, Reshape, Conv2D, MaxPooling2D
from tensorflow.keras.models import Model
import cv2
import time
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, balanced_accuracy_score
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping
import csv

# Define Capsule Layer
class CapsuleLayer(Layer):
    def __init__(self, num_capsule, dim_capsule, routings=3, **kwargs):
        super(CapsuleLayer, self).__init__(**kwargs)
        self.num_capsule = num_capsule
        self.dim_capsule = dim_capsule
        self.routings = routings

    def build(self, input_shape):
        input_dim_capsule = input_shape[-1]
        self.W = self.add_weight(shape=[input_dim_capsule, self.num_capsule * self.dim_capsule],
                                 initializer='glorot_uniform',
                                 name='W')

    def call(self, u_vecs):
        u_hat_vecs = tf.reduce_sum(tf.expand_dims(u_vecs, -1) * tf.expand_dims(self.W, 0), axis=-2)
        b = tf.zeros(shape=[tf.shape(u_hat_vecs)[0], self.num_capsule])
        for i in range(self.routings):
            c = tf.nn.softmax(b, axis=1)
            s_j = tf.reduce_sum(tf.multiply(c[:, :, None], u_hat_vecs), axis=1)
            v_j = self.squash(s_j)
            if i < self.routings - 1:
                b += tf.reduce_sum(tf.multiply(v_j[:, None, :], u_hat_vecs), axis=-1)
        return v_j

    def squash(self, s_j):
        s_squared_norm = tf.reduce_sum(tf.square(s_j), axis=-1, keepdims=True)
        scale = s_squared_norm / (1 + s_squared_norm) / tf.sqrt(s_squared_norm + tf.keras.backend.epsilon())
        return scale * s_j

# Start time
start_time = time.time()

# Placeholder data - replace with your actual training and testing data
X_train = np.random.rand(100, 100, 3)  # Example training data with shape (100, 100, 3)
y_train = np.random.randint(0, 2, size=100)  # Example training labels (binary)
X_test = np.random.rand(20, 100, 3)  # Example testing data with shape (20, 100, 3)
y_test = np.random.randint(0, 2, size=20)  # Example testing labels (binary)

# Modify the data shapes based on the model requirements
X_train_resized = np.array([cv2.resize(img, (224, 224)) for img in X_train])
X_train_resized = np.expand_dims(X_train_resized, axis=-1)  # Add channel dimension
X_train_resized = np.repeat(X_train_resized, 3, axis=-1)  # Repeat the channel dimension to match the expected input shape of VGG16

# Example: Assuming X_test is another dataset
X_test_resized = np.array([cv2.resize(img, (224, 224)) for img in X_test])
X_test_resized = np.expand_dims(X_test_resized, axis=-1)
X_test_resized = np.repeat(X_test_resized, 3, axis=-1)

# Load pre-trained VGG16 model without top layers
vgg_base = tf.keras.applications.VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Add Capsule Network layer on top of VGG16
input_tensor = Input(shape=(224, 224, 3))
vgg_output = vgg_base(input_tensor)
flatten = Flatten()(vgg_output)
x = Dense(128, activation='relu')(flatten)
x = Reshape((-1, 128))(x)  # Reshape to 3D tensor for Capsule Network
capsule = CapsuleLayer(num_capsule=10, dim_capsule=16, routings=3)(x)  # Example: 10 capsules with dimension 16
capsule = Flatten()(capsule)  # Flatten the output
output = Dense(1, activation='sigmoid')(capsule)  # Use a single output unit for binary classification

# Create the full model
model = Model(inputs=input_tensor, outputs=output)

# Compile the model with Adam optimizer
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Display model summary
model.summary()

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)

# Train the model with early stopping and 50 epochs
history = model.fit(X_train_resized, y_train, epochs=200, validation_data=(X_test_resized, y_test), callbacks=[early_stopping])

# Plot training history
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test_resized, y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')

# Confusion matrix
test_predictions = (model.predict(X_test_resized) > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test, test_predictions)
print("Confusion Matrix:")
print(conf_matrix)

# Generate classification report
print("Classification Report:")
print(classification_report(y_test, test_predictions))

# ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, test_predictions)
roc_auc = roc_auc_score(y_test, test_predictions)
print(f'AUC Score: {roc_auc:.2f}')

# Calculate Precision, Recall, F1 Score, Cohen's Kappa, Matthews Correlation Coefficient, and Balanced Accuracy
precision = precision_score(y_test, test_predictions)
recall = recall_score(y_test, test_predictions)
f1 = f1_score(y_test, test_predictions)
kappa = cohen_kappa_score(y_test, test_predictions)
mcc = matthews_corrcoef(y_test, test_predictions)
balanced_acc = balanced_accuracy_score(y_test, test_predictions)

# Print additional metrics
print("\nPrecision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Cohen's Kappa Coefficient:", kappa)
print("Matthews Correlation Coefficient (MCC):", mcc)
print("Balanced Accuracy:", balanced_acc)

# Save the model predictions to a CSV file
csv_file = "model_predictions.csv"
with open(csv_file, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['True_Label', 'Predicted_Label'])
    writer.writerows(zip(y_test, test_predictions))

print("Model predictions saved to:", csv_file)

# End time
end_time = time.time()

# Print the time taken
print(f"Time taken: {end_time - start_time:.2f} seconds")
# Out:
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_9 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ vgg16 (Functional)              │ (None, 7, 7, 512)      │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_8 (Flatten)             │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 128)            │     3,211,392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_3 (Reshape)             │ (None, 1, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ capsule_layer_2 (CapsuleLayer)  │ (None, 160)            │        20,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_9 (Flatten)             │ (None, 160)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 1)              │           161 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,946,721 (68.46 MB)
#  Trainable params: 17,946,721 (68.46 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 17s 4s/step - accuracy: 0.4969 - loss: 0.7015 - val_accuracy: 0.3000 - val_loss: 0.7223
# Epoch 2/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 16s 4s/step - accuracy: 0.4295 - loss: 0.6992 - val_accuracy: 0.7000 - val_loss: 0.6750
# Epoch 3/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 16s 4s/step - accuracy: 0.4809 - loss: 0.6978 - val_accuracy: 0.7000 - val_loss: 0.6823
# Epoch 4/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 16s 4s/step - accuracy: 0.4747 - loss: 0.6960 - val_accuracy: 0.7000 - val_loss: 0.6850
# Epoch 5/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 16s 4s/step - accuracy: 0.4945 - loss: 0.6936 - val_accuracy: 0.7000 - val_loss: 0.6788
# Epoch 5: early stopping
# Restoring model weights from the end of the best epoch: 2.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 743ms/step - accuracy: 0.7000 - loss: 0.6750
# Test Accuracy: 70.00%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 841ms/step
# Confusion Matrix:
# [[ 0  6]
#  [ 0 14]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         6
#            1       0.70      1.00      0.82        14
#
#     accuracy                           0.70        20
#    macro avg       0.35      0.50      0.41        20
# weighted avg       0.49      0.70      0.58        20
#
# AUC Score: 0.50
#
# Precision: 0.7
# Recall: 1.0
# F1 Score: 0.8235294117647058
# Cohen's Kappa Coefficient: 0.0
# Matthews Correlation Coefficient (MCC): 0.0
# Balanced Accuracy: 0.5
# Model predictions saved to: model_predictions.csv
# Time taken: 83.82 seconds
